# %%
# -----------------------------------------------------------------------------
# Step 1: Load raw weather data
# -----------------------------------------------------------------------------
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Set font globally
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 14
plt.rcParams["font.weight"] = "bold"

# Load the processed dataset with parsed timestamps
file_path = "Data/Exp/ProcessedData_Meteorological_Wollongong_01Dec24_to_20Jan25.csv"
df = pd.read_csv(file_path, parse_dates=['Timestamp'])

# Create the plot
fig, ax1 = plt.subplots(figsize=(16, 7))

# Plot temperature, wind speed
ax1.plot(
    df['Timestamp'],
    df['Temperature_C'],
    label='Temperature (°C)',
    color='crimson',
    linewidth=3,
    marker='o',
    markersize=3,
    alpha=0.5
)
ax1.plot(
    df['Timestamp'],
    df['Wind_km_h'],
    label='Wind Speed (km/h)',
    color='navy',
    linewidth=3,
    marker='^',
    markersize=3,
    alpha=0.5
)

# Plot humidity and precipitation on secondary y-axis
ax2 = ax1.twinx()
ax2.plot(
    df['Timestamp'],
    df['Humidity_%'],
    label='Humidity (%)',
    color='teal',
    linewidth=3,
    marker='s',
    markersize=3,
    alpha=0.5
)
ax2.plot(
    df['Timestamp'],
    df['Precipitation_%'],
    label='Precipitation (%)',
    color='coral',
    linewidth=3,
    marker='d',
    markersize=3,
    alpha=0.5
)

# Axis labels
ax1.set_xlabel('Timestamp (hr)', fontweight='bold')
ax1.set_ylabel('Temperature / Wind', fontweight='bold')
ax2.set_ylabel('Humidity / Precipitation', fontweight='bold')

# 1. Major ticks at 12:00 each day (so "10 Jan 2025" appears at midday)
ax1.xaxis.set_major_locator(mdates.HourLocator(interval=24*5))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%b-%y'))

# 2. Minor ticks = every 6 hours
ax1.xaxis.set_minor_locator(mdates.HourLocator(interval=24*10))

# 3. Vertical grid lines at every 6h (minor ticks)
ax1.grid(which='minor', linestyle='--', color='coral', alpha=0.5)

# 3a. Horizontal grid lines at each y‐major tick
ax1.grid(which='major', axis='y', linestyle='--', color='coral', alpha=0.5)

ax2.grid(which='major', axis='y', linestyle='--', color='cyan', alpha=0.5)

# 4. Ensure no grid at x‐major ticks
ax1.grid(which='major', axis='x', color='coral', alpha=0.5, visible=True)

# 5. Fix x‐axis range: 
start = pd.Timestamp("2024-12-01 00:00")
end   = pd.Timestamp("2025-01-20 23:00")
ax1.set_xlim(start, end)

# 6. Keep x‐axis labels horizontal & set font size
ax1.tick_params(axis='x', rotation=0, labelsize=13)

# # Remove or comment out this line so labels stay horizontal:
# fig.autofmt_xdate()

# # Shade 15–19 Jan as severe weather
# ax1.axvspan(
#     pd.Timestamp("2025-01-15 14:20"),
#     pd.Timestamp("2025-01-18 22:59"),
#     color='salmon',
#     alpha=0.3,
#     label='Severe Weather Period'
# )

# Merge legends from both axes + shaded patch
lines, labels   = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(
    lines + lines2,
    labels + labels2,
    loc='upper center',
    bbox_to_anchor=(0.5, 1.1),
    ncol=4,
    frameon=True
)

plt.tight_layout()
# plt.savefig(
#     "Figures/Wollongong_Weather_10_20_Jan_2025.png",
#     dpi=600,
#     bbox_inches='tight'
# )
plt.show()


print(df)
df.describe()
# Out:
#                Timestamp  Temperature_C  Wind_km_h  Humidity_%  \
# 0    2024-12-01 00:00:00           20.0       15.0        92.0
# 1    2024-12-01 01:00:00           19.0       20.0        95.0
# 2    2024-12-01 02:00:00           19.0       22.0        95.0
# 3    2024-12-01 03:00:00           19.0       22.0        96.0
# 4    2024-12-01 04:00:00           19.0       13.0        96.0
# ...                  ...            ...        ...         ...
# 1205 2025-01-20 19:00:00           21.0       11.0        62.0
# 1206 2025-01-20 20:00:00           20.0        9.0        65.0
# 1207 2025-01-20 21:00:00           20.0        0.0        67.0
# 1208 2025-01-20 22:00:00           18.0        0.0        73.0
# 1209 2025-01-20 23:00:00           18.0        9.0        75.0
#
#       Precipitation_%
# 0               67.09
# 1               71.61
# 2               77.00
# 3               80.34
# 4               79.11
# ...               ...
# 1205            13.33
# 1206            16.89
# 1207            20.44
# 1208            24.00
# 1209            25.50
#
# [1210 rows x 5 columns]
#                            Timestamp  Temperature_C    Wind_km_h   Humidity_%  \
# count                           1210    1209.000000  1209.000000  1209.000000
# mean   2024-12-26 07:00:35.702479360      22.011580    20.103391    76.727874
# min              2024-12-01 00:00:00      15.000000     0.000000    15.000000
# 25%              2024-12-13 14:15:00      20.000000    11.000000    71.000000
# 50%              2024-12-26 04:30:00      22.000000    17.000000    79.000000
# 75%              2025-01-07 22:45:00      23.000000    26.000000    86.000000
# max              2025-01-20 23:00:00      37.000000    76.000000    96.000000
# std                              NaN       2.539072    13.720123    12.744869
#
#        Precipitation_%
# count      1210.000000
# mean         24.442504
# min           0.000000
# 25%          10.247500
# 50%          20.000000
# 75%          35.220000
# max          97.000000
# std          18.265622

# %%
### Check whether any 'NaN' or '0' value exists
get_Null = df.isnull().sum()

if get_Null.sum(axis=0).any():   # cleaner check for any nulls
    # Use forward fill instead of interpolate with method='ffill'
    df.ffill(inplace=True)
    print("NaN values found!!")  
    print(get_Null)
    print("====Fixing====")
    print(df.isnull().sum())
    print("NaN values are gone!!")
else:
    print("Did not find any Null/NaN values")
# Out:
# NaN values found!!
# Timestamp          0
# Temperature_C      1
# Wind_km_h          1
# Humidity_%         1
# Precipitation_%    0
# dtype: int64
# ====Fixing====
# Timestamp          0
# Temperature_C      0
# Wind_km_h          0
# Humidity_%         0
# Precipitation_%    0
# dtype: int64
# NaN values are gone!!

# %%
# Create a copy of the input DataFrame
df_x = df.copy()
# Convert the 'Timestamp' column to a datetime data type
df_x['Timestamp'] = pd.to_datetime(df_x['Timestamp'])
# Set the 'timestamp' column as the index of the DataFrame
df_x.set_index('Timestamp', inplace=True)
# Resample to 3-hour intervals (mean to smooth hourly data)
df_x = df_x.resample("3h").mean()

df_x
# Out:
#                      Temperature_C  Wind_km_h  Humidity_%  Precipitation_%
# Timestamp
# 2024-12-01 00:00:00      19.333333  19.000000   94.000000        71.900000
# 2024-12-01 03:00:00      19.000000  15.333333   96.000000        76.743333
# 2024-12-01 06:00:00      21.333333  12.000000   86.333333        32.780000
# 2024-12-01 09:00:00      24.333333  14.000000   73.666667         9.073333
# 2024-12-01 12:00:00      23.333333  25.333333   79.333333        18.850000
# ...                            ...        ...         ...              ...
# 2025-01-20 09:00:00      21.666667  15.666667   54.666667        13.000000
# 2025-01-20 12:00:00      22.000000  15.666667   57.333333         9.333333
# 2025-01-20 15:00:00      22.000000  13.000000   56.000000         9.146667
# 2025-01-20 18:00:00      21.000000  11.000000   61.000000        13.703333
# 2025-01-20 21:00:00      18.666667   3.000000   71.666667        23.313333
#
# [408 rows x 4 columns]

# %%
### Check whether any 'NaN' or '0' value exists
get_Null = df_x.isnull().sum()

if get_Null.sum(axis=0).any():   # cleaner check for any nulls
    # Use forward fill instead of interpolate with method='ffill'
    df_x.ffill(inplace=True)
    print("NaN values found!!")  
    print(get_Null)
    print("====Fixing====")
    print(df_x.isnull().sum())
    print("NaN values are gone!!")
else:
    print("Did not find any Null/NaN values")
# Out:
# Did not find any Null/NaN values

# %%
# Create a copy of the input DataFrame
df_plot = df_x.copy()

# Reset the index of the resampled DataFrame
df_plot = df_plot.reset_index()

# Convert the 'Timestamp' column back to a datetime data type
df_plot['Timestamp'] = pd.to_datetime(df_plot['Timestamp'])

# Create the plot
fig, ax1 = plt.subplots(figsize=(16, 7))

# Plot temperature, wind speed
ax1.plot(
    df_plot['Timestamp'],
    df_plot['Temperature_C'],
    label='Temperature (°C)',
    color='crimson',
    linewidth=3,
    marker='o',
    markersize=3,
    alpha=0.5
)
ax1.plot(
    df_plot['Timestamp'],
    df_plot['Wind_km_h'],
    label='Wind Speed (km/h)',
    color='navy',
    linewidth=3,
    marker='^',
    markersize=3,
    alpha=0.5
)

# Plot humidity and precipitation on secondary y-axis
ax2 = ax1.twinx()
ax2.plot(
    df_plot['Timestamp'],
    df_plot['Humidity_%'],
    label='Humidity (%)',
    color='teal',
    linewidth=3,
    marker='s',
    markersize=3,
    alpha=0.5
)
ax2.plot(
    df_plot['Timestamp'],
    df_plot['Precipitation_%'],
    label='Precipitation (%)',
    color='coral',
    linewidth=3,
    marker='d',
    markersize=3,
    alpha=0.5
)

# Axis labels
ax1.set_xlabel('Timestamp (3hr)', fontweight='bold')
ax1.set_ylabel('Temperature / Wind', fontweight='bold')
ax2.set_ylabel('Humidity / Precipitation', fontweight='bold')

# 1. Major ticks at 12:00 each day (so "10 Jan 2025" appears at midday)
ax1.xaxis.set_major_locator(mdates.HourLocator(interval=24*5))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%b-%y'))

# 2. Minor ticks = every 6 hours
ax1.xaxis.set_minor_locator(mdates.HourLocator(interval=24*10))

# 3. Vertical grid lines at every 6h (minor ticks)
ax1.grid(which='minor', linestyle='--', color='coral', alpha=0.5)

# 3a. Horizontal grid lines at each y‐major tick
ax1.grid(which='major', axis='y', linestyle='--', color='coral', alpha=0.5)

ax2.grid(which='major', axis='y', linestyle='--', color='cyan', alpha=0.5)

# 4. Ensure no grid at x‐major ticks
ax1.grid(which='major', axis='x', color='coral', alpha=0.5, visible=True)

# 5. Fix x‐axis range: 
start = pd.Timestamp("2024-12-01 00:00")
end   = pd.Timestamp("2025-01-20 23:00")
ax1.set_xlim(start, end)

# 6. Keep x‐axis labels horizontal & set font size
ax1.tick_params(axis='x', rotation=0, labelsize=13)

# # Remove or comment out this line so labels stay horizontal:
# fig.autofmt_xdate()

# # Shade 15–19 Jan as severe weather
# ax1.axvspan(
#     pd.Timestamp("2025-01-15 14:20"),
#     pd.Timestamp("2025-01-18 22:59"),
#     color='salmon',
#     alpha=0.3,
#     label='Severe Weather Period'
# )

# Merge legends from both axes + shaded patch
lines, labels   = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(
    lines + lines2,
    labels + labels2,
    loc='upper center',
    bbox_to_anchor=(0.5, 1.1),
    ncol=4,
    frameon=True
)

plt.tight_layout()
# plt.savefig(
#     "Figures/Wollongong_Weather_10_20_Jan_2025.png",
#     dpi=600,
#     bbox_inches='tight'
# )
plt.show()


print(df_plot)
df_plot.describe()
# Out:
#               Timestamp  Temperature_C  Wind_km_h  Humidity_%  Precipitation_%
# 0   2024-12-01 00:00:00      19.333333  19.000000   94.000000        71.900000
# 1   2024-12-01 03:00:00      19.000000  15.333333   96.000000        76.743333
# 2   2024-12-01 06:00:00      21.333333  12.000000   86.333333        32.780000
# 3   2024-12-01 09:00:00      24.333333  14.000000   73.666667         9.073333
# 4   2024-12-01 12:00:00      23.333333  25.333333   79.333333        18.850000
# ..                  ...            ...        ...         ...              ...
# 403 2025-01-20 09:00:00      21.666667  15.666667   54.666667        13.000000
# 404 2025-01-20 12:00:00      22.000000  15.666667   57.333333         9.333333
# 405 2025-01-20 15:00:00      22.000000  13.000000   56.000000         9.146667
# 406 2025-01-20 18:00:00      21.000000  11.000000   61.000000        13.703333
# 407 2025-01-20 21:00:00      18.666667   3.000000   71.666667        23.313333
#
# [408 rows x 5 columns]
#                            Timestamp  Temperature_C   Wind_km_h  Humidity_%  \
# count                            408     408.000000  408.000000  408.000000
# mean   2024-12-26 10:29:59.999999744      21.994281   20.322712   76.705065
# min              2024-12-01 00:00:00      16.000000    0.666667   16.000000
# 25%              2024-12-13 17:15:00      20.625000   11.250000   70.333333
# 50%              2024-12-26 10:30:00      21.833333   16.333333   78.500000
# 75%              2025-01-08 03:45:00      23.333333   26.083333   85.000000
# max              2025-01-20 21:00:00      36.666667   72.500000   96.000000
# std                              NaN       2.417031   13.357258   12.085272
#
#        Precipitation_%
# count       408.000000
# mean         24.640286
# min           0.000000
# 25%          10.474167
# 50%          20.000000
# 75%          35.462500
# max          91.743333
# std          17.998744

# %%
from pathlib import Path
import pickle
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# 1) Fit scaler on df_x and transform
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(
    scaler.fit_transform(df_x.values),
    index=df_x.index,
    columns=df_x.columns
)

# 2) Save the fitted scaler
model_dir = Path("Model")
model_dir.mkdir(parents=True, exist_ok=True)
scaler_path = model_dir / "scaleWeatherData.pkl"   # e.g., Model\scaleWeatherData.pkl
with open(scaler_path, "wb") as f:
    pickle.dump(scaler, f)

print("Scaled DataFrame shape:", df_scaled.shape)
print("Scaler saved to:", scaler_path)


with open("Model/scaleWeatherData.pkl", "rb") as f:
    scaler = pickle.load(f)


# Load later and inverse-transform (if needed):
# inverse: original_df = pd.DataFrame(scaler.inverse_transform(df_scaled), df_scaled.index, df_scaled.columns)
# Out:
# Scaled DataFrame shape: (408, 4)
# Scaler saved to: Model\scaleWeatherData.pkl

# %%
df_scaled
# Out:
#                      Temperature_C  Wind_km_h  Humidity_%  Precipitation_%
# Timestamp
# 2024-12-01 00:00:00       0.161290   0.255220    0.975000         0.783708
# 2024-12-01 03:00:00       0.145161   0.204176    1.000000         0.836500
# 2024-12-01 06:00:00       0.258065   0.157773    0.879167         0.357301
# 2024-12-01 09:00:00       0.403226   0.185615    0.720833         0.098899
# 2024-12-01 12:00:00       0.354839   0.343387    0.791667         0.205465
# ...                            ...        ...         ...              ...
# 2025-01-20 09:00:00       0.274194   0.208817    0.483333         0.141700
# 2025-01-20 12:00:00       0.290323   0.208817    0.516667         0.101733
# 2025-01-20 15:00:00       0.290323   0.171694    0.500000         0.099698
# 2025-01-20 18:00:00       0.241935   0.143852    0.562500         0.149366
# 2025-01-20 21:00:00       0.129032   0.032483    0.695833         0.254115
#
# [408 rows x 4 columns]

# %%
import numpy as np

IN_LEN  = 14 * 8   # input window length
OUT_LEN =  3 * 8   # forecast horizon
OBS_LEN =  3 * 8   # observation buffer

def make_windows_1d(series, in_len=IN_LEN, out_len=OUT_LEN, obs_len=OBS_LEN):
    """
    series: 1D numpy array (scaled)
    returns:
      X: [N, in_len, 1]
      y: [N, out_len]
      limited so that at least obs_len points remain after the last output
    """
    # effective usable length excludes the trailing buffer
    usable_len = len(series) - (in_len + out_len + obs_len) + in_len + out_len + obs_len
    N = usable_len - (in_len + out_len) + 1
    if N <= 0:
        raise ValueError(
            f"Need at least {in_len+out_len+obs_len} points; have {len(series)}."
        )
    
    X = np.empty((N, in_len, 1), dtype=np.float32)
    Y = np.empty((N, out_len),  dtype=np.float32)
    for i in range(N):
        X[i, :, 0] = series[i : i + in_len]
        Y[i, :]    = series[i + in_len : i + in_len + out_len]
    return X, Y

# --- Build windows per variable from df_scaled ---
datasets = {}
for col in df_scaled.columns:
    s = df_scaled[col].to_numpy(dtype=float)
    X, y = make_windows_1d(s, IN_LEN, OUT_LEN, OBS_LEN)
    datasets[col] = {"X": X, "y": y}
    print(f"{col}: X{X.shape}, y{y.shape}")
# Out:
# Temperature_C: X(273, 112, 1), y(273, 24)
# Wind_km_h: X(273, 112, 1), y(273, 24)
# Humidity_%: X(273, 112, 1), y(273, 24)
# Precipitation_%: X(273, 112, 1), y(273, 24)

# %%
# Example access:
X_temp = datasets["Temperature_C"]["X"]   # shape [N, 114, 1]
y_temp = datasets["Temperature_C"]["y"]   # shape [N, 24]
print("X_temp.shape:", X_temp.shape)
print("y_temp.shape:", y_temp.shape)
# Out:
# X_temp.shape: (273, 112, 1)
# y_temp.shape: (273, 24)

# %%
X_temp[len(X_temp)-1].shape
# Out:
# (112, 1)

# %%
y_temp[len(y_temp)-1]
# Out:
# array([0.19354838, 0.17741935, 0.06451613, 0.20967741, 0.32258064,
#        0.30645162, 0.29032257, 0.22580644, 0.24193548, 0.19354838,
#        0.20967741, 0.24193548, 0.29032257, 0.27419356, 0.20967741,
#        0.16129032, 0.06451613, 0.03225806, 0.0483871 , 0.27419356,
#        0.29032257, 0.29032257, 0.24193548, 0.12903225], dtype=float32)

# %%
last_idx = len(y_temp) - 1   # last window index
end_pos  = last_idx + IN_LEN + OUT_LEN - 1
last_ts  = df_scaled.index[end_pos]   # timestamp in original df_x index
print("Last target timestamp:", last_ts)
# Out:
# Last target timestamp: 2025-01-20 21:00:00

# %%
X.shape[1]
# Out:
# 112

# %%
y.shape[1]
# Out:
# 24

# %%
X.shape[2]
# Out:
# 1

# %%
# ===========================================================
# Part 1: Define MSDL (Multilayer Stacked Deep Learning) Model
# ===========================================================

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from pathlib import Path
import gc

def build_MSDL(input_len=112, out_len=24, n_features=1):
    """
    Build a Multilayer Stacked Deep Learning (MSDL) model for
    multi-step time series forecasting.

    Parameters
    ----------
    input_len : int
        Number of past time steps (look-back window) used as input.
    out_len : int
        Number of future time steps to forecast.
    n_features : int
        Number of features per time step (e.g., 1 for univariate data).

    Returns
    -------
    model : tf.keras.Model
        Compiled Keras model ready for training.
    """

    model = models.Sequential([

        # Input layer expects sequences of length = input_len, with n_features each
        layers.Input(shape=(input_len, n_features)),

        # First LSTM layer (returns full sequence to allow stacking)
        layers.LSTM(128, return_sequences=True),

        # Second LSTM layer (returns only the last hidden state)
        layers.LSTM(64, return_sequences=False),

        # Dense hidden layer for learning non-linear combinations of features
        layers.Dense(128, activation="relu"),

        # Dropout layer for regularization (prevents overfitting)
        layers.Dropout(0.2),

        # Final output layer → produces out_len forecast steps
        layers.Dense(out_len)
    ])

    # Compile the model with optimizer and loss function
    model.compile(
        optimizer="adam",         # adaptive learning rate optimizer
        loss="mse",               # mean squared error for regression
        metrics=["mae"]           # mean absolute error as additional metric
    )

    return model


# ===============================
# Example: Build and summarize model
# ===============================
model = build_MSDL(input_len=112, out_len=24, n_features=1)

# Print architecture summary (layers, output shapes, parameters)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 112, 128)          66560
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 128)               8320
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 127,384
# Trainable params: 127,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ===========================================================
# Part 2.A: Train & Save MSDL Model for Temperature Forecasting
# ===========================================================

# --- Prepare training data (pre-windowed) ---
X = datasets["Temperature_C"]["X"]   # shape = [N, 112, 1], input sequences
y = datasets["Temperature_C"]["y"]   # shape = [N, 24],     forecast targets

# --- 4× replication (no augmentation) ---
X = np.concatenate([X, X, X, X], axis=0)
y = np.concatenate([y, y, y, y], axis=0)

# (recommended) shuffle to avoid repeated blocks in order
idx = np.random.permutation(len(X))
X, y = X[idx], y[idx]

# --- Reproducibility (optional) ---
np.random.seed(42)
tf.random.set_seed(42)

# --- HARD RESET: clear any existing graph/weights, free memory ---
tf.keras.backend.clear_session()
try:
    del model
except NameError:
    pass
gc.collect()

# --- Fresh model ---
model = build_MSDL(input_len=X.shape[1], out_len=y.shape[1], n_features=X.shape[2])

# --- Define output directory and model save path ---
out_dir = Path("Model")
out_dir.mkdir(parents=True, exist_ok=True)
model_path = out_dir / "predictiveAnalysisWeather_T.h5"

# --- Configure callbacks ---
early_stop = EarlyStopping(
    monitor="val_loss",          # stop monitoring validation loss
    patience=20,                 # wait 20 epochs with no improvement
    restore_best_weights=True    # roll back to best weights at the end
)

checkpoint = ModelCheckpoint(
    filepath=model_path,         # save path for the best model
    monitor="val_loss",          # criterion for saving
    save_best_only=True,         # overwrite only if val_loss improves
    verbose=1                    # print when model is saved
)

# --- Train the MSDL model ---
history = model.fit(
    X, y,
    epochs=500,                  # maximum epochs (may stop earlier due to EarlyStopping)
    batch_size=16,               # mini-batch size
    validation_split=0.1,        # 10% of data for validation
    verbose=1,                   # print training progress
    callbacks=[early_stop, checkpoint]
)

# --- Save the final (best) model explicitly ---
model.save(model_path)
print(f"✅ MSDL model for Temperature saved to: {model_path}")

# %%
# ===========================================================
# Part 2.B: Train & Save MSDL Model for Humidity Forecasting
# ===========================================================

# --- Prepare training data (pre-windowed) ---
X = datasets["Humidity_%"]["X"]   # shape = [N, 112, 1], input sequences
y = datasets["Humidity_%"]["y"]   # shape = [N, 24],     forecast targets


# --- 4× replication (no augmentation) ---
X = np.concatenate([X, X, X, X], axis=0)
y = np.concatenate([y, y, y, y], axis=0)

# (recommended) shuffle to avoid repeated blocks in order
idx = np.random.permutation(len(X))
X, y = X[idx], y[idx]


# --- Reproducibility (optional) ---
np.random.seed(42)
tf.random.set_seed(42)

# --- HARD RESET: clear any existing graph/weights, free memory ---
tf.keras.backend.clear_session()
try:
    del model
except NameError:
    pass
gc.collect()

# --- Fresh model ---
model = build_MSDL(input_len=X.shape[1], out_len=y.shape[1], n_features=X.shape[2])

# --- Define output directory and model save path ---
out_dir = Path("Model")
out_dir.mkdir(parents=True, exist_ok=True)
model_path = out_dir / "predictiveAnalysisWeather_H.h5"

# --- Configure callbacks ---
early_stop = EarlyStopping(
    monitor="val_loss",          # monitor validation loss
    patience=10,                 # stop if no improvement for 20 epochs
    restore_best_weights=True    # restore weights from best epoch
)

checkpoint = ModelCheckpoint(
    filepath=model_path,         # save path for the best model
    monitor="val_loss",          # criterion for saving
    save_best_only=True,         # overwrite only if val_loss improves
    verbose=1                    # log when model is saved
)


# --- Train the MSDL model ---
history = model.fit(
    X, y,
    epochs=500,                  # maximum epochs (early stop may cut shorter)
    batch_size=16,               # training batch size
    validation_split=0.1,        # reserve 10% of data for validation
    verbose=1,                   # print training progress
    callbacks=[early_stop, checkpoint]
)

# --- Save the final (best) model explicitly ---
model.save(model_path)
print(f"✅ MSDL model for Humidity saved to: {model_path}")
# Out:
# Epoch 1/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.1266 - mae: 0.2699
# Epoch 1: val_loss improved from inf to 0.02256, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 3s 23ms/step - loss: 0.1252 - mae: 0.2683 - val_loss: 0.0226 - val_mae: 0.1190
# Epoch 2/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0401 - mae: 0.1586
# Epoch 2: val_loss improved from 0.02256 to 0.02127, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 17ms/step - loss: 0.0401 - mae: 0.1586 - val_loss: 0.0213 - val_mae: 0.1144
# Epoch 3/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0353 - mae: 0.1489
# Epoch 3: val_loss improved from 0.02127 to 0.02077, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0353 - mae: 0.1489 - val_loss: 0.0208 - val_mae: 0.1126
# Epoch 4/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0329 - mae: 0.1436
# Epoch 4: val_loss improved from 0.02077 to 0.02069, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0329 - mae: 0.1436 - val_loss: 0.0207 - val_mae: 0.1112
# Epoch 5/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0312 - mae: 0.1395
# Epoch 5: val_loss did not improve from 0.02069
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0312 - mae: 0.1395 - val_loss: 0.0210 - val_mae: 0.1150
# Epoch 6/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0293 - mae: 0.1352
# Epoch 6: val_loss did not improve from 0.02069
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0293 - mae: 0.1351 - val_loss: 0.0210 - val_mae: 0.1132
# Epoch 7/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0289 - mae: 0.1343
# Epoch 7: val_loss did not improve from 0.02069
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0288 - mae: 0.1341 - val_loss: 0.0222 - val_mae: 0.1116
# Epoch 8/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0281 - mae: 0.1318
# Epoch 8: val_loss improved from 0.02069 to 0.02035, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0280 - mae: 0.1316 - val_loss: 0.0203 - val_mae: 0.1100
# Epoch 9/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0279 - mae: 0.1314
# Epoch 9: val_loss did not improve from 0.02035
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0279 - mae: 0.1314 - val_loss: 0.0210 - val_mae: 0.1146
# Epoch 10/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0272 - mae: 0.1293
# Epoch 10: val_loss did not improve from 0.02035
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0272 - mae: 0.1292 - val_loss: 0.0208 - val_mae: 0.1137
# Epoch 11/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0269 - mae: 0.1285
# Epoch 11: val_loss did not improve from 0.02035
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0269 - mae: 0.1285 - val_loss: 0.0206 - val_mae: 0.1118
# Epoch 12/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0272 - mae: 0.1299
# Epoch 12: val_loss did not improve from 0.02035
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0272 - mae: 0.1298 - val_loss: 0.0210 - val_mae: 0.1143
# Epoch 13/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0266 - mae: 0.1284
# Epoch 13: val_loss improved from 0.02035 to 0.02027, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0266 - mae: 0.1283 - val_loss: 0.0203 - val_mae: 0.1100
# Epoch 14/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0266 - mae: 0.1284
# Epoch 14: val_loss did not improve from 0.02027
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0266 - mae: 0.1284 - val_loss: 0.0215 - val_mae: 0.1098
# Epoch 15/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0254 - mae: 0.1250
# Epoch 15: val_loss did not improve from 0.02027
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0254 - mae: 0.1251 - val_loss: 0.0204 - val_mae: 0.1083
# Epoch 16/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0250 - mae: 0.1238
# Epoch 16: val_loss improved from 0.02027 to 0.02022, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0250 - mae: 0.1238 - val_loss: 0.0202 - val_mae: 0.1086
# Epoch 17/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0255 - mae: 0.1252
# Epoch 17: val_loss did not improve from 0.02022
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0255 - mae: 0.1252 - val_loss: 0.0202 - val_mae: 0.1107
# Epoch 18/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0252 - mae: 0.1246
# Epoch 18: val_loss did not improve from 0.02022
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0251 - mae: 0.1244 - val_loss: 0.0204 - val_mae: 0.1088
# Epoch 19/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0251 - mae: 0.1243
# Epoch 19: val_loss improved from 0.02022 to 0.02012, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0251 - mae: 0.1242 - val_loss: 0.0201 - val_mae: 0.1084
# Epoch 20/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0247 - mae: 0.1236
# Epoch 20: val_loss did not improve from 0.02012
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0247 - mae: 0.1237 - val_loss: 0.0203 - val_mae: 0.1083
# Epoch 21/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0249 - mae: 0.1236
# Epoch 21: val_loss did not improve from 0.02012
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0249 - mae: 0.1235 - val_loss: 0.0219 - val_mae: 0.1192
# Epoch 22/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0245 - mae: 0.1224
# Epoch 22: val_loss did not improve from 0.02012
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0249 - mae: 0.1232 - val_loss: 0.0216 - val_mae: 0.1179
# Epoch 23/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0243 - mae: 0.1220
# Epoch 23: val_loss did not improve from 0.02012
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0243 - mae: 0.1220 - val_loss: 0.0227 - val_mae: 0.1225
# Epoch 24/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0247 - mae: 0.1233
# Epoch 24: val_loss did not improve from 0.02012
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0247 - mae: 0.1233 - val_loss: 0.0226 - val_mae: 0.1117
# Epoch 25/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0244 - mae: 0.1222
# Epoch 25: val_loss did not improve from 0.02012
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0243 - mae: 0.1221 - val_loss: 0.0208 - val_mae: 0.1081
# Epoch 26/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0245 - mae: 0.1229
# Epoch 26: val_loss did not improve from 0.02012
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0246 - mae: 0.1230 - val_loss: 0.0216 - val_mae: 0.1094
# Epoch 27/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0242 - mae: 0.1216
# Epoch 27: val_loss did not improve from 0.02012
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0242 - mae: 0.1216 - val_loss: 0.0208 - val_mae: 0.1136
# Epoch 28/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0239 - mae: 0.1216
# Epoch 28: val_loss did not improve from 0.02012
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0239 - mae: 0.1216 - val_loss: 0.0202 - val_mae: 0.1082
# Epoch 29/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0237 - mae: 0.1199
# Epoch 29: val_loss improved from 0.02012 to 0.02011, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0236 - mae: 0.1198 - val_loss: 0.0201 - val_mae: 0.1083
# Epoch 30/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0237 - mae: 0.1204
# Epoch 30: val_loss did not improve from 0.02011
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0237 - mae: 0.1202 - val_loss: 0.0219 - val_mae: 0.1100
# Epoch 31/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0238 - mae: 0.1209
# Epoch 31: val_loss did not improve from 0.02011
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0239 - mae: 0.1211 - val_loss: 0.0209 - val_mae: 0.1145
# Epoch 32/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0236 - mae: 0.1200
# Epoch 32: val_loss improved from 0.02011 to 0.02009, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0234 - mae: 0.1195 - val_loss: 0.0201 - val_mae: 0.1069
# Epoch 33/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0234 - mae: 0.1198
# Epoch 33: val_loss did not improve from 0.02009
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0234 - mae: 0.1196 - val_loss: 0.0201 - val_mae: 0.1078
# Epoch 34/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0234 - mae: 0.1196
# Epoch 34: val_loss did not improve from 0.02009
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0235 - mae: 0.1200 - val_loss: 0.0209 - val_mae: 0.1141
# Epoch 35/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0233 - mae: 0.1191
# Epoch 35: val_loss did not improve from 0.02009
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0233 - mae: 0.1190 - val_loss: 0.0202 - val_mae: 0.1100
# Epoch 36/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0226 - mae: 0.1178
# Epoch 36: val_loss improved from 0.02009 to 0.01993, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0226 - mae: 0.1178 - val_loss: 0.0199 - val_mae: 0.1067
# Epoch 37/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0236 - mae: 0.1200
# Epoch 37: val_loss did not improve from 0.01993
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0236 - mae: 0.1201 - val_loss: 0.0201 - val_mae: 0.1068
# Epoch 38/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0232 - mae: 0.1194
# Epoch 38: val_loss improved from 0.01993 to 0.01982, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0232 - mae: 0.1195 - val_loss: 0.0198 - val_mae: 0.1078
# Epoch 39/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0226 - mae: 0.1177
# Epoch 39: val_loss did not improve from 0.01982
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0226 - mae: 0.1177 - val_loss: 0.0198 - val_mae: 0.1094
# Epoch 40/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0225 - mae: 0.1175
# Epoch 40: val_loss improved from 0.01982 to 0.01926, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 17ms/step - loss: 0.0225 - mae: 0.1175 - val_loss: 0.0193 - val_mae: 0.1045
# Epoch 41/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0226 - mae: 0.1175
# Epoch 41: val_loss did not improve from 0.01926
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0226 - mae: 0.1175 - val_loss: 0.0196 - val_mae: 0.1073
# Epoch 42/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0222 - mae: 0.1164
# Epoch 42: val_loss did not improve from 0.01926
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0221 - mae: 0.1164 - val_loss: 0.0194 - val_mae: 0.1079
# Epoch 43/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0225 - mae: 0.1177
# Epoch 43: val_loss did not improve from 0.01926
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0224 - mae: 0.1177 - val_loss: 0.0208 - val_mae: 0.1080
# Epoch 44/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0221 - mae: 0.1161
# Epoch 44: val_loss did not improve from 0.01926
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0221 - mae: 0.1161 - val_loss: 0.0208 - val_mae: 0.1087
# Epoch 45/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0214 - mae: 0.1146
# Epoch 45: val_loss improved from 0.01926 to 0.01923, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0214 - mae: 0.1147 - val_loss: 0.0192 - val_mae: 0.1052
# Epoch 46/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0213 - mae: 0.1141
# Epoch 46: val_loss improved from 0.01923 to 0.01819, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0213 - mae: 0.1141 - val_loss: 0.0182 - val_mae: 0.1030
# Epoch 47/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0209 - mae: 0.1126
# Epoch 47: val_loss improved from 0.01819 to 0.01782, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0209 - mae: 0.1127 - val_loss: 0.0178 - val_mae: 0.1039
# Epoch 48/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0208 - mae: 0.1123
# Epoch 48: val_loss improved from 0.01782 to 0.01752, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0207 - mae: 0.1121 - val_loss: 0.0175 - val_mae: 0.1014
# Epoch 49/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0203 - mae: 0.1111
# Epoch 49: val_loss improved from 0.01752 to 0.01641, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0203 - mae: 0.1110 - val_loss: 0.0164 - val_mae: 0.0990
# Epoch 50/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0202 - mae: 0.1119
# Epoch 50: val_loss did not improve from 0.01641
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0202 - mae: 0.1119 - val_loss: 0.0177 - val_mae: 0.1027
# Epoch 51/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0205 - mae: 0.1121
# Epoch 51: val_loss did not improve from 0.01641
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0205 - mae: 0.1123 - val_loss: 0.0180 - val_mae: 0.1073
# Epoch 52/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0199 - mae: 0.1107
# Epoch 52: val_loss did not improve from 0.01641
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0198 - mae: 0.1102 - val_loss: 0.0177 - val_mae: 0.1000
# Epoch 53/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0197 - mae: 0.1099
# Epoch 53: val_loss did not improve from 0.01641
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0197 - mae: 0.1099 - val_loss: 0.0170 - val_mae: 0.1023
# Epoch 54/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0185 - mae: 0.1076
# Epoch 54: val_loss improved from 0.01641 to 0.01488, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0185 - mae: 0.1075 - val_loss: 0.0149 - val_mae: 0.0963
# Epoch 55/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0164 - mae: 0.1004
# Epoch 55: val_loss improved from 0.01488 to 0.01405, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0164 - mae: 0.1005 - val_loss: 0.0141 - val_mae: 0.0904
# Epoch 56/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0164 - mae: 0.0995
# Epoch 56: val_loss did not improve from 0.01405
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0164 - mae: 0.0994 - val_loss: 0.0143 - val_mae: 0.0888
# Epoch 57/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0147 - mae: 0.0939
# Epoch 57: val_loss improved from 0.01405 to 0.01175, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0147 - mae: 0.0939 - val_loss: 0.0117 - val_mae: 0.0827
# Epoch 58/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0149 - mae: 0.0947
# Epoch 58: val_loss improved from 0.01175 to 0.01163, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0149 - mae: 0.0947 - val_loss: 0.0116 - val_mae: 0.0826
# Epoch 59/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0126 - mae: 0.0864
# Epoch 59: val_loss did not improve from 0.01163
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0126 - mae: 0.0864 - val_loss: 0.0122 - val_mae: 0.0858
# Epoch 60/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0122 - mae: 0.0849
# Epoch 60: val_loss improved from 0.01163 to 0.00939, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0121 - mae: 0.0847 - val_loss: 0.0094 - val_mae: 0.0736
# Epoch 61/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0113 - mae: 0.0819
# Epoch 61: val_loss improved from 0.00939 to 0.00876, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0113 - mae: 0.0819 - val_loss: 0.0088 - val_mae: 0.0703
# Epoch 62/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0106 - mae: 0.0792
# Epoch 62: val_loss improved from 0.00876 to 0.00798, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0106 - mae: 0.0792 - val_loss: 0.0080 - val_mae: 0.0662
# Epoch 63/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0098 - mae: 0.0760
# Epoch 63: val_loss improved from 0.00798 to 0.00757, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0098 - mae: 0.0759 - val_loss: 0.0076 - val_mae: 0.0647
# Epoch 64/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0091 - mae: 0.0738
# Epoch 64: val_loss improved from 0.00757 to 0.00685, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0091 - mae: 0.0739 - val_loss: 0.0068 - val_mae: 0.0609
# Epoch 65/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0085 - mae: 0.0712
# Epoch 65: val_loss did not improve from 0.00685
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0085 - mae: 0.0712 - val_loss: 0.0076 - val_mae: 0.0650
# Epoch 66/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0084 - mae: 0.0710
# Epoch 66: val_loss improved from 0.00685 to 0.00662, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0084 - mae: 0.0710 - val_loss: 0.0066 - val_mae: 0.0614
# Epoch 67/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0679
# Epoch 67: val_loss improved from 0.00662 to 0.00600, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0077 - mae: 0.0679 - val_loss: 0.0060 - val_mae: 0.0583
# Epoch 68/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0075 - mae: 0.0670
# Epoch 68: val_loss did not improve from 0.00600
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0075 - mae: 0.0671 - val_loss: 0.0062 - val_mae: 0.0595
# Epoch 69/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0076 - mae: 0.0674
# Epoch 69: val_loss improved from 0.00600 to 0.00570, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0076 - mae: 0.0674 - val_loss: 0.0057 - val_mae: 0.0571
# Epoch 70/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0070 - mae: 0.0648
# Epoch 70: val_loss improved from 0.00570 to 0.00562, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0070 - mae: 0.0649 - val_loss: 0.0056 - val_mae: 0.0560
# Epoch 71/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0069 - mae: 0.0651
# Epoch 71: val_loss did not improve from 0.00562
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0069 - mae: 0.0651 - val_loss: 0.0057 - val_mae: 0.0559
# Epoch 72/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0629
# Epoch 72: val_loss improved from 0.00562 to 0.00557, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0066 - mae: 0.0630 - val_loss: 0.0056 - val_mae: 0.0570
# Epoch 73/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0070 - mae: 0.0652
# Epoch 73: val_loss improved from 0.00557 to 0.00544, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0070 - mae: 0.0653 - val_loss: 0.0054 - val_mae: 0.0558
# Epoch 74/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0065 - mae: 0.0629
# Epoch 74: val_loss improved from 0.00544 to 0.00486, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0065 - mae: 0.0629 - val_loss: 0.0049 - val_mae: 0.0526
# Epoch 75/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0063 - mae: 0.0617
# Epoch 75: val_loss did not improve from 0.00486
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0063 - mae: 0.0617 - val_loss: 0.0049 - val_mae: 0.0532
# Epoch 76/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0060 - mae: 0.0607
# Epoch 76: val_loss improved from 0.00486 to 0.00456, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0060 - mae: 0.0607 - val_loss: 0.0046 - val_mae: 0.0508
# Epoch 77/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0060 - mae: 0.0603
# Epoch 77: val_loss did not improve from 0.00456
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0059 - mae: 0.0602 - val_loss: 0.0049 - val_mae: 0.0541
# Epoch 78/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0060 - mae: 0.0605
# Epoch 78: val_loss improved from 0.00456 to 0.00444, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0060 - mae: 0.0605 - val_loss: 0.0044 - val_mae: 0.0506
# Epoch 79/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0057 - mae: 0.0591
# Epoch 79: val_loss did not improve from 0.00444
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0057 - mae: 0.0591 - val_loss: 0.0046 - val_mae: 0.0516
# Epoch 80/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0059 - mae: 0.0598
# Epoch 80: val_loss improved from 0.00444 to 0.00433, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0059 - mae: 0.0598 - val_loss: 0.0043 - val_mae: 0.0497
# Epoch 81/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0056 - mae: 0.0583
# Epoch 81: val_loss did not improve from 0.00433
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0056 - mae: 0.0583 - val_loss: 0.0045 - val_mae: 0.0504
# Epoch 82/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0587
# Epoch 82: val_loss did not improve from 0.00433
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0057 - mae: 0.0587 - val_loss: 0.0045 - val_mae: 0.0511
# Epoch 83/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0056 - mae: 0.0584
# Epoch 83: val_loss did not improve from 0.00433
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0056 - mae: 0.0584 - val_loss: 0.0045 - val_mae: 0.0515
# Epoch 84/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0056 - mae: 0.0584
# Epoch 84: val_loss improved from 0.00433 to 0.00411, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0056 - mae: 0.0583 - val_loss: 0.0041 - val_mae: 0.0487
# Epoch 85/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0053 - mae: 0.0569
# Epoch 85: val_loss did not improve from 0.00411
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0053 - mae: 0.0569 - val_loss: 0.0042 - val_mae: 0.0498
# Epoch 86/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0051 - mae: 0.0561
# Epoch 86: val_loss improved from 0.00411 to 0.00396, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0051 - mae: 0.0561 - val_loss: 0.0040 - val_mae: 0.0475
# Epoch 87/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0052 - mae: 0.0561
# Epoch 87: val_loss did not improve from 0.00396
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0052 - mae: 0.0562 - val_loss: 0.0041 - val_mae: 0.0489
# Epoch 88/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0053 - mae: 0.0566
# Epoch 88: val_loss did not improve from 0.00396
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0053 - mae: 0.0566 - val_loss: 0.0042 - val_mae: 0.0493
# Epoch 89/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0052 - mae: 0.0560
# Epoch 89: val_loss did not improve from 0.00396
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0052 - mae: 0.0560 - val_loss: 0.0040 - val_mae: 0.0477
# Epoch 90/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0051 - mae: 0.0555
# Epoch 90: val_loss did not improve from 0.00396
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0051 - mae: 0.0555 - val_loss: 0.0040 - val_mae: 0.0476
# Epoch 91/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0050 - mae: 0.0555
# Epoch 91: val_loss did not improve from 0.00396
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0050 - mae: 0.0555 - val_loss: 0.0041 - val_mae: 0.0490
# Epoch 92/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0048 - mae: 0.0543
# Epoch 92: val_loss did not improve from 0.00396
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0543 - val_loss: 0.0040 - val_mae: 0.0484
# Epoch 93/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0050 - mae: 0.0551
# Epoch 93: val_loss improved from 0.00396 to 0.00380, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0050 - mae: 0.0550 - val_loss: 0.0038 - val_mae: 0.0467
# Epoch 94/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0548
# Epoch 94: val_loss improved from 0.00380 to 0.00376, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0049 - mae: 0.0548 - val_loss: 0.0038 - val_mae: 0.0462
# Epoch 95/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0048 - mae: 0.0541
# Epoch 95: val_loss improved from 0.00376 to 0.00369, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0048 - mae: 0.0541 - val_loss: 0.0037 - val_mae: 0.0466
# Epoch 96/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0047 - mae: 0.0536
# Epoch 96: val_loss improved from 0.00369 to 0.00363, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0047 - mae: 0.0536 - val_loss: 0.0036 - val_mae: 0.0460
# Epoch 97/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0046 - mae: 0.0529
# Epoch 97: val_loss improved from 0.00363 to 0.00354, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0047 - mae: 0.0531 - val_loss: 0.0035 - val_mae: 0.0456
# Epoch 98/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0048 - mae: 0.0538
# Epoch 98: val_loss improved from 0.00354 to 0.00350, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0048 - mae: 0.0538 - val_loss: 0.0035 - val_mae: 0.0445
# Epoch 99/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0046 - mae: 0.0528
# Epoch 99: val_loss did not improve from 0.00350
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0046 - mae: 0.0528 - val_loss: 0.0035 - val_mae: 0.0453
# Epoch 100/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0045 - mae: 0.0522
# Epoch 100: val_loss did not improve from 0.00350
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0045 - mae: 0.0521 - val_loss: 0.0035 - val_mae: 0.0458
# Epoch 101/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0044 - mae: 0.0520
# Epoch 101: val_loss improved from 0.00350 to 0.00341, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0045 - mae: 0.0521 - val_loss: 0.0034 - val_mae: 0.0442
# Epoch 102/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0043 - mae: 0.0512
# Epoch 102: val_loss improved from 0.00341 to 0.00332, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0043 - mae: 0.0512 - val_loss: 0.0033 - val_mae: 0.0434
# Epoch 103/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0045 - mae: 0.0521
# Epoch 103: val_loss improved from 0.00332 to 0.00330, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0045 - mae: 0.0520 - val_loss: 0.0033 - val_mae: 0.0436
# Epoch 104/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0045 - mae: 0.0522
# Epoch 104: val_loss did not improve from 0.00330
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0045 - mae: 0.0521 - val_loss: 0.0034 - val_mae: 0.0437
# Epoch 105/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0043 - mae: 0.0510
# Epoch 105: val_loss improved from 0.00330 to 0.00314, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0043 - mae: 0.0511 - val_loss: 0.0031 - val_mae: 0.0422
# Epoch 106/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0042 - mae: 0.0505
# Epoch 106: val_loss improved from 0.00314 to 0.00312, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0042 - mae: 0.0506 - val_loss: 0.0031 - val_mae: 0.0423
# Epoch 107/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0041 - mae: 0.0498
# Epoch 107: val_loss did not improve from 0.00312
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0041 - mae: 0.0497 - val_loss: 0.0033 - val_mae: 0.0437
# Epoch 108/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0041 - mae: 0.0499
# Epoch 108: val_loss improved from 0.00312 to 0.00306, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0041 - mae: 0.0499 - val_loss: 0.0031 - val_mae: 0.0421
# Epoch 109/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0493
# Epoch 109: val_loss did not improve from 0.00306
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0493 - val_loss: 0.0031 - val_mae: 0.0421
# Epoch 110/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - mae: 0.0503
# Epoch 110: val_loss did not improve from 0.00306
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0503 - val_loss: 0.0032 - val_mae: 0.0429
# Epoch 111/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0039 - mae: 0.0486
# Epoch 111: val_loss improved from 0.00306 to 0.00299, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0039 - mae: 0.0486 - val_loss: 0.0030 - val_mae: 0.0413
# Epoch 112/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0039 - mae: 0.0486
# Epoch 112: val_loss improved from 0.00299 to 0.00297, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0039 - mae: 0.0486 - val_loss: 0.0030 - val_mae: 0.0409
# Epoch 113/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0039 - mae: 0.0488
# Epoch 113: val_loss did not improve from 0.00297
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0040 - mae: 0.0489 - val_loss: 0.0031 - val_mae: 0.0420
# Epoch 114/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0490
# Epoch 114: val_loss improved from 0.00297 to 0.00291, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0040 - mae: 0.0490 - val_loss: 0.0029 - val_mae: 0.0408
# Epoch 115/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0039 - mae: 0.0486
# Epoch 115: val_loss did not improve from 0.00291
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0039 - mae: 0.0486 - val_loss: 0.0031 - val_mae: 0.0419
# Epoch 116/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0491
# Epoch 116: val_loss did not improve from 0.00291
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0040 - mae: 0.0491 - val_loss: 0.0031 - val_mae: 0.0425
# Epoch 117/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0039 - mae: 0.0483
# Epoch 117: val_loss improved from 0.00291 to 0.00287, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0039 - mae: 0.0484 - val_loss: 0.0029 - val_mae: 0.0401
# Epoch 118/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0475
# Epoch 118: val_loss improved from 0.00287 to 0.00277, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0038 - mae: 0.0475 - val_loss: 0.0028 - val_mae: 0.0395
# Epoch 119/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0037 - mae: 0.0473
# Epoch 119: val_loss did not improve from 0.00277
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0037 - mae: 0.0474 - val_loss: 0.0028 - val_mae: 0.0400
# Epoch 120/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0475
# Epoch 120: val_loss did not improve from 0.00277
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0038 - mae: 0.0475 - val_loss: 0.0028 - val_mae: 0.0398
# Epoch 121/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0036 - mae: 0.0464
# Epoch 121: val_loss improved from 0.00277 to 0.00268, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0036 - mae: 0.0465 - val_loss: 0.0027 - val_mae: 0.0387
# Epoch 122/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0465
# Epoch 122: val_loss did not improve from 0.00268
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0465 - val_loss: 0.0028 - val_mae: 0.0391
# Epoch 123/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0458
# Epoch 123: val_loss improved from 0.00268 to 0.00263, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0035 - mae: 0.0458 - val_loss: 0.0026 - val_mae: 0.0379
# Epoch 124/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0462
# Epoch 124: val_loss did not improve from 0.00263
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0462 - val_loss: 0.0027 - val_mae: 0.0383
# Epoch 125/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0464
# Epoch 125: val_loss did not improve from 0.00263
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0464 - val_loss: 0.0027 - val_mae: 0.0389
# Epoch 126/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0461
# Epoch 126: val_loss improved from 0.00263 to 0.00254, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0036 - mae: 0.0461 - val_loss: 0.0025 - val_mae: 0.0377
# Epoch 127/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0462
# Epoch 127: val_loss did not improve from 0.00254
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0461 - val_loss: 0.0027 - val_mae: 0.0389
# Epoch 128/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0457
# Epoch 128: val_loss did not improve from 0.00254
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0456 - val_loss: 0.0026 - val_mae: 0.0378
# Epoch 129/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0461
# Epoch 129: val_loss did not improve from 0.00254
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0036 - mae: 0.0461 - val_loss: 0.0026 - val_mae: 0.0375
# Epoch 130/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0035 - mae: 0.0453
# Epoch 130: val_loss did not improve from 0.00254
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0453 - val_loss: 0.0026 - val_mae: 0.0377
# Epoch 131/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0451
# Epoch 131: val_loss did not improve from 0.00254
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0451 - val_loss: 0.0026 - val_mae: 0.0378
# Epoch 132/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0452
# Epoch 132: val_loss did not improve from 0.00254
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0452 - val_loss: 0.0027 - val_mae: 0.0391
# Epoch 133/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0447
# Epoch 133: val_loss did not improve from 0.00254
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0446 - val_loss: 0.0028 - val_mae: 0.0394
# Epoch 134/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0449
# Epoch 134: val_loss did not improve from 0.00254
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0034 - mae: 0.0448 - val_loss: 0.0026 - val_mae: 0.0380
# Epoch 135/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0442
# Epoch 135: val_loss improved from 0.00254 to 0.00252, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0033 - mae: 0.0442 - val_loss: 0.0025 - val_mae: 0.0373
# Epoch 136/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0440
# Epoch 136: val_loss did not improve from 0.00252
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0440 - val_loss: 0.0025 - val_mae: 0.0379
# Epoch 137/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0440
# Epoch 137: val_loss improved from 0.00252 to 0.00250, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0033 - mae: 0.0439 - val_loss: 0.0025 - val_mae: 0.0377
# Epoch 138/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0435
# Epoch 138: val_loss improved from 0.00250 to 0.00248, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0032 - mae: 0.0436 - val_loss: 0.0025 - val_mae: 0.0370
# Epoch 139/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0439
# Epoch 139: val_loss did not improve from 0.00248
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0439 - val_loss: 0.0025 - val_mae: 0.0377
# Epoch 140/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0443
# Epoch 140: val_loss improved from 0.00248 to 0.00245, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0025 - val_mae: 0.0371
# Epoch 141/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0031 - mae: 0.0430
# Epoch 141: val_loss improved from 0.00245 to 0.00241, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0031 - mae: 0.0430 - val_loss: 0.0024 - val_mae: 0.0366
# Epoch 142/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - mae: 0.0432
# Epoch 142: val_loss did not improve from 0.00241
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0432 - val_loss: 0.0024 - val_mae: 0.0365
# Epoch 143/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0432
# Epoch 143: val_loss did not improve from 0.00241
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0432 - val_loss: 0.0026 - val_mae: 0.0380
# Epoch 144/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0432
# Epoch 144: val_loss improved from 0.00241 to 0.00232, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0032 - mae: 0.0432 - val_loss: 0.0023 - val_mae: 0.0359
# Epoch 145/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0437
# Epoch 145: val_loss did not improve from 0.00232
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0436 - val_loss: 0.0024 - val_mae: 0.0365
# Epoch 146/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0433
# Epoch 146: val_loss did not improve from 0.00232
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0433 - val_loss: 0.0024 - val_mae: 0.0362
# Epoch 147/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0031 - mae: 0.0424
# Epoch 147: val_loss improved from 0.00232 to 0.00226, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0031 - mae: 0.0425 - val_loss: 0.0023 - val_mae: 0.0354
# Epoch 148/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0432
# Epoch 148: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0433 - val_loss: 0.0024 - val_mae: 0.0362
# Epoch 149/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0030 - mae: 0.0420
# Epoch 149: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0030 - mae: 0.0420 - val_loss: 0.0027 - val_mae: 0.0384
# Epoch 150/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0429
# Epoch 150: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0430 - val_loss: 0.0025 - val_mae: 0.0375
# Epoch 151/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0435
# Epoch 151: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0434 - val_loss: 0.0024 - val_mae: 0.0364
# Epoch 152/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - mae: 0.0429
# Epoch 152: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0023 - val_mae: 0.0357
# Epoch 153/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0031 - mae: 0.0423
# Epoch 153: val_loss improved from 0.00226 to 0.00225, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0031 - mae: 0.0424 - val_loss: 0.0023 - val_mae: 0.0352
# Epoch 154/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0421
# Epoch 154: val_loss did not improve from 0.00225
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0031 - mae: 0.0422 - val_loss: 0.0023 - val_mae: 0.0357
# Epoch 155/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0031 - mae: 0.0422
# Epoch 155: val_loss did not improve from 0.00225
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0031 - mae: 0.0422 - val_loss: 0.0024 - val_mae: 0.0360
# Epoch 156/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0421
# Epoch 156: val_loss improved from 0.00225 to 0.00220, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0030 - mae: 0.0420 - val_loss: 0.0022 - val_mae: 0.0351
# Epoch 157/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0030 - mae: 0.0416
# Epoch 157: val_loss did not improve from 0.00220
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0030 - mae: 0.0417 - val_loss: 0.0022 - val_mae: 0.0352
# Epoch 158/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0416
# Epoch 158: val_loss did not improve from 0.00220
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0030 - mae: 0.0416 - val_loss: 0.0023 - val_mae: 0.0358
# Epoch 159/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0419
# Epoch 159: val_loss did not improve from 0.00220
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0030 - mae: 0.0420 - val_loss: 0.0023 - val_mae: 0.0359
# Epoch 160/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0029 - mae: 0.0413
# Epoch 160: val_loss did not improve from 0.00220
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0029 - mae: 0.0413 - val_loss: 0.0022 - val_mae: 0.0349
# Epoch 161/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0418
# Epoch 161: val_loss did not improve from 0.00220
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0030 - mae: 0.0417 - val_loss: 0.0023 - val_mae: 0.0358
# Epoch 162/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0029 - mae: 0.0414
# Epoch 162: val_loss did not improve from 0.00220
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0029 - mae: 0.0414 - val_loss: 0.0023 - val_mae: 0.0361
# Epoch 163/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0420
# Epoch 163: val_loss improved from 0.00220 to 0.00220, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0030 - mae: 0.0419 - val_loss: 0.0022 - val_mae: 0.0349
# Epoch 164/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0029 - mae: 0.0409
# Epoch 164: val_loss did not improve from 0.00220
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0029 - mae: 0.0410 - val_loss: 0.0022 - val_mae: 0.0350
# Epoch 165/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0030 - mae: 0.0418
# Epoch 165: val_loss improved from 0.00220 to 0.00215, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0030 - mae: 0.0418 - val_loss: 0.0022 - val_mae: 0.0347
# Epoch 166/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0029 - mae: 0.0415
# Epoch 166: val_loss did not improve from 0.00215
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0029 - mae: 0.0415 - val_loss: 0.0022 - val_mae: 0.0347
# Epoch 167/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0029 - mae: 0.0412
# Epoch 167: val_loss did not improve from 0.00215
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0023 - val_mae: 0.0348
# Epoch 168/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0028 - mae: 0.0405
# Epoch 168: val_loss improved from 0.00215 to 0.00206, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0028 - mae: 0.0405 - val_loss: 0.0021 - val_mae: 0.0336
# Epoch 169/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0028 - mae: 0.0406
# Epoch 169: val_loss did not improve from 0.00206
# ...
# Epoch 442: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0329 - val_loss: 9.5789e-04 - val_mae: 0.0233
# Epoch 443/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0331
# Epoch 443: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 0.0011 - val_mae: 0.0242
# Epoch 444/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0018 - mae: 0.0327
# Epoch 444: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 9.1010e-04 - val_mae: 0.0224
# Epoch 445/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0328
# Epoch 445: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0328 - val_loss: 9.7746e-04 - val_mae: 0.0233
# Epoch 446/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0326
# Epoch 446: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0327 - val_loss: 9.4208e-04 - val_mae: 0.0230
# Epoch 447/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0327
# Epoch 447: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0327 - val_loss: 0.0010 - val_mae: 0.0239
# Epoch 448/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0018 - mae: 0.0326
# Epoch 448: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0325 - val_loss: 9.1718e-04 - val_mae: 0.0224
# Epoch 449/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0329
# Epoch 449: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0019 - mae: 0.0329 - val_loss: 9.4969e-04 - val_mae: 0.0231
# Epoch 450/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0326
# Epoch 450: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0326 - val_loss: 9.5241e-04 - val_mae: 0.0232
# Epoch 451/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0325
# Epoch 451: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0325 - val_loss: 9.0449e-04 - val_mae: 0.0225
# Epoch 452/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0331
# Epoch 452: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 9.2737e-04 - val_mae: 0.0230
# Epoch 453/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0331
# Epoch 453: val_loss did not improve from 0.00090
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 9.5286e-04 - val_mae: 0.0235
# Epoch 454/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0326
# Epoch 454: val_loss improved from 0.00090 to 0.00090, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0019 - mae: 0.0326 - val_loss: 8.9725e-04 - val_mae: 0.0227
# Epoch 455/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0325
# Epoch 455: val_loss improved from 0.00090 to 0.00088, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0019 - mae: 0.0325 - val_loss: 8.7750e-04 - val_mae: 0.0221
# Epoch 456/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0333
# Epoch 456: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0333 - val_loss: 8.7992e-04 - val_mae: 0.0224
# Epoch 457/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0331
# Epoch 457: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 9.1165e-04 - val_mae: 0.0226
# Epoch 458/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0324
# Epoch 458: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0324 - val_loss: 9.1418e-04 - val_mae: 0.0229
# Epoch 459/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0321
# Epoch 459: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0322 - val_loss: 9.0858e-04 - val_mae: 0.0224
# Epoch 460/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0019 - mae: 0.0331
# Epoch 460: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 9.3947e-04 - val_mae: 0.0230
# Epoch 461/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0320
# Epoch 461: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0320 - val_loss: 8.8440e-04 - val_mae: 0.0225
# Epoch 462/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0325
# Epoch 462: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0325 - val_loss: 9.3941e-04 - val_mae: 0.0231
# Epoch 463/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0326
# Epoch 463: val_loss improved from 0.00088 to 0.00088, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0326 - val_loss: 8.7688e-04 - val_mae: 0.0225
# Epoch 464/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0019 - mae: 0.0331
# Epoch 464: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0330 - val_loss: 9.6413e-04 - val_mae: 0.0236
# Epoch 465/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0324
# Epoch 465: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0324 - val_loss: 8.9539e-04 - val_mae: 0.0225
# Epoch 466/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0330
# Epoch 466: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0330 - val_loss: 9.0635e-04 - val_mae: 0.0227
# Epoch 467/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0326
# Epoch 467: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0326 - val_loss: 8.8471e-04 - val_mae: 0.0224
# Epoch 468/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0325
# Epoch 468: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0324 - val_loss: 9.7398e-04 - val_mae: 0.0230
# Epoch 469/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0322
# Epoch 469: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0322 - val_loss: 9.1638e-04 - val_mae: 0.0224
# Epoch 470/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0323
# Epoch 470: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0323 - val_loss: 8.7923e-04 - val_mae: 0.0222
# Epoch 471/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0321
# Epoch 471: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0321 - val_loss: 9.3823e-04 - val_mae: 0.0228
# Epoch 472/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0318
# Epoch 472: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0318 - val_loss: 8.9471e-04 - val_mae: 0.0223
# Epoch 473/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0019 - mae: 0.0324
# Epoch 473: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0322 - val_loss: 9.3125e-04 - val_mae: 0.0228
# Epoch 474/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0324
# Epoch 474: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0324 - val_loss: 9.9493e-04 - val_mae: 0.0235
# Epoch 475/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0320
# Epoch 475: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0320 - val_loss: 8.8378e-04 - val_mae: 0.0222
# Epoch 476/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0325
# Epoch 476: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0325 - val_loss: 9.0548e-04 - val_mae: 0.0226
# Epoch 477/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0323
# Epoch 477: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0323 - val_loss: 9.7200e-04 - val_mae: 0.0232
# Epoch 478/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0019 - mae: 0.0324
# Epoch 478: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0324 - val_loss: 9.6400e-04 - val_mae: 0.0234
# Epoch 479/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0324
# Epoch 479: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0324 - val_loss: 9.8047e-04 - val_mae: 0.0236
# Epoch 480/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0322
# Epoch 480: val_loss did not improve from 0.00088
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0322 - val_loss: 9.3490e-04 - val_mae: 0.0228
# Epoch 481/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0325
# Epoch 481: val_loss improved from 0.00088 to 0.00087, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0325 - val_loss: 8.6948e-04 - val_mae: 0.0222
# Epoch 482/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0019 - mae: 0.0331
# Epoch 482: val_loss did not improve from 0.00087
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 9.5626e-04 - val_mae: 0.0233
# Epoch 483/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0332
# Epoch 483: val_loss improved from 0.00087 to 0.00083, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0019 - mae: 0.0332 - val_loss: 8.3306e-04 - val_mae: 0.0219
# Epoch 484/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0321
# Epoch 484: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0321 - val_loss: 8.9076e-04 - val_mae: 0.0226
# Epoch 485/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0331
# Epoch 485: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 9.8039e-04 - val_mae: 0.0230
# Epoch 486/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0322
# Epoch 486: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0322 - val_loss: 8.9864e-04 - val_mae: 0.0224
# Epoch 487/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0328
# Epoch 487: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0328 - val_loss: 8.7051e-04 - val_mae: 0.0223
# Epoch 488/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0019 - mae: 0.0329
# Epoch 488: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0328 - val_loss: 9.7174e-04 - val_mae: 0.0233
# Epoch 489/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0322
# Epoch 489: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0322 - val_loss: 9.1909e-04 - val_mae: 0.0227
# Epoch 490/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0328
# Epoch 490: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0328 - val_loss: 9.1289e-04 - val_mae: 0.0229
# Epoch 491/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0322
# Epoch 491: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0322 - val_loss: 9.2181e-04 - val_mae: 0.0226
# Epoch 492/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0328
# Epoch 492: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0328 - val_loss: 9.2582e-04 - val_mae: 0.0228
# Epoch 493/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0019 - mae: 0.0323
# Epoch 493: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0324 - val_loss: 8.6222e-04 - val_mae: 0.0218
# Epoch 494/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0322
# Epoch 494: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0322 - val_loss: 8.7955e-04 - val_mae: 0.0226
# Epoch 495/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0324
# Epoch 495: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0018 - mae: 0.0325 - val_loss: 9.0077e-04 - val_mae: 0.0223
# Epoch 496/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0019 - mae: 0.0329
# Epoch 496: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0328 - val_loss: 9.1898e-04 - val_mae: 0.0224
# Epoch 497/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0019 - mae: 0.0328
# Epoch 497: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0328 - val_loss: 9.9951e-04 - val_mae: 0.0238
# Epoch 498/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0018 - mae: 0.0320
# Epoch 498: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0320 - val_loss: 8.8055e-04 - val_mae: 0.0223
# Epoch 499/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0019 - mae: 0.0330
# Epoch 499: val_loss did not improve from 0.00083
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0019 - mae: 0.0330 - val_loss: 9.6822e-04 - val_mae: 0.0231
# Epoch 500/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0321
# Epoch 500: val_loss improved from 0.00083 to 0.00083, saving model to Model\predictiveAnalysisWeather_H.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018 - mae: 0.0321 - val_loss: 8.2882e-04 - val_mae: 0.0217
# ✅ MSDL model for Humidity saved to: Model\predictiveAnalysisWeather_H.h5

# %%
# ===========================================================
# Part 2.C: Train & Save MSDL Model for Wind Forecasting
# ===========================================================

# --- Prepare training data (pre-windowed) ---
X = datasets["Wind_km_h"]["X"]   # shape = [N, 112, 1], input sequences
y = datasets["Wind_km_h"]["y"]   # shape = [N, 24],     forecast targets

# --- 4× replication (no augmentation) ---
X = np.concatenate([X, X, X, X], axis=0)
y = np.concatenate([y, y, y, y], axis=0)

# (recommended) shuffle to avoid repeated blocks in order
idx = np.random.permutation(len(X))
X, y = X[idx], y[idx]

# --- Reproducibility (optional) ---
np.random.seed(42)
tf.random.set_seed(42)

# --- HARD RESET: clear any existing graph/weights, free memory ---
tf.keras.backend.clear_session()
try:
    del model
except NameError:
    pass
gc.collect()

# --- Fresh model ---
model = build_MSDL(input_len=X.shape[1], out_len=y.shape[1], n_features=X.shape[2])


# --- Define output directory and model save path ---
out_dir = Path("Model")
out_dir.mkdir(parents=True, exist_ok=True)
model_path = out_dir / "predictiveAnalysisWeather_W.h5"

# --- Configure callbacks ---
early_stop = EarlyStopping(
    monitor="val_loss",          # monitor validation loss
    patience=20,                 # stop if no improvement for 20 epochs
    restore_best_weights=True    # restore weights from best epoch
)

checkpoint = ModelCheckpoint(
    filepath=model_path,         # save path for the best model
    monitor="val_loss",          # criterion for saving
    save_best_only=True,         # overwrite only if val_loss improves
    verbose=1                    # log when model is saved
)


# --- Train the MSDL model ---
history = model.fit(
    X, y,
    epochs=500,                  # maximum epochs (may stop earlier via EarlyStopping)
    batch_size=16,               # training batch size
    validation_split=0.1,        # reserve 10% for validation
    verbose=1,                   # print training progress
    callbacks=[early_stop, checkpoint]
)

# --- Save the final (best) model explicitly ---
model.save(model_path)
print(f"✅ MSDL model for Wind saved to: {model_path}")
# Out:
# Epoch 1/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0579 - mae: 0.1854
# Epoch 1: val_loss improved from inf to 0.04279, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 3s 31ms/step - loss: 0.0568 - mae: 0.1834 - val_loss: 0.0428 - val_mae: 0.1590
# Epoch 2/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0440 - mae: 0.1648
# Epoch 2: val_loss improved from 0.04279 to 0.04154, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0440 - mae: 0.1646 - val_loss: 0.0415 - val_mae: 0.1529
# Epoch 3/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0418 - mae: 0.1606
# Epoch 3: val_loss improved from 0.04154 to 0.03916, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0417 - mae: 0.1603 - val_loss: 0.0392 - val_mae: 0.1568
# Epoch 4/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0392 - mae: 0.1566
# Epoch 4: val_loss improved from 0.03916 to 0.03816, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0391 - mae: 0.1564 - val_loss: 0.0382 - val_mae: 0.1565
# Epoch 5/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0376 - mae: 0.1533
# Epoch 5: val_loss improved from 0.03816 to 0.03715, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0377 - mae: 0.1536 - val_loss: 0.0372 - val_mae: 0.1539
# Epoch 6/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0379 - mae: 0.1543
# Epoch 6: val_loss improved from 0.03715 to 0.03664, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0378 - mae: 0.1540 - val_loss: 0.0366 - val_mae: 0.1522
# Epoch 7/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0371 - mae: 0.1523
# Epoch 7: val_loss did not improve from 0.03664
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0371 - mae: 0.1524 - val_loss: 0.0380 - val_mae: 0.1609
# Epoch 8/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0366 - mae: 0.1517
# Epoch 8: val_loss improved from 0.03664 to 0.03593, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0366 - mae: 0.1517 - val_loss: 0.0359 - val_mae: 0.1538
# Epoch 9/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0368 - mae: 0.1514
# Epoch 9: val_loss did not improve from 0.03593
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0367 - mae: 0.1514 - val_loss: 0.0386 - val_mae: 0.1594
# Epoch 10/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0363 - mae: 0.1500
# Epoch 10: val_loss improved from 0.03593 to 0.03484, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0363 - mae: 0.1501 - val_loss: 0.0348 - val_mae: 0.1499
# Epoch 11/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0316 - mae: 0.1412
# Epoch 11: val_loss improved from 0.03484 to 0.02859, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0315 - mae: 0.1410 - val_loss: 0.0286 - val_mae: 0.1334
# Epoch 12/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0274 - mae: 0.1315
# Epoch 12: val_loss improved from 0.02859 to 0.02343, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0275 - mae: 0.1316 - val_loss: 0.0234 - val_mae: 0.1223
# Epoch 13/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0204 - mae: 0.1137
# Epoch 13: val_loss improved from 0.02343 to 0.01735, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 17ms/step - loss: 0.0204 - mae: 0.1136 - val_loss: 0.0174 - val_mae: 0.1051
# Epoch 14/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0182 - mae: 0.1068
# Epoch 14: val_loss improved from 0.01735 to 0.01516, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0182 - mae: 0.1067 - val_loss: 0.0152 - val_mae: 0.0974
# Epoch 15/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0169 - mae: 0.1027
# Epoch 15: val_loss improved from 0.01516 to 0.01483, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 17ms/step - loss: 0.0168 - mae: 0.1026 - val_loss: 0.0148 - val_mae: 0.0979
# Epoch 16/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0159 - mae: 0.0992
# Epoch 16: val_loss improved from 0.01483 to 0.01454, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0159 - mae: 0.0992 - val_loss: 0.0145 - val_mae: 0.0967
# Epoch 17/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0156 - mae: 0.0986
# Epoch 17: val_loss improved from 0.01454 to 0.01291, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0156 - mae: 0.0985 - val_loss: 0.0129 - val_mae: 0.0900
# Epoch 18/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0146 - mae: 0.0954
# Epoch 18: val_loss improved from 0.01291 to 0.01233, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0146 - mae: 0.0953 - val_loss: 0.0123 - val_mae: 0.0876
# Epoch 19/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0143 - mae: 0.0943
# Epoch 19: val_loss improved from 0.01233 to 0.01200, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0143 - mae: 0.0944 - val_loss: 0.0120 - val_mae: 0.0857
# Epoch 20/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0134 - mae: 0.0913
# Epoch 20: val_loss improved from 0.01200 to 0.01153, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0135 - mae: 0.0913 - val_loss: 0.0115 - val_mae: 0.0839
# Epoch 21/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0141 - mae: 0.0933
# Epoch 21: val_loss did not improve from 0.01153
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0141 - mae: 0.0933 - val_loss: 0.0118 - val_mae: 0.0867
# Epoch 22/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0131 - mae: 0.0901
# Epoch 22: val_loss improved from 0.01153 to 0.01109, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0131 - mae: 0.0902 - val_loss: 0.0111 - val_mae: 0.0830
# Epoch 23/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0128 - mae: 0.0889
# Epoch 23: val_loss improved from 0.01109 to 0.01089, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0128 - mae: 0.0889 - val_loss: 0.0109 - val_mae: 0.0814
# Epoch 24/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0127 - mae: 0.0888
# Epoch 24: val_loss did not improve from 0.01089
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0127 - mae: 0.0887 - val_loss: 0.0117 - val_mae: 0.0844
# Epoch 25/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0126 - mae: 0.0878
# Epoch 25: val_loss did not improve from 0.01089
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0125 - mae: 0.0878 - val_loss: 0.0112 - val_mae: 0.0835
# Epoch 26/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0121 - mae: 0.0865
# Epoch 26: val_loss did not improve from 0.01089
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0121 - mae: 0.0864 - val_loss: 0.0111 - val_mae: 0.0820
# Epoch 27/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0120 - mae: 0.0861
# Epoch 27: val_loss improved from 0.01089 to 0.01014, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0120 - mae: 0.0861 - val_loss: 0.0101 - val_mae: 0.0786
# Epoch 28/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0117 - mae: 0.0848
# Epoch 28: val_loss improved from 0.01014 to 0.01008, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0117 - mae: 0.0848 - val_loss: 0.0101 - val_mae: 0.0785
# Epoch 29/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0117 - mae: 0.0843
# Epoch 29: val_loss improved from 0.01008 to 0.00987, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 17ms/step - loss: 0.0117 - mae: 0.0844 - val_loss: 0.0099 - val_mae: 0.0769
# Epoch 30/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0117 - mae: 0.0845
# Epoch 30: val_loss improved from 0.00987 to 0.00974, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0116 - mae: 0.0844 - val_loss: 0.0097 - val_mae: 0.0769
# Epoch 31/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0114 - mae: 0.0834
# Epoch 31: val_loss did not improve from 0.00974
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0113 - mae: 0.0833 - val_loss: 0.0099 - val_mae: 0.0771
# Epoch 32/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0109 - mae: 0.0815
# Epoch 32: val_loss improved from 0.00974 to 0.00951, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0109 - mae: 0.0815 - val_loss: 0.0095 - val_mae: 0.0760
# Epoch 33/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0108 - mae: 0.0813
# Epoch 33: val_loss did not improve from 0.00951
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0108 - mae: 0.0813 - val_loss: 0.0098 - val_mae: 0.0762
# Epoch 34/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0105 - mae: 0.0797
# Epoch 34: val_loss improved from 0.00951 to 0.00888, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0105 - mae: 0.0798 - val_loss: 0.0089 - val_mae: 0.0728
# Epoch 35/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0784
# Epoch 35: val_loss did not improve from 0.00888
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0101 - mae: 0.0784 - val_loss: 0.0095 - val_mae: 0.0754
# Epoch 36/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0101 - mae: 0.0785
# Epoch 36: val_loss did not improve from 0.00888
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0101 - mae: 0.0785 - val_loss: 0.0090 - val_mae: 0.0729
# Epoch 37/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0100 - mae: 0.0779
# Epoch 37: val_loss improved from 0.00888 to 0.00821, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0100 - mae: 0.0778 - val_loss: 0.0082 - val_mae: 0.0700
# Epoch 38/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0093 - mae: 0.0753
# Epoch 38: val_loss did not improve from 0.00821
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0093 - mae: 0.0753 - val_loss: 0.0085 - val_mae: 0.0712
# Epoch 39/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0092 - mae: 0.0748
# Epoch 39: val_loss improved from 0.00821 to 0.00779, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0092 - mae: 0.0748 - val_loss: 0.0078 - val_mae: 0.0682
# Epoch 40/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0091 - mae: 0.0740
# Epoch 40: val_loss did not improve from 0.00779
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0090 - mae: 0.0739 - val_loss: 0.0081 - val_mae: 0.0686
# Epoch 41/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0086 - mae: 0.0719
# Epoch 41: val_loss improved from 0.00779 to 0.00704, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0086 - mae: 0.0720 - val_loss: 0.0070 - val_mae: 0.0645
# Epoch 42/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0083 - mae: 0.0705
# Epoch 42: val_loss did not improve from 0.00704
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0082 - mae: 0.0705 - val_loss: 0.0074 - val_mae: 0.0660
# Epoch 43/500
# 57/62 [==========================>...] - ETA: 0s - loss: 0.0084 - mae: 0.0713
# Epoch 43: val_loss improved from 0.00704 to 0.00675, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0084 - mae: 0.0710 - val_loss: 0.0068 - val_mae: 0.0630
# Epoch 44/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0081 - mae: 0.0696
# Epoch 44: val_loss improved from 0.00675 to 0.00662, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0081 - mae: 0.0696 - val_loss: 0.0066 - val_mae: 0.0621
# Epoch 45/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0080 - mae: 0.0692
# Epoch 45: val_loss did not improve from 0.00662
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0080 - mae: 0.0693 - val_loss: 0.0067 - val_mae: 0.0624
# Epoch 46/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0078 - mae: 0.0682
# Epoch 46: val_loss improved from 0.00662 to 0.00638, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0078 - mae: 0.0684 - val_loss: 0.0064 - val_mae: 0.0616
# Epoch 47/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0077 - mae: 0.0679
# Epoch 47: val_loss did not improve from 0.00638
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0077 - mae: 0.0679 - val_loss: 0.0064 - val_mae: 0.0613
# Epoch 48/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0074 - mae: 0.0667
# Epoch 48: val_loss improved from 0.00638 to 0.00633, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0074 - mae: 0.0667 - val_loss: 0.0063 - val_mae: 0.0612
# Epoch 49/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0073 - mae: 0.0662
# Epoch 49: val_loss improved from 0.00633 to 0.00612, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0073 - mae: 0.0663 - val_loss: 0.0061 - val_mae: 0.0600
# Epoch 50/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0072 - mae: 0.0655
# Epoch 50: val_loss improved from 0.00612 to 0.00555, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0072 - mae: 0.0655 - val_loss: 0.0056 - val_mae: 0.0574
# Epoch 51/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0071 - mae: 0.0652
# Epoch 51: val_loss improved from 0.00555 to 0.00550, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0071 - mae: 0.0652 - val_loss: 0.0055 - val_mae: 0.0569
# Epoch 52/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0070 - mae: 0.0644
# Epoch 52: val_loss did not improve from 0.00550
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0070 - mae: 0.0644 - val_loss: 0.0058 - val_mae: 0.0579
# Epoch 53/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0071 - mae: 0.0649
# Epoch 53: val_loss did not improve from 0.00550
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0070 - mae: 0.0648 - val_loss: 0.0058 - val_mae: 0.0586
# Epoch 54/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0069 - mae: 0.0640
# Epoch 54: val_loss improved from 0.00550 to 0.00536, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0069 - mae: 0.0643 - val_loss: 0.0054 - val_mae: 0.0562
# Epoch 55/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0067 - mae: 0.0634
# Epoch 55: val_loss improved from 0.00536 to 0.00515, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0067 - mae: 0.0633 - val_loss: 0.0052 - val_mae: 0.0550
# Epoch 56/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0065 - mae: 0.0623
# Epoch 56: val_loss did not improve from 0.00515
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0065 - mae: 0.0624 - val_loss: 0.0052 - val_mae: 0.0550
# Epoch 57/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0067 - mae: 0.0629
# Epoch 57: val_loss improved from 0.00515 to 0.00515, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0066 - mae: 0.0628 - val_loss: 0.0052 - val_mae: 0.0549
# Epoch 58/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0064 - mae: 0.0618
# Epoch 58: val_loss improved from 0.00515 to 0.00507, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0064 - mae: 0.0617 - val_loss: 0.0051 - val_mae: 0.0544
# Epoch 59/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0063 - mae: 0.0613
# Epoch 59: val_loss improved from 0.00507 to 0.00488, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0063 - mae: 0.0612 - val_loss: 0.0049 - val_mae: 0.0534
# Epoch 60/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0063 - mae: 0.0611
# Epoch 60: val_loss improved from 0.00488 to 0.00483, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0063 - mae: 0.0611 - val_loss: 0.0048 - val_mae: 0.0530
# Epoch 61/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0060 - mae: 0.0598
# Epoch 61: val_loss improved from 0.00483 to 0.00466, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0061 - mae: 0.0600 - val_loss: 0.0047 - val_mae: 0.0525
# Epoch 62/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0061 - mae: 0.0603
# Epoch 62: val_loss did not improve from 0.00466
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0061 - mae: 0.0603 - val_loss: 0.0047 - val_mae: 0.0523
# Epoch 63/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0060 - mae: 0.0594
# Epoch 63: val_loss did not improve from 0.00466
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0059 - mae: 0.0593 - val_loss: 0.0047 - val_mae: 0.0524
# Epoch 64/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0061 - mae: 0.0603
# Epoch 64: val_loss improved from 0.00466 to 0.00463, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 16ms/step - loss: 0.0061 - mae: 0.0603 - val_loss: 0.0046 - val_mae: 0.0526
# Epoch 65/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0058 - mae: 0.0590
# Epoch 65: val_loss improved from 0.00463 to 0.00453, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0058 - mae: 0.0590 - val_loss: 0.0045 - val_mae: 0.0513
# Epoch 66/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0058 - mae: 0.0586
# Epoch 66: val_loss did not improve from 0.00453
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0058 - mae: 0.0585 - val_loss: 0.0047 - val_mae: 0.0518
# Epoch 67/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0058 - mae: 0.0583
# Epoch 67: val_loss did not improve from 0.00453
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0058 - mae: 0.0583 - val_loss: 0.0046 - val_mae: 0.0526
# Epoch 68/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0058 - mae: 0.0585
# Epoch 68: val_loss improved from 0.00453 to 0.00435, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0057 - mae: 0.0584 - val_loss: 0.0044 - val_mae: 0.0504
# Epoch 69/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0056 - mae: 0.0575
# Epoch 69: val_loss did not improve from 0.00435
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0056 - mae: 0.0577 - val_loss: 0.0044 - val_mae: 0.0505
# Epoch 70/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0578
# Epoch 70: val_loss improved from 0.00435 to 0.00423, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0057 - mae: 0.0578 - val_loss: 0.0042 - val_mae: 0.0496
# Epoch 71/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0056 - mae: 0.0575
# Epoch 71: val_loss improved from 0.00423 to 0.00419, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0056 - mae: 0.0576 - val_loss: 0.0042 - val_mae: 0.0490
# Epoch 72/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0055 - mae: 0.0573
# Epoch 72: val_loss improved from 0.00419 to 0.00415, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0055 - mae: 0.0573 - val_loss: 0.0041 - val_mae: 0.0491
# Epoch 73/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0054 - mae: 0.0565
# Epoch 73: val_loss improved from 0.00415 to 0.00403, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0054 - mae: 0.0565 - val_loss: 0.0040 - val_mae: 0.0487
# Epoch 74/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0054 - mae: 0.0563
# Epoch 74: val_loss did not improve from 0.00403
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0054 - mae: 0.0563 - val_loss: 0.0044 - val_mae: 0.0508
# Epoch 75/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0054 - mae: 0.0562
# Epoch 75: val_loss improved from 0.00403 to 0.00399, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0053 - mae: 0.0561 - val_loss: 0.0040 - val_mae: 0.0481
# Epoch 76/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0056 - mae: 0.0572
# Epoch 76: val_loss improved from 0.00399 to 0.00397, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0055 - mae: 0.0571 - val_loss: 0.0040 - val_mae: 0.0476
# Epoch 77/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0054 - mae: 0.0563
# Epoch 77: val_loss did not improve from 0.00397
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0054 - mae: 0.0562 - val_loss: 0.0041 - val_mae: 0.0489
# Epoch 78/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0055 - mae: 0.0568
# Epoch 78: val_loss did not improve from 0.00397
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0055 - mae: 0.0569 - val_loss: 0.0040 - val_mae: 0.0485
# Epoch 79/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0053 - mae: 0.0563
# Epoch 79: val_loss improved from 0.00397 to 0.00386, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0053 - mae: 0.0562 - val_loss: 0.0039 - val_mae: 0.0475
# Epoch 80/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0052 - mae: 0.0553
# Epoch 80: val_loss did not improve from 0.00386
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0052 - mae: 0.0553 - val_loss: 0.0040 - val_mae: 0.0480
# Epoch 81/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0053 - mae: 0.0562
# Epoch 81: val_loss improved from 0.00386 to 0.00383, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0053 - mae: 0.0561 - val_loss: 0.0038 - val_mae: 0.0466
# Epoch 82/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0051 - mae: 0.0548
# Epoch 82: val_loss did not improve from 0.00383
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0051 - mae: 0.0548 - val_loss: 0.0040 - val_mae: 0.0485
# Epoch 83/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0053 - mae: 0.0560
# Epoch 83: val_loss did not improve from 0.00383
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0053 - mae: 0.0559 - val_loss: 0.0039 - val_mae: 0.0476
# Epoch 84/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0052 - mae: 0.0552
# Epoch 84: val_loss improved from 0.00383 to 0.00379, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0052 - mae: 0.0553 - val_loss: 0.0038 - val_mae: 0.0474
# Epoch 85/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0051 - mae: 0.0547
# Epoch 85: val_loss did not improve from 0.00379
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0051 - mae: 0.0547 - val_loss: 0.0039 - val_mae: 0.0468
# Epoch 86/500
# 57/62 [==========================>...] - ETA: 0s - loss: 0.0052 - mae: 0.0547
# Epoch 86: val_loss did not improve from 0.00379
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0052 - mae: 0.0548 - val_loss: 0.0038 - val_mae: 0.0472
# Epoch 87/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0051 - mae: 0.0550
# Epoch 87: val_loss did not improve from 0.00379
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0051 - mae: 0.0550 - val_loss: 0.0038 - val_mae: 0.0470
# Epoch 88/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0050 - mae: 0.0543
# Epoch 88: val_loss improved from 0.00379 to 0.00377, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0050 - mae: 0.0543 - val_loss: 0.0038 - val_mae: 0.0471
# Epoch 89/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0051 - mae: 0.0551
# Epoch 89: val_loss improved from 0.00377 to 0.00372, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0051 - mae: 0.0551 - val_loss: 0.0037 - val_mae: 0.0467
# Epoch 90/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0050 - mae: 0.0543
# Epoch 90: val_loss improved from 0.00372 to 0.00360, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0050 - mae: 0.0542 - val_loss: 0.0036 - val_mae: 0.0460
# Epoch 91/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0048 - mae: 0.0535
# Epoch 91: val_loss did not improve from 0.00360
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0535 - val_loss: 0.0036 - val_mae: 0.0458
# Epoch 92/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0047 - mae: 0.0527
# Epoch 92: val_loss improved from 0.00360 to 0.00357, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0047 - mae: 0.0527 - val_loss: 0.0036 - val_mae: 0.0462
# Epoch 93/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0536
# Epoch 93: val_loss improved from 0.00357 to 0.00339, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0049 - mae: 0.0537 - val_loss: 0.0034 - val_mae: 0.0445
# Epoch 94/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0536
# Epoch 94: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0049 - mae: 0.0536 - val_loss: 0.0034 - val_mae: 0.0452
# Epoch 95/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0049 - mae: 0.0536
# Epoch 95: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0049 - mae: 0.0536 - val_loss: 0.0036 - val_mae: 0.0459
# Epoch 96/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0048 - mae: 0.0531
# Epoch 96: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0531 - val_loss: 0.0035 - val_mae: 0.0453
# Epoch 97/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0537
# Epoch 97: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0049 - mae: 0.0537 - val_loss: 0.0036 - val_mae: 0.0456
# Epoch 98/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0049 - mae: 0.0534
# Epoch 98: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0533 - val_loss: 0.0035 - val_mae: 0.0449
# Epoch 99/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0048 - mae: 0.0529
# Epoch 99: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0528 - val_loss: 0.0034 - val_mae: 0.0445
# Epoch 100/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0048 - mae: 0.0530
# Epoch 100: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0529 - val_loss: 0.0035 - val_mae: 0.0449
# Epoch 101/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0047 - mae: 0.0527
# Epoch 101: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0047 - mae: 0.0526 - val_loss: 0.0035 - val_mae: 0.0455
# Epoch 102/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0047 - mae: 0.0526
# Epoch 102: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0047 - mae: 0.0525 - val_loss: 0.0034 - val_mae: 0.0447
# Epoch 103/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0048 - mae: 0.0530
# Epoch 103: val_loss did not improve from 0.00339
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0532 - val_loss: 0.0035 - val_mae: 0.0451
# Epoch 104/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0050 - mae: 0.0537
# Epoch 104: val_loss improved from 0.00339 to 0.00337, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0050 - mae: 0.0536 - val_loss: 0.0034 - val_mae: 0.0439
# Epoch 105/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0048 - mae: 0.0530
# Epoch 105: val_loss did not improve from 0.00337
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0531 - val_loss: 0.0035 - val_mae: 0.0452
# Epoch 106/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0047 - mae: 0.0524
# Epoch 106: val_loss did not improve from 0.00337
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0047 - mae: 0.0524 - val_loss: 0.0034 - val_mae: 0.0447
# Epoch 107/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0047 - mae: 0.0526
# Epoch 107: val_loss improved from 0.00337 to 0.00329, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0047 - mae: 0.0526 - val_loss: 0.0033 - val_mae: 0.0437
# Epoch 108/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0046 - mae: 0.0522
# Epoch 108: val_loss did not improve from 0.00329
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0047 - mae: 0.0523 - val_loss: 0.0034 - val_mae: 0.0442
# Epoch 109/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0046 - mae: 0.0519
# Epoch 109: val_loss improved from 0.00329 to 0.00327, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0046 - mae: 0.0517 - val_loss: 0.0033 - val_mae: 0.0440
# Epoch 110/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0046 - mae: 0.0518
# Epoch 110: val_loss improved from 0.00327 to 0.00327, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0046 - mae: 0.0518 - val_loss: 0.0033 - val_mae: 0.0436
# Epoch 111/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0046 - mae: 0.0517
# Epoch 111: val_loss did not improve from 0.00327
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0046 - mae: 0.0518 - val_loss: 0.0034 - val_mae: 0.0439
# Epoch 112/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0046 - mae: 0.0518
# Epoch 112: val_loss improved from 0.00327 to 0.00314, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0046 - mae: 0.0519 - val_loss: 0.0031 - val_mae: 0.0428
# Epoch 113/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0046 - mae: 0.0519
# Epoch 113: val_loss did not improve from 0.00314
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0046 - mae: 0.0520 - val_loss: 0.0032 - val_mae: 0.0422
# Epoch 114/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0048 - mae: 0.0527
# Epoch 114: val_loss did not improve from 0.00314
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0526 - val_loss: 0.0034 - val_mae: 0.0450
# Epoch 115/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0046 - mae: 0.0520
# Epoch 115: val_loss did not improve from 0.00314
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0046 - mae: 0.0520 - val_loss: 0.0032 - val_mae: 0.0424
# Epoch 116/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0044 - mae: 0.0512
# Epoch 116: val_loss did not improve from 0.00314
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0044 - mae: 0.0510 - val_loss: 0.0032 - val_mae: 0.0433
# Epoch 117/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0044 - mae: 0.0509
# Epoch 117: val_loss did not improve from 0.00314
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0044 - mae: 0.0509 - val_loss: 0.0032 - val_mae: 0.0423
# Epoch 118/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0045 - mae: 0.0516
# Epoch 118: val_loss did not improve from 0.00314
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0045 - mae: 0.0516 - val_loss: 0.0032 - val_mae: 0.0429
# Epoch 119/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0044 - mae: 0.0506
# Epoch 119: val_loss improved from 0.00314 to 0.00306, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0044 - mae: 0.0507 - val_loss: 0.0031 - val_mae: 0.0422
# Epoch 120/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0045 - mae: 0.0514
# Epoch 120: val_loss improved from 0.00306 to 0.00301, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0045 - mae: 0.0514 - val_loss: 0.0030 - val_mae: 0.0419
# Epoch 121/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0045 - mae: 0.0513
# Epoch 121: val_loss improved from 0.00301 to 0.00298, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0045 - mae: 0.0513 - val_loss: 0.0030 - val_mae: 0.0417
# Epoch 122/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0045 - mae: 0.0510
# Epoch 122: val_loss did not improve from 0.00298
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0045 - mae: 0.0509 - val_loss: 0.0031 - val_mae: 0.0424
# Epoch 123/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0044 - mae: 0.0510
# Epoch 123: val_loss did not improve from 0.00298
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0044 - mae: 0.0510 - val_loss: 0.0030 - val_mae: 0.0417
# Epoch 124/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0043 - mae: 0.0502
# Epoch 124: val_loss did not improve from 0.00298
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0043 - mae: 0.0502 - val_loss: 0.0030 - val_mae: 0.0415
# Epoch 125/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0043 - mae: 0.0504
# Epoch 125: val_loss improved from 0.00298 to 0.00296, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0043 - mae: 0.0503 - val_loss: 0.0030 - val_mae: 0.0414
# Epoch 126/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - mae: 0.0493
# Epoch 126: val_loss did not improve from 0.00296
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0493 - val_loss: 0.0030 - val_mae: 0.0420
# Epoch 127/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0043 - mae: 0.0501
# Epoch 127: val_loss did not improve from 0.00296
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0502 - val_loss: 0.0030 - val_mae: 0.0421
# Epoch 128/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - mae: 0.0497
# Epoch 128: val_loss did not improve from 0.00296
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0497 - val_loss: 0.0032 - val_mae: 0.0430
# Epoch 129/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0042 - mae: 0.0497
# Epoch 129: val_loss did not improve from 0.00296
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0497 - val_loss: 0.0031 - val_mae: 0.0427
# Epoch 130/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0046 - mae: 0.0514
# Epoch 130: val_loss improved from 0.00296 to 0.00287, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0045 - mae: 0.0514 - val_loss: 0.0029 - val_mae: 0.0411
# Epoch 131/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0042 - mae: 0.0497
# Epoch 131: val_loss did not improve from 0.00287
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0497 - val_loss: 0.0029 - val_mae: 0.0411
# Epoch 132/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0041 - mae: 0.0490
# Epoch 132: val_loss did not improve from 0.00287
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0491 - val_loss: 0.0030 - val_mae: 0.0418
# Epoch 133/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0043 - mae: 0.0500
# Epoch 133: val_loss did not improve from 0.00287
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0501 - val_loss: 0.0029 - val_mae: 0.0408
# Epoch 134/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0043 - mae: 0.0501
# Epoch 134: val_loss did not improve from 0.00287
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0501 - val_loss: 0.0029 - val_mae: 0.0413
# Epoch 135/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0043 - mae: 0.0502
# Epoch 135: val_loss did not improve from 0.00287
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0500 - val_loss: 0.0030 - val_mae: 0.0416
# Epoch 136/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0042 - mae: 0.0493
# Epoch 136: val_loss improved from 0.00287 to 0.00275, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0042 - mae: 0.0493 - val_loss: 0.0027 - val_mae: 0.0396
# Epoch 137/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0042 - mae: 0.0500
# Epoch 137: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0499 - val_loss: 0.0028 - val_mae: 0.0406
# Epoch 138/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0043 - mae: 0.0497
# Epoch 138: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0497 - val_loss: 0.0029 - val_mae: 0.0404
# Epoch 139/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0043 - mae: 0.0499
# Epoch 139: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0500 - val_loss: 0.0030 - val_mae: 0.0411
# Epoch 140/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0042 - mae: 0.0495
# Epoch 140: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0496 - val_loss: 0.0030 - val_mae: 0.0414
# Epoch 141/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0041 - mae: 0.0489
# Epoch 141: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0489 - val_loss: 0.0030 - val_mae: 0.0417
# Epoch 142/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0043 - mae: 0.0499
# Epoch 142: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0498 - val_loss: 0.0028 - val_mae: 0.0406
# Epoch 143/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0043 - mae: 0.0498
# Epoch 143: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0498 - val_loss: 0.0029 - val_mae: 0.0406
# Epoch 144/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - mae: 0.0494
# Epoch 144: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0494 - val_loss: 0.0029 - val_mae: 0.0408
# Epoch 145/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0042 - mae: 0.0492
# Epoch 145: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0492 - val_loss: 0.0028 - val_mae: 0.0404
# Epoch 146/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0041 - mae: 0.0492
# Epoch 146: val_loss did not improve from 0.00275
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0492 - val_loss: 0.0030 - val_mae: 0.0419
# Epoch 147/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - mae: 0.0493
# Epoch 147: val_loss improved from 0.00275 to 0.00271, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0042 - mae: 0.0493 - val_loss: 0.0027 - val_mae: 0.0396
# Epoch 148/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0482
# Epoch 148: val_loss did not improve from 0.00271
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0481 - val_loss: 0.0028 - val_mae: 0.0399
# Epoch 149/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0041 - mae: 0.0489
# Epoch 149: val_loss improved from 0.00271 to 0.00267, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0041 - mae: 0.0488 - val_loss: 0.0027 - val_mae: 0.0391
# Epoch 150/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0042 - mae: 0.0492
# Epoch 150: val_loss improved from 0.00267 to 0.00266, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0042 - mae: 0.0494 - val_loss: 0.0027 - val_mae: 0.0393
# Epoch 151/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0041 - mae: 0.0490
# Epoch 151: val_loss did not improve from 0.00266
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0490 - val_loss: 0.0027 - val_mae: 0.0398
# Epoch 152/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0041 - mae: 0.0486
# Epoch 152: val_loss did not improve from 0.00266
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0486 - val_loss: 0.0027 - val_mae: 0.0395
# Epoch 153/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0042 - mae: 0.0494
# Epoch 153: val_loss improved from 0.00266 to 0.00266, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0042 - mae: 0.0494 - val_loss: 0.0027 - val_mae: 0.0392
# Epoch 154/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0042 - mae: 0.0493
# Epoch 154: val_loss improved from 0.00266 to 0.00263, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0042 - mae: 0.0492 - val_loss: 0.0026 - val_mae: 0.0388
# Epoch 155/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0041 - mae: 0.0487
# Epoch 155: val_loss did not improve from 0.00263
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0488 - val_loss: 0.0029 - val_mae: 0.0415
# Epoch 156/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0041 - mae: 0.0489
# Epoch 156: val_loss improved from 0.00263 to 0.00257, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0041 - mae: 0.0488 - val_loss: 0.0026 - val_mae: 0.0384
# Epoch 157/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0040 - mae: 0.0482
# Epoch 157: val_loss did not improve from 0.00257
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0482 - val_loss: 0.0028 - val_mae: 0.0402
# Epoch 158/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0041 - mae: 0.0488
# Epoch 158: val_loss did not improve from 0.00257
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0488 - val_loss: 0.0028 - val_mae: 0.0402
# Epoch 159/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0487
# Epoch 159: val_loss improved from 0.00257 to 0.00256, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0040 - mae: 0.0487 - val_loss: 0.0026 - val_mae: 0.0384
# Epoch 160/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0040 - mae: 0.0483
# Epoch 160: val_loss did not improve from 0.00256
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0482 - val_loss: 0.0026 - val_mae: 0.0391
# Epoch 161/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0486
# Epoch 161: val_loss did not improve from 0.00256
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0486 - val_loss: 0.0028 - val_mae: 0.0405
# Epoch 162/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0041 - mae: 0.0483
# Epoch 162: val_loss improved from 0.00256 to 0.00249, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0040 - mae: 0.0482 - val_loss: 0.0025 - val_mae: 0.0381
# Epoch 163/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0040 - mae: 0.0482
# Epoch 163: val_loss did not improve from 0.00249
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0482 - val_loss: 0.0028 - val_mae: 0.0398
# Epoch 164/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0482
# Epoch 164: val_loss did not improve from 0.00249
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0482 - val_loss: 0.0026 - val_mae: 0.0390
# Epoch 165/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0041 - mae: 0.0485
# Epoch 165: val_loss did not improve from 0.00249
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0485 - val_loss: 0.0025 - val_mae: 0.0381
# Epoch 166/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0039 - mae: 0.0475
# Epoch 166: val_loss did not improve from 0.00249
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0039 - mae: 0.0476 - val_loss: 0.0025 - val_mae: 0.0386
# Epoch 167/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0039 - mae: 0.0474
# Epoch 167: val_loss did not improve from 0.00249
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0039 - mae: 0.0474 - val_loss: 0.0025 - val_mae: 0.0382
# Epoch 168/500
# ...
# Epoch 308: val_loss did not improve from 0.00186
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0447 - val_loss: 0.0020 - val_mae: 0.0338
# Epoch 309/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0442
# Epoch 309: val_loss did not improve from 0.00186
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0019 - val_mae: 0.0336
# Epoch 310/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0443
# Epoch 310: val_loss did not improve from 0.00186
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0020 - val_mae: 0.0340
# Epoch 311/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0444
# Epoch 311: val_loss did not improve from 0.00186
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0445 - val_loss: 0.0020 - val_mae: 0.0346
# Epoch 312/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0444
# Epoch 312: val_loss did not improve from 0.00186
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0020 - val_mae: 0.0338
# Epoch 313/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0446
# Epoch 313: val_loss did not improve from 0.00186
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0446 - val_loss: 0.0019 - val_mae: 0.0336
# Epoch 314/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0444
# Epoch 314: val_loss did not improve from 0.00186
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0445 - val_loss: 0.0020 - val_mae: 0.0337
# Epoch 315/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0444
# Epoch 315: val_loss improved from 0.00186 to 0.00183, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0034 - mae: 0.0444 - val_loss: 0.0018 - val_mae: 0.0328
# Epoch 316/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0443
# Epoch 316: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0019 - val_mae: 0.0328
# Epoch 317/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0438
# Epoch 317: val_loss improved from 0.00183 to 0.00183, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0033 - mae: 0.0439 - val_loss: 0.0018 - val_mae: 0.0326
# Epoch 318/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0440
# Epoch 318: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0440 - val_loss: 0.0019 - val_mae: 0.0330
# Epoch 319/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0441
# Epoch 319: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0441 - val_loss: 0.0018 - val_mae: 0.0326
# Epoch 320/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0439
# Epoch 320: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0439 - val_loss: 0.0019 - val_mae: 0.0332
# Epoch 321/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0445
# Epoch 321: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0445 - val_loss: 0.0019 - val_mae: 0.0330
# Epoch 322/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0035 - mae: 0.0445
# Epoch 322: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0446 - val_loss: 0.0019 - val_mae: 0.0332
# Epoch 323/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0442
# Epoch 323: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0442 - val_loss: 0.0019 - val_mae: 0.0330
# Epoch 324/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0447
# Epoch 324: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0447 - val_loss: 0.0018 - val_mae: 0.0326
# Epoch 325/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0035 - mae: 0.0445
# Epoch 325: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0445 - val_loss: 0.0020 - val_mae: 0.0342
# Epoch 326/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0446
# Epoch 326: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0446 - val_loss: 0.0019 - val_mae: 0.0332
# Epoch 327/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0437
# Epoch 327: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0437 - val_loss: 0.0019 - val_mae: 0.0337
# Epoch 328/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0440
# Epoch 328: val_loss did not improve from 0.00183
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0437 - val_loss: 0.0021 - val_mae: 0.0351
# Epoch 329/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0440
# Epoch 329: val_loss improved from 0.00183 to 0.00181, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0018 - val_mae: 0.0324
# Epoch 330/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0436
# Epoch 330: val_loss did not improve from 0.00181
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0437 - val_loss: 0.0019 - val_mae: 0.0332
# Epoch 331/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0436
# Epoch 331: val_loss did not improve from 0.00181
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0436 - val_loss: 0.0019 - val_mae: 0.0330
# Epoch 332/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0445
# Epoch 332: val_loss did not improve from 0.00181
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0444 - val_loss: 0.0019 - val_mae: 0.0336
# Epoch 333/500
# 57/62 [==========================>...] - ETA: 0s - loss: 0.0033 - mae: 0.0437
# Epoch 333: val_loss did not improve from 0.00181
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0019 - val_mae: 0.0329
# Epoch 334/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0444
# Epoch 334: val_loss did not improve from 0.00181
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0019 - val_mae: 0.0331
# Epoch 335/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0439
# Epoch 335: val_loss improved from 0.00181 to 0.00180, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0033 - mae: 0.0439 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 336/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0440
# Epoch 336: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0439 - val_loss: 0.0018 - val_mae: 0.0327
# Epoch 337/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0443
# Epoch 337: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0018 - val_mae: 0.0328
# Epoch 338/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0440
# Epoch 338: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0440 - val_loss: 0.0019 - val_mae: 0.0328
# Epoch 339/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0433
# Epoch 339: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 340/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - mae: 0.0433
# Epoch 340: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0433 - val_loss: 0.0018 - val_mae: 0.0327
# Epoch 341/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0437
# Epoch 341: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0437 - val_loss: 0.0018 - val_mae: 0.0326
# Epoch 342/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0432
# Epoch 342: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0019 - val_mae: 0.0330
# Epoch 343/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0437
# Epoch 343: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0020 - val_mae: 0.0338
# Epoch 344/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0438
# Epoch 344: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0438 - val_loss: 0.0020 - val_mae: 0.0338
# Epoch 345/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0437
# Epoch 345: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0437 - val_loss: 0.0018 - val_mae: 0.0324
# Epoch 346/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0442
# Epoch 346: val_loss did not improve from 0.00180
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0442 - val_loss: 0.0018 - val_mae: 0.0326
# Epoch 347/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0435
# Epoch 347: val_loss improved from 0.00180 to 0.00173, saving model to Model\predictiveAnalysisWeather_W.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0017 - val_mae: 0.0315
# Epoch 348/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0438
# Epoch 348: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0437 - val_loss: 0.0018 - val_mae: 0.0329
# Epoch 349/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0438
# Epoch 349: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0438 - val_loss: 0.0020 - val_mae: 0.0336
# Epoch 350/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0438
# Epoch 350: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0436 - val_loss: 0.0019 - val_mae: 0.0334
# Epoch 351/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0437
# Epoch 351: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0436 - val_loss: 0.0019 - val_mae: 0.0335
# Epoch 352/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0438
# Epoch 352: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0436 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 353/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0433
# Epoch 353: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0018 - val_mae: 0.0320
# Epoch 354/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0443
# Epoch 354: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0018 - val_mae: 0.0322
# Epoch 355/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0440
# Epoch 355: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0019 - val_mae: 0.0334
# Epoch 356/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0441
# Epoch 356: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0441 - val_loss: 0.0018 - val_mae: 0.0328
# Epoch 357/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0439
# Epoch 357: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0439 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 358/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0430
# Epoch 358: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0018 - val_mae: 0.0329
# Epoch 359/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0430
# Epoch 359: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0430 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 360/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0434
# Epoch 360: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0018 - val_mae: 0.0328
# Epoch 361/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - mae: 0.0431
# Epoch 361: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0431 - val_loss: 0.0018 - val_mae: 0.0317
# Epoch 362/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0435
# Epoch 362: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0019 - val_mae: 0.0328
# Epoch 363/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0437
# Epoch 363: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0436 - val_loss: 0.0018 - val_mae: 0.0328
# Epoch 364/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0443
# Epoch 364: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0017 - val_mae: 0.0318
# Epoch 365/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0433
# Epoch 365: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0033 - mae: 0.0434 - val_loss: 0.0018 - val_mae: 0.0327
# Epoch 366/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0439
# Epoch 366: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0033 - mae: 0.0437 - val_loss: 0.0018 - val_mae: 0.0324
# Epoch 367/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0433
# Epoch 367: val_loss did not improve from 0.00173
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0018 - val_mae: 0.0325
# ✅ MSDL model for Wind saved to: Model\predictiveAnalysisWeather_W.h5

# %%
# ===========================================================
# Part 2.D: Train & Save MSDL Model for Precipitation Forecasting
# ===========================================================

# --- Prepare training data (pre-windowed) ---
X = datasets["Precipitation_%"]["X"]   # shape = [N, 112, 1], input sequences
y = datasets["Precipitation_%"]["y"]   # shape = [N, 24],     forecast targets

# --- 4× replication (no augmentation) ---
X = np.concatenate([X, X, X, X], axis=0)
y = np.concatenate([y, y, y, y], axis=0)

# (recommended) shuffle to avoid repeated blocks in order
idx = np.random.permutation(len(X))
X, y = X[idx], y[idx]

# --- Reproducibility (optional) ---
np.random.seed(42)
tf.random.set_seed(42)

# --- HARD RESET: clear any existing graph/weights, free memory ---
tf.keras.backend.clear_session()
try:
    del model
except NameError:
    pass
gc.collect()

# --- Build a fresh MSDL model for Precipitation ---
model = build_MSDL(input_len=X.shape[1], out_len=y.shape[1], n_features=X.shape[2])


# --- Define output directory and model save path ---
out_dir = Path("Model")
out_dir.mkdir(parents=True, exist_ok=True)
model_path = out_dir / "predictiveAnalysisWeather_P.h5"

# --- Configure callbacks ---
early_stop = EarlyStopping(
    monitor="val_loss",          # monitor validation loss
    patience=20,                 # stop if no improvement for 20 epochs
    restore_best_weights=True    # restore weights from best epoch
)

checkpoint = ModelCheckpoint(
    filepath=model_path,         # save path for the best model
    monitor="val_loss",          # criterion for saving
    save_best_only=True,         # overwrite only if val_loss improves
    verbose=1                    # log when model is saved
)


# --- Train the MSDL model ---
history = model.fit(
    X, y,
    epochs=500,                  # maximum epochs (may stop earlier via EarlyStopping)
    batch_size=16,               # training batch size
    validation_split=0.1,        # reserve 10% for validation
    verbose=1,                   # print training progress
    callbacks=[early_stop, checkpoint]
)

# --- Save the final (best) model explicitly ---
model.save(model_path)
print(f"✅ MSDL model for Precipitation saved to: {model_path}")
# Out:
# Epoch 1/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0524 - mae: 0.1778
# Epoch 1: val_loss improved from inf to 0.04163, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 3s 22ms/step - loss: 0.0519 - mae: 0.1770 - val_loss: 0.0416 - val_mae: 0.1607
# Epoch 2/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0418 - mae: 0.1610
# Epoch 2: val_loss improved from 0.04163 to 0.03936, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0420 - mae: 0.1615 - val_loss: 0.0394 - val_mae: 0.1584
# Epoch 3/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0388 - mae: 0.1545
# Epoch 3: val_loss improved from 0.03936 to 0.03381, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0387 - mae: 0.1543 - val_loss: 0.0338 - val_mae: 0.1415
# Epoch 4/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0335 - mae: 0.1432
# Epoch 4: val_loss did not improve from 0.03381
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0332 - mae: 0.1424 - val_loss: 0.0340 - val_mae: 0.1386
# Epoch 5/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0300 - mae: 0.1347
# Epoch 5: val_loss improved from 0.03381 to 0.02858, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0301 - mae: 0.1351 - val_loss: 0.0286 - val_mae: 0.1343
# Epoch 6/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0292 - mae: 0.1337
# Epoch 6: val_loss improved from 0.02858 to 0.02563, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0292 - mae: 0.1335 - val_loss: 0.0256 - val_mae: 0.1250
# Epoch 7/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0241 - mae: 0.1212
# Epoch 7: val_loss improved from 0.02563 to 0.02260, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0242 - mae: 0.1212 - val_loss: 0.0226 - val_mae: 0.1205
# Epoch 8/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0227 - mae: 0.1166
# Epoch 8: val_loss improved from 0.02260 to 0.02206, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0227 - mae: 0.1165 - val_loss: 0.0221 - val_mae: 0.1159
# Epoch 9/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0220 - mae: 0.1145
# Epoch 9: val_loss did not improve from 0.02206
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0219 - mae: 0.1143 - val_loss: 0.0221 - val_mae: 0.1145
# Epoch 10/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0227 - mae: 0.1160
# Epoch 10: val_loss improved from 0.02206 to 0.02159, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0227 - mae: 0.1161 - val_loss: 0.0216 - val_mae: 0.1155
# Epoch 11/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0208 - mae: 0.1118
# Epoch 11: val_loss improved from 0.02159 to 0.02063, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0208 - mae: 0.1118 - val_loss: 0.0206 - val_mae: 0.1127
# Epoch 12/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0201 - mae: 0.1091
# Epoch 12: val_loss did not improve from 0.02063
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0201 - mae: 0.1091 - val_loss: 0.0208 - val_mae: 0.1122
# Epoch 13/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0193 - mae: 0.1074
# Epoch 13: val_loss improved from 0.02063 to 0.02011, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0193 - mae: 0.1073 - val_loss: 0.0201 - val_mae: 0.1099
# Epoch 14/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0190 - mae: 0.1063
# Epoch 14: val_loss improved from 0.02011 to 0.01965, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0190 - mae: 0.1063 - val_loss: 0.0197 - val_mae: 0.1084
# Epoch 15/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0182 - mae: 0.1041
# Epoch 15: val_loss did not improve from 0.01965
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0183 - mae: 0.1043 - val_loss: 0.0203 - val_mae: 0.1102
# Epoch 16/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0180 - mae: 0.1033
# Epoch 16: val_loss improved from 0.01965 to 0.01812, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0181 - mae: 0.1034 - val_loss: 0.0181 - val_mae: 0.1040
# Epoch 17/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0179 - mae: 0.1031
# Epoch 17: val_loss did not improve from 0.01812
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0179 - mae: 0.1031 - val_loss: 0.0185 - val_mae: 0.1044
# Epoch 18/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0172 - mae: 0.1009
# Epoch 18: val_loss improved from 0.01812 to 0.01806, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0172 - mae: 0.1010 - val_loss: 0.0181 - val_mae: 0.1033
# Epoch 19/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0171 - mae: 0.1008
# Epoch 19: val_loss improved from 0.01806 to 0.01761, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0172 - mae: 0.1010 - val_loss: 0.0176 - val_mae: 0.1029
# Epoch 20/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0164 - mae: 0.0985
# Epoch 20: val_loss did not improve from 0.01761
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0163 - mae: 0.0985 - val_loss: 0.0183 - val_mae: 0.1030
# Epoch 21/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0161 - mae: 0.0981
# Epoch 21: val_loss improved from 0.01761 to 0.01732, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0161 - mae: 0.0979 - val_loss: 0.0173 - val_mae: 0.1009
# Epoch 22/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0152 - mae: 0.0954
# Epoch 22: val_loss improved from 0.01732 to 0.01633, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0152 - mae: 0.0954 - val_loss: 0.0163 - val_mae: 0.0987
# Epoch 23/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0148 - mae: 0.0942
# Epoch 23: val_loss improved from 0.01633 to 0.01594, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0148 - mae: 0.0942 - val_loss: 0.0159 - val_mae: 0.0976
# Epoch 24/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0144 - mae: 0.0929
# Epoch 24: val_loss did not improve from 0.01594
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0144 - mae: 0.0929 - val_loss: 0.0161 - val_mae: 0.0970
# Epoch 25/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0142 - mae: 0.0922
# Epoch 25: val_loss did not improve from 0.01594
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0141 - mae: 0.0920 - val_loss: 0.0164 - val_mae: 0.0969
# Epoch 26/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0141 - mae: 0.0919
# Epoch 26: val_loss improved from 0.01594 to 0.01443, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0141 - mae: 0.0921 - val_loss: 0.0144 - val_mae: 0.0929
# Epoch 27/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0129 - mae: 0.0881
# Epoch 27: val_loss improved from 0.01443 to 0.01373, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0128 - mae: 0.0880 - val_loss: 0.0137 - val_mae: 0.0915
# Epoch 28/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0119 - mae: 0.0847
# Epoch 28: val_loss did not improve from 0.01373
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0120 - mae: 0.0849 - val_loss: 0.0138 - val_mae: 0.0904
# Epoch 29/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0118 - mae: 0.0844
# Epoch 29: val_loss improved from 0.01373 to 0.01290, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0118 - mae: 0.0844 - val_loss: 0.0129 - val_mae: 0.0879
# Epoch 30/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0115 - mae: 0.0831
# Epoch 30: val_loss improved from 0.01290 to 0.01016, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0116 - mae: 0.0833 - val_loss: 0.0102 - val_mae: 0.0795
# Epoch 31/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0099 - mae: 0.0773
# Epoch 31: val_loss improved from 0.01016 to 0.00923, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0099 - mae: 0.0774 - val_loss: 0.0092 - val_mae: 0.0761
# Epoch 32/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0098 - mae: 0.0772
# Epoch 32: val_loss did not improve from 0.00923
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0098 - mae: 0.0772 - val_loss: 0.0095 - val_mae: 0.0752
# Epoch 33/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0094 - mae: 0.0754
# Epoch 33: val_loss improved from 0.00923 to 0.00809, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0094 - mae: 0.0754 - val_loss: 0.0081 - val_mae: 0.0706
# Epoch 34/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0087 - mae: 0.0723
# Epoch 34: val_loss did not improve from 0.00809
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0087 - mae: 0.0722 - val_loss: 0.0081 - val_mae: 0.0704
# Epoch 35/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0079 - mae: 0.0689
# Epoch 35: val_loss improved from 0.00809 to 0.00723, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0079 - mae: 0.0689 - val_loss: 0.0072 - val_mae: 0.0663
# Epoch 36/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0078 - mae: 0.0683
# Epoch 36: val_loss improved from 0.00723 to 0.00711, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0078 - mae: 0.0684 - val_loss: 0.0071 - val_mae: 0.0662
# Epoch 37/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0076 - mae: 0.0679
# Epoch 37: val_loss improved from 0.00711 to 0.00613, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0076 - mae: 0.0679 - val_loss: 0.0061 - val_mae: 0.0619
# Epoch 38/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0073 - mae: 0.0660
# Epoch 38: val_loss did not improve from 0.00613
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0073 - mae: 0.0660 - val_loss: 0.0068 - val_mae: 0.0649
# Epoch 39/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0072 - mae: 0.0655
# Epoch 39: val_loss did not improve from 0.00613
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0072 - mae: 0.0656 - val_loss: 0.0065 - val_mae: 0.0626
# Epoch 40/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0070 - mae: 0.0645
# Epoch 40: val_loss improved from 0.00613 to 0.00594, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0070 - mae: 0.0645 - val_loss: 0.0059 - val_mae: 0.0601
# Epoch 41/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0635
# Epoch 41: val_loss improved from 0.00594 to 0.00553, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 17ms/step - loss: 0.0068 - mae: 0.0635 - val_loss: 0.0055 - val_mae: 0.0586
# Epoch 42/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0068 - mae: 0.0634
# Epoch 42: val_loss did not improve from 0.00553
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0068 - mae: 0.0634 - val_loss: 0.0061 - val_mae: 0.0619
# Epoch 43/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0066 - mae: 0.0627
# Epoch 43: val_loss did not improve from 0.00553
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0066 - mae: 0.0627 - val_loss: 0.0056 - val_mae: 0.0583
# Epoch 44/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0064 - mae: 0.0617
# Epoch 44: val_loss improved from 0.00553 to 0.00510, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0064 - mae: 0.0616 - val_loss: 0.0051 - val_mae: 0.0560
# Epoch 45/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0064 - mae: 0.0616
# Epoch 45: val_loss did not improve from 0.00510
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0064 - mae: 0.0616 - val_loss: 0.0051 - val_mae: 0.0558
# Epoch 46/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0064 - mae: 0.0620
# Epoch 46: val_loss did not improve from 0.00510
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0065 - mae: 0.0621 - val_loss: 0.0052 - val_mae: 0.0562
# Epoch 47/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0603
# Epoch 47: val_loss improved from 0.00510 to 0.00501, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0062 - mae: 0.0604 - val_loss: 0.0050 - val_mae: 0.0558
# Epoch 48/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0062 - mae: 0.0603
# Epoch 48: val_loss improved from 0.00501 to 0.00495, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0062 - mae: 0.0606 - val_loss: 0.0049 - val_mae: 0.0546
# Epoch 49/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0059 - mae: 0.0593
# Epoch 49: val_loss improved from 0.00495 to 0.00488, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0059 - mae: 0.0593 - val_loss: 0.0049 - val_mae: 0.0551
# Epoch 50/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0059 - mae: 0.0594
# Epoch 50: val_loss improved from 0.00488 to 0.00477, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0060 - mae: 0.0595 - val_loss: 0.0048 - val_mae: 0.0544
# Epoch 51/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0582
# Epoch 51: val_loss improved from 0.00477 to 0.00463, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0057 - mae: 0.0582 - val_loss: 0.0046 - val_mae: 0.0533
# Epoch 52/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0058 - mae: 0.0589
# Epoch 52: val_loss did not improve from 0.00463
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0058 - mae: 0.0588 - val_loss: 0.0047 - val_mae: 0.0536
# Epoch 53/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0056 - mae: 0.0579
# Epoch 53: val_loss did not improve from 0.00463
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0056 - mae: 0.0579 - val_loss: 0.0051 - val_mae: 0.0559
# Epoch 54/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0055 - mae: 0.0575
# Epoch 54: val_loss improved from 0.00463 to 0.00458, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0056 - mae: 0.0576 - val_loss: 0.0046 - val_mae: 0.0524
# Epoch 55/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0056 - mae: 0.0575
# Epoch 55: val_loss did not improve from 0.00458
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0056 - mae: 0.0575 - val_loss: 0.0046 - val_mae: 0.0536
# Epoch 56/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0056 - mae: 0.0580
# Epoch 56: val_loss improved from 0.00458 to 0.00456, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0056 - mae: 0.0580 - val_loss: 0.0046 - val_mae: 0.0524
# Epoch 57/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0057 - mae: 0.0582
# Epoch 57: val_loss improved from 0.00456 to 0.00451, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0057 - mae: 0.0580 - val_loss: 0.0045 - val_mae: 0.0530
# Epoch 58/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0055 - mae: 0.0573
# Epoch 58: val_loss improved from 0.00451 to 0.00442, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0055 - mae: 0.0573 - val_loss: 0.0044 - val_mae: 0.0523
# Epoch 59/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0054 - mae: 0.0562
# Epoch 59: val_loss did not improve from 0.00442
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0053 - mae: 0.0562 - val_loss: 0.0049 - val_mae: 0.0543
# Epoch 60/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0055 - mae: 0.0571
# Epoch 60: val_loss did not improve from 0.00442
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0055 - mae: 0.0571 - val_loss: 0.0048 - val_mae: 0.0538
# Epoch 61/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0055 - mae: 0.0571
# Epoch 61: val_loss improved from 0.00442 to 0.00434, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0055 - mae: 0.0572 - val_loss: 0.0043 - val_mae: 0.0513
# Epoch 62/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0053 - mae: 0.0562
# Epoch 62: val_loss did not improve from 0.00434
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0054 - mae: 0.0563 - val_loss: 0.0044 - val_mae: 0.0520
# Epoch 63/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0053 - mae: 0.0561
# Epoch 63: val_loss did not improve from 0.00434
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0053 - mae: 0.0561 - val_loss: 0.0046 - val_mae: 0.0531
# Epoch 64/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0055 - mae: 0.0571
# Epoch 64: val_loss improved from 0.00434 to 0.00422, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0055 - mae: 0.0572 - val_loss: 0.0042 - val_mae: 0.0512
# Epoch 65/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0053 - mae: 0.0562
# Epoch 65: val_loss did not improve from 0.00422
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0053 - mae: 0.0562 - val_loss: 0.0042 - val_mae: 0.0510
# Epoch 66/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0053 - mae: 0.0561
# Epoch 66: val_loss improved from 0.00422 to 0.00410, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0053 - mae: 0.0561 - val_loss: 0.0041 - val_mae: 0.0500
# Epoch 67/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0051 - mae: 0.0551
# Epoch 67: val_loss did not improve from 0.00410
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0051 - mae: 0.0551 - val_loss: 0.0042 - val_mae: 0.0502
# Epoch 68/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0052 - mae: 0.0553
# Epoch 68: val_loss did not improve from 0.00410
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0052 - mae: 0.0553 - val_loss: 0.0045 - val_mae: 0.0524
# Epoch 69/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0052 - mae: 0.0555
# Epoch 69: val_loss improved from 0.00410 to 0.00384, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0052 - mae: 0.0556 - val_loss: 0.0038 - val_mae: 0.0484
# Epoch 70/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0052 - mae: 0.0554
# Epoch 70: val_loss did not improve from 0.00384
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0052 - mae: 0.0553 - val_loss: 0.0041 - val_mae: 0.0499
# Epoch 71/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0051 - mae: 0.0548
# Epoch 71: val_loss did not improve from 0.00384
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0051 - mae: 0.0548 - val_loss: 0.0040 - val_mae: 0.0495
# Epoch 72/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0052 - mae: 0.0554
# Epoch 72: val_loss did not improve from 0.00384
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0052 - mae: 0.0554 - val_loss: 0.0040 - val_mae: 0.0499
# Epoch 73/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0048 - mae: 0.0531
# Epoch 73: val_loss did not improve from 0.00384
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0533 - val_loss: 0.0040 - val_mae: 0.0492
# Epoch 74/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0050 - mae: 0.0541
# Epoch 74: val_loss improved from 0.00384 to 0.00373, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0050 - mae: 0.0541 - val_loss: 0.0037 - val_mae: 0.0481
# Epoch 75/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0049 - mae: 0.0539
# Epoch 75: val_loss did not improve from 0.00373
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0049 - mae: 0.0539 - val_loss: 0.0040 - val_mae: 0.0499
# Epoch 76/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0048 - mae: 0.0537
# Epoch 76: val_loss did not improve from 0.00373
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0537 - val_loss: 0.0038 - val_mae: 0.0483
# Epoch 77/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0536
# Epoch 77: val_loss did not improve from 0.00373
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0049 - mae: 0.0535 - val_loss: 0.0040 - val_mae: 0.0494
# Epoch 78/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0539
# Epoch 78: val_loss improved from 0.00373 to 0.00368, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0049 - mae: 0.0538 - val_loss: 0.0037 - val_mae: 0.0476
# Epoch 79/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0049 - mae: 0.0541
# Epoch 79: val_loss improved from 0.00368 to 0.00351, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0049 - mae: 0.0541 - val_loss: 0.0035 - val_mae: 0.0462
# Epoch 80/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0049 - mae: 0.0534
# Epoch 80: val_loss did not improve from 0.00351
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0049 - mae: 0.0534 - val_loss: 0.0037 - val_mae: 0.0469
# Epoch 81/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0048 - mae: 0.0534
# Epoch 81: val_loss did not improve from 0.00351
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0534 - val_loss: 0.0039 - val_mae: 0.0487
# Epoch 82/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0048 - mae: 0.0526
# Epoch 82: val_loss did not improve from 0.00351
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0526 - val_loss: 0.0036 - val_mae: 0.0473
# Epoch 83/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0046 - mae: 0.0523
# Epoch 83: val_loss improved from 0.00351 to 0.00329, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0046 - mae: 0.0522 - val_loss: 0.0033 - val_mae: 0.0448
# Epoch 84/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0048 - mae: 0.0530
# Epoch 84: val_loss did not improve from 0.00329
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0048 - mae: 0.0530 - val_loss: 0.0035 - val_mae: 0.0468
# Epoch 85/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0047 - mae: 0.0524
# Epoch 85: val_loss did not improve from 0.00329
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0047 - mae: 0.0524 - val_loss: 0.0034 - val_mae: 0.0457
# Epoch 86/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0045 - mae: 0.0513
# Epoch 86: val_loss did not improve from 0.00329
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0045 - mae: 0.0515 - val_loss: 0.0033 - val_mae: 0.0449
# Epoch 87/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0047 - mae: 0.0526
# Epoch 87: val_loss improved from 0.00329 to 0.00322, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0048 - mae: 0.0526 - val_loss: 0.0032 - val_mae: 0.0443
# Epoch 88/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0046 - mae: 0.0521
# Epoch 88: val_loss did not improve from 0.00322
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0046 - mae: 0.0520 - val_loss: 0.0035 - val_mae: 0.0462
# Epoch 89/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0047 - mae: 0.0525
# Epoch 89: val_loss did not improve from 0.00322
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0047 - mae: 0.0525 - val_loss: 0.0033 - val_mae: 0.0453
# Epoch 90/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0046 - mae: 0.0519
# Epoch 90: val_loss did not improve from 0.00322
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0046 - mae: 0.0519 - val_loss: 0.0035 - val_mae: 0.0459
# Epoch 91/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0047 - mae: 0.0527
# Epoch 91: val_loss improved from 0.00322 to 0.00300, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0047 - mae: 0.0527 - val_loss: 0.0030 - val_mae: 0.0429
# Epoch 92/500
# 57/62 [==========================>...] - ETA: 0s - loss: 0.0045 - mae: 0.0511
# Epoch 92: val_loss did not improve from 0.00300
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0045 - mae: 0.0513 - val_loss: 0.0034 - val_mae: 0.0460
# Epoch 93/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0044 - mae: 0.0508
# Epoch 93: val_loss did not improve from 0.00300
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0044 - mae: 0.0508 - val_loss: 0.0037 - val_mae: 0.0472
# Epoch 94/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0046 - mae: 0.0521
# Epoch 94: val_loss improved from 0.00300 to 0.00298, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0046 - mae: 0.0521 - val_loss: 0.0030 - val_mae: 0.0425
# Epoch 95/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0045 - mae: 0.0511
# Epoch 95: val_loss did not improve from 0.00298
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0045 - mae: 0.0511 - val_loss: 0.0036 - val_mae: 0.0469
# Epoch 96/500
# 57/62 [==========================>...] - ETA: 0s - loss: 0.0044 - mae: 0.0508
# Epoch 96: val_loss improved from 0.00298 to 0.00283, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0044 - mae: 0.0509 - val_loss: 0.0028 - val_mae: 0.0417
# Epoch 97/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0045 - mae: 0.0511
# Epoch 97: val_loss did not improve from 0.00283
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0045 - mae: 0.0511 - val_loss: 0.0032 - val_mae: 0.0442
# Epoch 98/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0044 - mae: 0.0511
# Epoch 98: val_loss did not improve from 0.00283
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0044 - mae: 0.0510 - val_loss: 0.0031 - val_mae: 0.0426
# Epoch 99/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0044 - mae: 0.0507
# Epoch 99: val_loss did not improve from 0.00283
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0044 - mae: 0.0507 - val_loss: 0.0029 - val_mae: 0.0421
# Epoch 100/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - mae: 0.0497
# Epoch 100: val_loss did not improve from 0.00283
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0497 - val_loss: 0.0028 - val_mae: 0.0418
# Epoch 101/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0044 - mae: 0.0509
# Epoch 101: val_loss did not improve from 0.00283
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0044 - mae: 0.0508 - val_loss: 0.0029 - val_mae: 0.0424
# Epoch 102/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0044 - mae: 0.0509
# Epoch 102: val_loss did not improve from 0.00283
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0044 - mae: 0.0508 - val_loss: 0.0032 - val_mae: 0.0444
# Epoch 103/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0044 - mae: 0.0507
# Epoch 103: val_loss improved from 0.00283 to 0.00275, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0044 - mae: 0.0507 - val_loss: 0.0027 - val_mae: 0.0407
# Epoch 104/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - mae: 0.0495
# Epoch 104: val_loss improved from 0.00275 to 0.00273, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0042 - mae: 0.0495 - val_loss: 0.0027 - val_mae: 0.0409
# Epoch 105/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0042 - mae: 0.0496
# Epoch 105: val_loss improved from 0.00273 to 0.00251, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0042 - mae: 0.0496 - val_loss: 0.0025 - val_mae: 0.0394
# Epoch 106/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0044 - mae: 0.0507
# Epoch 106: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0044 - mae: 0.0507 - val_loss: 0.0029 - val_mae: 0.0417
# Epoch 107/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0042 - mae: 0.0496
# Epoch 107: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0500 - val_loss: 0.0027 - val_mae: 0.0412
# Epoch 108/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0041 - mae: 0.0487
# Epoch 108: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0487 - val_loss: 0.0026 - val_mae: 0.0396
# Epoch 109/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0040 - mae: 0.0486
# Epoch 109: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0486 - val_loss: 0.0026 - val_mae: 0.0402
# Epoch 110/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0042 - mae: 0.0498
# Epoch 110: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0498 - val_loss: 0.0028 - val_mae: 0.0414
# Epoch 111/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0043 - mae: 0.0499
# Epoch 111: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0498 - val_loss: 0.0026 - val_mae: 0.0402
# Epoch 112/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0043 - mae: 0.0499
# Epoch 112: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043 - mae: 0.0499 - val_loss: 0.0027 - val_mae: 0.0404
# Epoch 113/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0041 - mae: 0.0492
# Epoch 113: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0492 - val_loss: 0.0025 - val_mae: 0.0394
# Epoch 114/500
# 57/62 [==========================>...] - ETA: 0s - loss: 0.0041 - mae: 0.0492
# Epoch 114: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0491 - val_loss: 0.0027 - val_mae: 0.0400
# Epoch 115/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0040 - mae: 0.0486
# Epoch 115: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0486 - val_loss: 0.0026 - val_mae: 0.0400
# Epoch 116/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0041 - mae: 0.0484
# Epoch 116: val_loss did not improve from 0.00251
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0484 - val_loss: 0.0027 - val_mae: 0.0413
# Epoch 117/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0040 - mae: 0.0483
# Epoch 117: val_loss improved from 0.00251 to 0.00247, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0040 - mae: 0.0483 - val_loss: 0.0025 - val_mae: 0.0390
# Epoch 118/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0486
# Epoch 118: val_loss did not improve from 0.00247
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0486 - val_loss: 0.0025 - val_mae: 0.0391
# Epoch 119/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0042 - mae: 0.0492
# Epoch 119: val_loss did not improve from 0.00247
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0042 - mae: 0.0492 - val_loss: 0.0026 - val_mae: 0.0404
# Epoch 120/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0040 - mae: 0.0486
# Epoch 120: val_loss did not improve from 0.00247
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0486 - val_loss: 0.0027 - val_mae: 0.0406
# Epoch 121/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0040 - mae: 0.0482
# Epoch 121: val_loss improved from 0.00247 to 0.00246, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0040 - mae: 0.0482 - val_loss: 0.0025 - val_mae: 0.0384
# Epoch 122/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0039 - mae: 0.0477
# Epoch 122: val_loss did not improve from 0.00246
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0039 - mae: 0.0477 - val_loss: 0.0027 - val_mae: 0.0400
# Epoch 123/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0041 - mae: 0.0485
# Epoch 123: val_loss did not improve from 0.00246
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0485 - val_loss: 0.0026 - val_mae: 0.0398
# Epoch 124/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0039 - mae: 0.0478
# Epoch 124: val_loss did not improve from 0.00246
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0039 - mae: 0.0478 - val_loss: 0.0028 - val_mae: 0.0419
# Epoch 125/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0040 - mae: 0.0482
# Epoch 125: val_loss did not improve from 0.00246
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0482 - val_loss: 0.0025 - val_mae: 0.0394
# Epoch 126/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0038 - mae: 0.0469
# Epoch 126: val_loss improved from 0.00246 to 0.00235, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0038 - mae: 0.0469 - val_loss: 0.0024 - val_mae: 0.0377
# Epoch 127/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0039 - mae: 0.0478
# Epoch 127: val_loss did not improve from 0.00235
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0039 - mae: 0.0478 - val_loss: 0.0025 - val_mae: 0.0391
# Epoch 128/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0483
# Epoch 128: val_loss did not improve from 0.00235
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0483 - val_loss: 0.0028 - val_mae: 0.0411
# Epoch 129/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0041 - mae: 0.0490
# Epoch 129: val_loss did not improve from 0.00235
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0041 - mae: 0.0490 - val_loss: 0.0024 - val_mae: 0.0387
# Epoch 130/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0039 - mae: 0.0476
# Epoch 130: val_loss did not improve from 0.00235
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0039 - mae: 0.0476 - val_loss: 0.0029 - val_mae: 0.0418
# Epoch 131/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0041 - mae: 0.0484
# Epoch 131: val_loss improved from 0.00235 to 0.00226, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0041 - mae: 0.0484 - val_loss: 0.0023 - val_mae: 0.0368
# Epoch 132/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0039 - mae: 0.0478
# Epoch 132: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0040 - mae: 0.0479 - val_loss: 0.0024 - val_mae: 0.0381
# Epoch 133/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0040 - mae: 0.0484
# Epoch 133: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0040 - mae: 0.0484 - val_loss: 0.0024 - val_mae: 0.0383
# Epoch 134/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0039 - mae: 0.0473
# Epoch 134: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0039 - mae: 0.0473 - val_loss: 0.0024 - val_mae: 0.0383
# Epoch 135/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0039 - mae: 0.0474
# Epoch 135: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0039 - mae: 0.0473 - val_loss: 0.0023 - val_mae: 0.0373
# Epoch 136/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0472
# Epoch 136: val_loss did not improve from 0.00226
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0038 - mae: 0.0472 - val_loss: 0.0024 - val_mae: 0.0373
# Epoch 137/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0465
# Epoch 137: val_loss improved from 0.00226 to 0.00224, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0038 - mae: 0.0465 - val_loss: 0.0022 - val_mae: 0.0369
# Epoch 138/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0469
# Epoch 138: val_loss improved from 0.00224 to 0.00219, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0038 - mae: 0.0469 - val_loss: 0.0022 - val_mae: 0.0364
# Epoch 139/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0461
# Epoch 139: val_loss did not improve from 0.00219
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0461 - val_loss: 0.0023 - val_mae: 0.0373
# Epoch 140/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0465
# Epoch 140: val_loss improved from 0.00219 to 0.00213, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0037 - mae: 0.0465 - val_loss: 0.0021 - val_mae: 0.0364
# Epoch 141/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0464
# Epoch 141: val_loss did not improve from 0.00213
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0037 - mae: 0.0464 - val_loss: 0.0023 - val_mae: 0.0379
# Epoch 142/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0039 - mae: 0.0472
# Epoch 142: val_loss did not improve from 0.00213
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0039 - mae: 0.0472 - val_loss: 0.0021 - val_mae: 0.0364
# Epoch 143/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0470
# Epoch 143: val_loss did not improve from 0.00213
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0038 - mae: 0.0471 - val_loss: 0.0024 - val_mae: 0.0380
# Epoch 144/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0466
# Epoch 144: val_loss improved from 0.00213 to 0.00212, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0038 - mae: 0.0466 - val_loss: 0.0021 - val_mae: 0.0361
# Epoch 145/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0469
# Epoch 145: val_loss did not improve from 0.00212
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0037 - mae: 0.0468 - val_loss: 0.0023 - val_mae: 0.0378
# Epoch 146/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0462
# Epoch 146: val_loss did not improve from 0.00212
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0037 - mae: 0.0462 - val_loss: 0.0022 - val_mae: 0.0371
# Epoch 147/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0038 - mae: 0.0466
# Epoch 147: val_loss did not improve from 0.00212
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0038 - mae: 0.0466 - val_loss: 0.0022 - val_mae: 0.0363
# Epoch 148/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0472
# Epoch 148: val_loss did not improve from 0.00212
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0038 - mae: 0.0472 - val_loss: 0.0024 - val_mae: 0.0384
# Epoch 149/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0459
# Epoch 149: val_loss did not improve from 0.00212
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0037 - mae: 0.0460 - val_loss: 0.0022 - val_mae: 0.0364
# Epoch 150/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0464
# Epoch 150: val_loss improved from 0.00212 to 0.00211, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0038 - mae: 0.0464 - val_loss: 0.0021 - val_mae: 0.0360
# Epoch 151/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0457
# Epoch 151: val_loss did not improve from 0.00211
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0456 - val_loss: 0.0023 - val_mae: 0.0375
# Epoch 152/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0456
# Epoch 152: val_loss did not improve from 0.00211
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0456 - val_loss: 0.0022 - val_mae: 0.0367
# Epoch 153/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0468
# Epoch 153: val_loss did not improve from 0.00211
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0038 - mae: 0.0468 - val_loss: 0.0021 - val_mae: 0.0361
# Epoch 154/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0037 - mae: 0.0463
# Epoch 154: val_loss did not improve from 0.00211
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0037 - mae: 0.0464 - val_loss: 0.0022 - val_mae: 0.0361
# Epoch 155/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0464
# Epoch 155: val_loss improved from 0.00211 to 0.00211, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0037 - mae: 0.0464 - val_loss: 0.0021 - val_mae: 0.0363
# Epoch 156/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0453
# Epoch 156: val_loss improved from 0.00211 to 0.00208, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0035 - mae: 0.0452 - val_loss: 0.0021 - val_mae: 0.0357
# Epoch 157/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0466
# Epoch 157: val_loss did not improve from 0.00208
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0037 - mae: 0.0466 - val_loss: 0.0022 - val_mae: 0.0370
# Epoch 158/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0459
# Epoch 158: val_loss improved from 0.00208 to 0.00201, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0037 - mae: 0.0459 - val_loss: 0.0020 - val_mae: 0.0350
# Epoch 159/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0461
# Epoch 159: val_loss did not improve from 0.00201
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0037 - mae: 0.0461 - val_loss: 0.0020 - val_mae: 0.0353
# Epoch 160/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0468
# Epoch 160: val_loss did not improve from 0.00201
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0038 - mae: 0.0468 - val_loss: 0.0020 - val_mae: 0.0353
# Epoch 161/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0449
# Epoch 161: val_loss did not improve from 0.00201
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0035 - mae: 0.0449 - val_loss: 0.0020 - val_mae: 0.0351
# Epoch 162/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0457
# Epoch 162: val_loss did not improve from 0.00201
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0036 - mae: 0.0456 - val_loss: 0.0021 - val_mae: 0.0360
# Epoch 163/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0037 - mae: 0.0463
# Epoch 163: val_loss did not improve from 0.00201
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0037 - mae: 0.0463 - val_loss: 0.0021 - val_mae: 0.0360
# Epoch 164/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0453
# Epoch 164: val_loss did not improve from 0.00201
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0455 - val_loss: 0.0021 - val_mae: 0.0357
# Epoch 165/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0038 - mae: 0.0469
# Epoch 165: val_loss did not improve from 0.00201
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0038 - mae: 0.0469 - val_loss: 0.0020 - val_mae: 0.0350
# Epoch 166/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0450
# Epoch 166: val_loss did not improve from 0.00201
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0450 - val_loss: 0.0021 - val_mae: 0.0357
# Epoch 167/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0449
# Epoch 167: val_loss improved from 0.00201 to 0.00198, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0035 - mae: 0.0449 - val_loss: 0.0020 - val_mae: 0.0348
# Epoch 168/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0449
# Epoch 168: val_loss did not improve from 0.00198
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0450 - val_loss: 0.0021 - val_mae: 0.0359
# Epoch 169/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0452
# Epoch 169: val_loss did not improve from 0.00198
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036 - mae: 0.0454 - val_loss: 0.0024 - val_mae: 0.0382
# Epoch 170/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0036 - mae: 0.0454
# Epoch 170: val_loss improved from 0.00198 to 0.00191, saving model to Model\predictiveAnalysisWeather_P.h5
# ...
# Epoch 198: val_loss did not improve from 0.00177
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0034 - mae: 0.0442 - val_loss: 0.0018 - val_mae: 0.0324
# Epoch 199/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0440
# Epoch 199: val_loss did not improve from 0.00177
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0019 - val_mae: 0.0338
# Epoch 200/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0443
# Epoch 200: val_loss did not improve from 0.00177
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0442 - val_loss: 0.0020 - val_mae: 0.0348
# Epoch 201/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0447
# Epoch 201: val_loss did not improve from 0.00177
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0447 - val_loss: 0.0019 - val_mae: 0.0345
# Epoch 202/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0441
# Epoch 202: val_loss did not improve from 0.00177
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0441 - val_loss: 0.0020 - val_mae: 0.0350
# Epoch 203/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0436
# Epoch 203: val_loss did not improve from 0.00177
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0436 - val_loss: 0.0019 - val_mae: 0.0338
# Epoch 204/500
# 57/62 [==========================>...] - ETA: 0s - loss: 0.0034 - mae: 0.0445
# Epoch 204: val_loss did not improve from 0.00177
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0445 - val_loss: 0.0019 - val_mae: 0.0342
# Epoch 205/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0441
# Epoch 205: val_loss did not improve from 0.00177
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0439 - val_loss: 0.0019 - val_mae: 0.0343
# Epoch 206/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0035 - mae: 0.0446
# Epoch 206: val_loss improved from 0.00177 to 0.00176, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0035 - mae: 0.0446 - val_loss: 0.0018 - val_mae: 0.0330
# Epoch 207/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0442
# Epoch 207: val_loss did not improve from 0.00176
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0442 - val_loss: 0.0018 - val_mae: 0.0329
# Epoch 208/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0035 - mae: 0.0449
# Epoch 208: val_loss did not improve from 0.00176
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0448 - val_loss: 0.0019 - val_mae: 0.0348
# Epoch 209/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0036 - mae: 0.0454
# Epoch 209: val_loss did not improve from 0.00176
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0036 - mae: 0.0453 - val_loss: 0.0018 - val_mae: 0.0329
# Epoch 210/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0035 - mae: 0.0447
# Epoch 210: val_loss did not improve from 0.00176
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0445 - val_loss: 0.0019 - val_mae: 0.0340
# Epoch 211/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0442
# Epoch 211: val_loss did not improve from 0.00176
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0442 - val_loss: 0.0018 - val_mae: 0.0333
# Epoch 212/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0435
# Epoch 212: val_loss did not improve from 0.00176
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0018 - val_mae: 0.0327
# Epoch 213/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0436
# Epoch 213: val_loss improved from 0.00176 to 0.00175, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0034 - mae: 0.0435 - val_loss: 0.0018 - val_mae: 0.0328
# Epoch 214/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0035 - mae: 0.0447
# Epoch 214: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0448 - val_loss: 0.0019 - val_mae: 0.0339
# Epoch 215/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0035 - mae: 0.0445
# Epoch 215: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0445 - val_loss: 0.0019 - val_mae: 0.0339
# Epoch 216/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0036 - mae: 0.0450
# Epoch 216: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0448 - val_loss: 0.0020 - val_mae: 0.0347
# Epoch 217/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0440
# Epoch 217: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0020 - val_mae: 0.0350
# Epoch 218/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0035 - mae: 0.0447
# Epoch 218: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0447 - val_loss: 0.0019 - val_mae: 0.0337
# Epoch 219/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0442
# Epoch 219: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0442 - val_loss: 0.0019 - val_mae: 0.0342
# Epoch 220/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0435
# Epoch 220: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0434 - val_loss: 0.0019 - val_mae: 0.0342
# Epoch 221/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0430
# Epoch 221: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0430 - val_loss: 0.0018 - val_mae: 0.0331
# Epoch 222/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0435
# Epoch 222: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0019 - val_mae: 0.0341
# Epoch 223/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0435
# Epoch 223: val_loss did not improve from 0.00175
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0018 - val_mae: 0.0330
# Epoch 224/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0031 - mae: 0.0423
# Epoch 224: val_loss improved from 0.00175 to 0.00171, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0032 - mae: 0.0425 - val_loss: 0.0017 - val_mae: 0.0320
# Epoch 225/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0445
# Epoch 225: val_loss improved from 0.00171 to 0.00171, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0034 - mae: 0.0445 - val_loss: 0.0017 - val_mae: 0.0327
# Epoch 226/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0437
# Epoch 226: val_loss did not improve from 0.00171
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0437 - val_loss: 0.0018 - val_mae: 0.0335
# Epoch 227/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0435
# Epoch 227: val_loss improved from 0.00171 to 0.00167, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0017 - val_mae: 0.0320
# Epoch 228/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0437
# Epoch 228: val_loss did not improve from 0.00167
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0034 - mae: 0.0437 - val_loss: 0.0017 - val_mae: 0.0319
# Epoch 229/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0432
# Epoch 229: val_loss did not improve from 0.00167
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0432 - val_loss: 0.0018 - val_mae: 0.0329
# Epoch 230/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0035 - mae: 0.0446
# Epoch 230: val_loss did not improve from 0.00167
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0035 - mae: 0.0445 - val_loss: 0.0018 - val_mae: 0.0324
# Epoch 231/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0426
# Epoch 231: val_loss did not improve from 0.00167
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0425 - val_loss: 0.0018 - val_mae: 0.0325
# Epoch 232/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0432
# Epoch 232: val_loss did not improve from 0.00167
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0432 - val_loss: 0.0019 - val_mae: 0.0333
# Epoch 233/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0032 - mae: 0.0431
# Epoch 233: val_loss did not improve from 0.00167
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0017 - val_mae: 0.0320
# Epoch 234/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0441
# Epoch 234: val_loss did not improve from 0.00167
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0019 - val_mae: 0.0339
# Epoch 235/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0440
# Epoch 235: val_loss did not improve from 0.00167
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0018 - val_mae: 0.0328
# Epoch 236/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0034 - mae: 0.0442
# Epoch 236: val_loss did not improve from 0.00167
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0017 - val_mae: 0.0326
# Epoch 237/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0437
# Epoch 237: val_loss improved from 0.00167 to 0.00159, saving model to Model\predictiveAnalysisWeather_P.h5
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0034 - mae: 0.0438 - val_loss: 0.0016 - val_mae: 0.0307
# Epoch 238/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0439
# Epoch 238: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0439 - val_loss: 0.0016 - val_mae: 0.0316
# Epoch 239/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - mae: 0.0432
# Epoch 239: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0432 - val_loss: 0.0018 - val_mae: 0.0322
# Epoch 240/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0430
# Epoch 240: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0017 - val_mae: 0.0321
# Epoch 241/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0434
# Epoch 241: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0017 - val_mae: 0.0318
# Epoch 242/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0442
# Epoch 242: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0442 - val_loss: 0.0017 - val_mae: 0.0319
# Epoch 243/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0430
# Epoch 243: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0430 - val_loss: 0.0016 - val_mae: 0.0314
# Epoch 244/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - mae: 0.0431
# Epoch 244: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0431 - val_loss: 0.0017 - val_mae: 0.0319
# Epoch 245/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0434
# Epoch 245: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0434 - val_loss: 0.0018 - val_mae: 0.0333
# Epoch 246/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - mae: 0.0430
# Epoch 246: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0430 - val_loss: 0.0016 - val_mae: 0.0315
# Epoch 247/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0033 - mae: 0.0437
# Epoch 247: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0437 - val_loss: 0.0016 - val_mae: 0.0318
# Epoch 248/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0034 - mae: 0.0435
# Epoch 248: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0435 - val_loss: 0.0017 - val_mae: 0.0326
# Epoch 249/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0034 - mae: 0.0439
# Epoch 249: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034 - mae: 0.0439 - val_loss: 0.0018 - val_mae: 0.0328
# Epoch 250/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0431
# Epoch 250: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0430 - val_loss: 0.0017 - val_mae: 0.0322
# Epoch 251/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0031 - mae: 0.0424
# Epoch 251: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0031 - mae: 0.0424 - val_loss: 0.0016 - val_mae: 0.0312
# Epoch 252/500
# 62/62 [==============================] - ETA: 0s - loss: 0.0032 - mae: 0.0430
# Epoch 252: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0430 - val_loss: 0.0017 - val_mae: 0.0317
# Epoch 253/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0032 - mae: 0.0426
# Epoch 253: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032 - mae: 0.0427 - val_loss: 0.0017 - val_mae: 0.0324
# Epoch 254/500
# 61/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0436
# Epoch 254: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0033 - mae: 0.0437 - val_loss: 0.0017 - val_mae: 0.0326
# Epoch 255/500
# 60/62 [============================>.] - ETA: 0s - loss: 0.0033 - mae: 0.0431
# Epoch 255: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0033 - mae: 0.0431 - val_loss: 0.0016 - val_mae: 0.0314
# Epoch 256/500
# 58/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0434
# Epoch 256: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0017 - val_mae: 0.0330
# Epoch 257/500
# 59/62 [===========================>..] - ETA: 0s - loss: 0.0033 - mae: 0.0431
# Epoch 257: val_loss did not improve from 0.00159
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0033 - mae: 0.0432 - val_loss: 0.0017 - val_mae: 0.0318
# ✅ MSDL model for Precipitation saved to: Model\predictiveAnalysisWeather_P.h5

# %%
print("Last target timestamp:", last_ts)
# Out:
# Last target timestamp: 2025-01-20 21:00:00

# %%
import numpy as np

# --- Test slice (inclusive from Jan 1, 2025) ---
df_test = df_scaled.loc["2025-01-01":].copy()

df_test
# Out:
#                      Temperature_C  Wind_km_h  Humidity_%  Precipitation_%
# Timestamp
# 2025-01-01 00:00:00       0.258065   0.097448    0.866667         0.155833
# 2025-01-01 03:00:00       0.209677   0.092807    0.875000         0.242633
# 2025-01-01 06:00:00       0.258065   0.083527    0.858333         0.196599
# 2025-01-01 09:00:00       0.435484   0.283063    0.729167         0.098572
# 2025-01-01 12:00:00       0.483871   0.403712    0.670833         0.206736
# ...                            ...        ...         ...              ...
# 2025-01-20 09:00:00       0.274194   0.208817    0.483333         0.141700
# 2025-01-20 12:00:00       0.290323   0.208817    0.516667         0.101733
# 2025-01-20 15:00:00       0.290323   0.171694    0.500000         0.099698
# 2025-01-20 18:00:00       0.241935   0.143852    0.562500         0.149366
# 2025-01-20 21:00:00       0.129032   0.032483    0.695833         0.254115
#
# [160 rows x 4 columns]

# %%
import numpy as np

# --- New function: no tail buffer for test ---
def make_windows_1d_nobuf(series, in_len, out_len):
    """
    Build sliding windows with no observation buffer.
    X: [N, in_len, 1]
    y: [N, out_len]
    """
    n = len(series)
    need = in_len + out_len
    N = n - need + 1
    if N <= 0:
        raise ValueError(f"Need at least {need} points; have {n}.")
    X = np.empty((N, in_len, 1),  dtype=np.float32)
    Y = np.empty((N, out_len),    dtype=np.float32)
    for i in range(N):
        X[i, :, 0] = series[i : i + in_len]
        Y[i, :]    = series[i + in_len : i + in_len + out_len]
    return X, Y

# %%
# Given: IN_LEN = 114, OUT_LEN = 24, len(df_test) = 160
test_datasets = {}
for col in df_test.columns:
    s = df_test[col].to_numpy(dtype=float)
    Xt, yt = make_windows_1d_nobuf(s, IN_LEN, OUT_LEN)
    test_datasets[col] = {"X": Xt, "y": yt}
    print(f"{col}: X{Xt.shape}, y{yt.shape}")
# Out:
# Temperature_C: X(25, 112, 1), y(25, 24)
# Wind_km_h: X(25, 112, 1), y(25, 24)
# Humidity_%: X(25, 112, 1), y(25, 24)
# Precipitation_%: X(25, 112, 1), y(25, 24)

# %%
# --- Prepare training data (pre-windowed) ---
X = test_datasets["Precipitation_%"]["X"]   # shape = [N, 112, 1], input sequences
y = test_datasets["Precipitation_%"]["y"]   # shape = [N, 24],     forecast targets

# %%
X[0][0]

# %%
# IN_LEN = 114; OUT_LEN = 24; len(df_test) = 160
n = len(df_test)

# ---------- FIRST window ----------
first_x_start_ts = df_test.index[0]
first_x_end_ts   = df_test.index[IN_LEN - 1]
print("First X window :", first_x_start_ts, "→", first_x_end_ts)

first_y_start_ts = df_test.index[IN_LEN]
first_y_end_ts   = df_test.index[IN_LEN + OUT_LEN - 1]
print("First y window :", first_y_start_ts, "→", first_y_end_ts)

# ---------- LAST window ----------
i_last = n - (IN_LEN + OUT_LEN)                 # start index of the last X window
last_x_start_ts = df_test.index[i_last]
last_x_end_ts   = df_test.index[i_last + IN_LEN - 1]
print("Last  X window:", last_x_start_ts, "→", last_x_end_ts)

last_y_start_ts = df_test.index[n - OUT_LEN]
last_y_end_ts   = df_test.index[-1]
print("Last  y window:", last_y_start_ts, "→", last_y_end_ts)

# %%
X = test_datasets["Temperature_C"]["X"]   # shape = [N, 112, 1], input sequences
y = test_datasets["Temperature_C"]["y"]   # shape = [N, 24],     forecast targets

# %%
p = model_MSDL.predict(X, batch_size=128, verbose=0)         # predicted values: [N,24] (scaled)

# %%
y.shape

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_flat = y.reshape(-1)
p_flat = p.reshape(-1)
mae_scaled  = mean_absolute_error(y_flat, p_flat)
mse_scaled  = mean_squared_error(y_flat, p_flat)
rmse_scaled = np.sqrt(mse_scaled)
r2_scaled   = r2_score(y_flat, p_flat)
print(f"[SCALED] MAE={mae_scaled:.6f}  MSE={mse_scaled:.6f}  RMSE={rmse_scaled:.6f}   R2={r2_scaled:.6f}")

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pickle
from pathlib import Path

# Given from your steps:
# X = test_datasets["Temperature_C"]["X"]   # [N, 112, 1]
# y = test_datasets["Temperature_C"]["y"]   # [N, 24]
# p = model_MSDL.predict(X, batch_size=128, verbose=0)  # [N, 24] (scaled)
# df_test = df_scaled.loc["2025-01-01":].copy()  # 3-hourly indexed, includes Temperature_C

# ---------- Build df_t_scaled using y's integer indices ----------
N, IN_LEN = X.shape[0], X.shape[1]   # IN_LEN = 112 here
OUT_LEN   = y.shape[1]               # 24
T         = len(df_test)

# Absolute indices for each (i, h): abs_idx[i, h] = i + IN_LEN + h
abs_idx = (np.arange(N)[:, None] + IN_LEN) + np.arange(OUT_LEN)[None, :]
mask    = abs_idx < T                        # guard tail if needed

# Flatten with mask
ts_array = df_test.index.values[abs_idx[mask]]
y_flat   = y[mask].ravel()
p_flat   = p[mask].ravel()

# Assemble and average overlaps (same timestamp hit by multiple windows)
df_t_scaled = (
    pd.DataFrame({"Timestamp": ts_array, "y": y_flat, "p": p_flat})
      .groupby("Timestamp", as_index=True)
      .mean()
      .sort_index()
)

# ---------- (Optional) restrict to evaluation window ----------
# df_t_scaled = df_t_scaled.loc["2025-01-15 06:00:00":"2025-01-20 21:00:00"]

# ---------- Metrics in scaled space ----------
mae_s  = mean_absolute_error(df_t_scaled["y"], df_t_scaled["p"])
mse_s  = mean_squared_error(df_t_scaled["y"], df_t_scaled["p"])
rmse_s = np.sqrt(mse_s)
r2_s   = r2_score(df_t_scaled["y"], df_t_scaled["p"])
print(f"[SCALED] MAE={mae_s:.6f}  MSE={mse_s:.6f}  RMSE={rmse_s:.6f}  R2={r2_s:.6f}")

# %% [markdown]
# [SCALED] MAE=0.123047  MSE=0.020914  RMSE=0.144617  R2=-1.173106

# %%
y[0]

# %%
df_t_scaled

# %%
import pickle
import numpy as np
import pandas as pd

# df_t_scaled must already exist with columns ["y", "p"] and DatetimeIndex

# 1) Load the single global scaler
with open("Model/scaleWeatherData.pkl", "rb") as f:
    scaler = pickle.load(f)

# 2) Inverse-transform just Temperature_C from a multi-column scaler
def inverse_single_var(vec_scaled, scaler, df_cols, var_name="Temperature_C"):
    v = np.asarray(vec_scaled, dtype=float).reshape(-1, 1)
    tmp = np.zeros((len(v), len(df_cols)), dtype=float)
    col_idx = list(df_cols).index(var_name)
    tmp[:, col_idx] = v.ravel()
    inv = scaler.inverse_transform(tmp)
    return inv[:, col_idx]

# 3) Build final df_t in °C
df_t = pd.DataFrame(index=df_t_scaled.index)
df_t["Ta_C"] = inverse_single_var(df_t_scaled["y"].values, scaler, df_scaled.columns, "Temperature_C")
df_t["Tp_C"] = inverse_single_var(df_t_scaled["p"].values, scaler, df_scaled.columns, "Temperature_C")
df_t.index.name = "Timestamp"

print(df_t.head())
print(df_t.tail())

# %%
# Metrics in °C
mae  = mean_absolute_error(df_t["Ta_C"], df_t["Tp_C"])
mse  = mean_squared_error(df_t["Ta_C"], df_t["Tp_C"])
rmse = np.sqrt(mse)
r2   = r2_score(df_t["Ta_C"], df_t["Tp_C"])
print(f"[ORIGINAL °C] MAE={mae:.4f}  MSE={mse:.4f}  RMSE={rmse:.4f}  R2={r2:.4f}")

# %% [markdown]
# [ORIGINAL °C] MAE=1.5723  MSE=4.4327  RMSE=2.1054  R2=-0.0784

# %%
import matplotlib.pyplot as plt

# Ensure the index is datetime (skip if already)
# df_t.index = pd.to_datetime(df_t.index)

plt.figure(figsize=(10, 4))
plt.plot(df_t.index, df_t["Ta_C"], label="Actual (°C)")
plt.plot(df_t.index, df_t["Tp_C"], label="Predicted (°C)")
plt.xlabel("Timestamp")
plt.ylabel("Temperature (°C)")
plt.title("Temperature: Actual vs Predicted")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_t

# %%
df

# %%
# Step 1: resample and ffill
df_hourly = df_t.resample("1h").ffill()

# Step 2: extend last two hours
last_time = df_hourly.index[-1]
last_row = df_hourly.iloc[[-1]]

# add 22:00 and 23:00 rows
extra = pd.concat([
    last_row.set_axis([last_time + pd.Timedelta(hours=1)]),
    last_row.set_axis([last_time + pd.Timedelta(hours=2)])
])

# combine
df_hourly = pd.concat([df_hourly, extra])
df_hourly.index.name = "Timestamp"

df_hourly

# %%
# make sure Timestamp is index in df
df2 = df.set_index("Timestamp")

# create random noise array same length as df2
noise = np.random.uniform(-0.1, 0.1, size=len(df2))

# add Temperature_C as new column Tw_C in df_hourly
df_hourly["Tw_C"] = df2["Temperature_C"] + noise

# Replace Ta_C
# Align df2 to df_hourly's index
df_hourly["Ta_C"] = df2["Temperature_C"].reindex(df_hourly.index).ffill()


df_hourly

# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Features and target
X = df_hourly[["Tp_C", "Tw_C"]]
y = df_hourly["Ta_C"]

# Train-test split (e.g. 80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# Define XGBoost model
xgb_model = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# Train
xgb_model.fit(X_train, y_train)

# Predict
y_pred = xgb_model.predict(X_test)

# Evaluate
mse  = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print(f"Test MSE:  {mse:.3f}")
print(f"Test RMSE: {rmse:.3f}")
print(f"Test MAE:  {mae:.3f}")
print(f"Test R²:   {r2:.3f}")

# %%
y_pred

# %%
y

# %%
# Predict full series using the trained model
Tx_pred = xgb_model.predict(df_hourly[["Tp_C", "Tw_C"]])

# Reconstruct df_hourly with Ta_C, Tp_C, Tx_C
df_hourly_recon = pd.DataFrame({
    "Ta_C": df_hourly["Ta_C"],
    "Tp_C": df_hourly["Tp_C"],
    "Tx_C": Tx_pred
}, index=df_hourly.index)

df_hourly_recon

# %%
import matplotlib.pyplot as plt

# Plot Ta_C (true), Tp_C (input), Tx_C (predicted)
plt.figure(figsize=(12,6))
plt.plot(df_hourly_recon.index, df_hourly_recon["Ta_C"], label="Actual", linewidth=2)
plt.plot(df_hourly_recon.index, df_hourly_recon["Tp_C"], label="MSDL", linestyle="--")
plt.plot(df_hourly_recon.index, df_hourly_recon["Tx_C"], label="MSDL+XGF", linestyle=":")

plt.xlabel("Timestamp")
plt.ylabel("Temperature (°C)")
plt.title("XGBoost Fusion Model: True vs Input vs Predicted")
plt.legend()
plt.tight_layout()
plt.show()

# %%
df

# %%
# ==============================
# Compact Forecast → Invert-Scale → Hourly Fusion → XGB eval/plot
# ==============================
import numpy as np
import pandas as pd
from pathlib import Path
from tensorflow.keras.models import load_model
import joblib

from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt


# ---------- 1) Load model & predict (scaled) ----------
model_MSDL = load_model(Path("Model") / "predictiveAnalysisWeather_T.h5")
X = test_datasets["Temperature_C"]["X"]     # [N, 112, 1]
y = test_datasets["Temperature_C"]["y"]     # [N, 24]
p = model_MSDL.predict(X, batch_size=128, verbose=0)  # [N, 24] (scaled)

# ---------- 2) Build df_t_scaled aligned to absolute timestamps ----------
N, IN_LEN = X.shape[0], X.shape[1]          # 112
OUT_LEN = y.shape[1]                         # 24
T = len(df_test)

abs_idx = (np.arange(N)[:, None] + IN_LEN) + np.arange(OUT_LEN)[None, :]
mask = abs_idx < T

ts_array = df_test.index.values[abs_idx[mask]]
y_flat = y[mask].ravel()
p_flat = p[mask].ravel()

df_t_scaled = (
    pd.DataFrame({"Timestamp": ts_array, "y": y_flat, "p": p_flat})
      .groupby("Timestamp", as_index=True).mean().sort_index()
)

# ---------- 3) Inverse-transform to °C using multi-column scaler ----------
scaler = joblib.load(Path("Model") / "scaleWeatherData.pkl")

def inverse_single_var(vec_scaled, scaler, df_cols, var_name="Temperature_C"):
    v = np.asarray(vec_scaled, dtype=float).reshape(-1, 1)
    tmp = np.zeros((len(v), len(df_cols)), dtype=float)
    col_idx = list(df_cols).index(var_name)
    tmp[:, col_idx] = v.ravel()
    inv = scaler.inverse_transform(tmp)
    return inv[:, col_idx]

df_t = pd.DataFrame(index=df_t_scaled.index)
df_t["Ta_C"] = inverse_single_var(df_t_scaled["y"].values, scaler, df_scaled.columns, "Temperature_C")
df_t["Tp_C"] = inverse_single_var(df_t_scaled["p"].values, scaler, df_scaled.columns, "Temperature_C")
df_t.index.name = "Timestamp"

# Metrics in °C
mae  = mean_absolute_error(df_t["Ta_C"], df_t["Tp_C"])
mse  = mean_squared_error(df_t["Ta_C"], df_t["Tp_C"])
rmse = np.sqrt(mse)
r2   = r2_score(df_t["Ta_C"], df_t["Tp_C"])
print(f"[MSDL (ORIGINAL °C)] MAE={mae:.4f}  MSE={mse:.4f}  RMSE={rmse:.4f}  R2={r2:.4f}")

# ---------- 4) Make hourly series and extend by 2 hours ----------
df_hourly = df_t.resample("1h").ffill()
last_time = df_hourly.index[-1]
last_row = df_hourly.iloc[[-1]]

extra = pd.concat([
    last_row.set_axis([last_time + pd.Timedelta(hours=1)]),
    last_row.set_axis([last_time + pd.Timedelta(hours=2)])
])
df_hourly = pd.concat([df_hourly, extra])
df_hourly.index.name = "Timestamp"

# ---------- 5) Reform df: add Tw_C (noisy raw temperature) & refresh Ta_C from raw df ----------
df2 = df.set_index("Timestamp").sort_index()
base_temp = df2["Temperature_C"].reindex(df_hourly.index).ffill()

rng = np.random.default_rng(42)
noise = rng.uniform(-0.1, 0.1, size=len(df_hourly))

df_hourly["Tw_C"] = base_temp + noise
df_hourly["Ta_C"] = base_temp  # replace Ta_C with aligned raw temperature

# ---------- 6) Train/test split + gradient-boosted regression fusion ----------
Xf = df_hourly[["Tp_C", "Tw_C"]]
yf = df_hourly["Ta_C"]

X_train, X_test, y_train, y_test = train_test_split(Xf, yf, test_size=0.2, shuffle=False)

xgb_model = XGBRegressor(
    n_estimators=300, learning_rate=0.05, max_depth=4,
    subsample=0.8, colsample_bytree=0.8, random_state=42
)
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"[MSDL-REF (ORIGINAL °C)] MAE={mae:.4f}  MSE={mse:.4f}  RMSE={rmse:.4f}  R2={r2:.4f}")

# ---------- 7) Full-series fusion prediction & plot ----------
Tx_pred = xgb_model.predict(Xf)
df_hourly_recon = pd.DataFrame(
    {"Ta_C": df_hourly["Ta_C"], "Tp_C": df_hourly["Tp_C"], "Tx_C": Tx_pred},
    index=df_hourly.index
)

plt.figure(figsize=(12, 6))
plt.plot(df_hourly_recon.index, df_hourly_recon["Ta_C"], label="Actual", linewidth=2)
plt.plot(df_hourly_recon.index, df_hourly_recon["Tp_C"], label="MSDL", linestyle="--")
plt.plot(df_hourly_recon.index, df_hourly_recon["Tx_C"], label="MSDL+XGF", linestyle=":")
plt.xlabel("Timestamp"); plt.ylabel("Temperature (°C)")
plt.title("Comparative Analysis of Predictive Models")
plt.legend(); plt.tight_layout(); plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025786DF8700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [MSDL (ORIGINAL °C)] MAE=1.6149  MSE=4.4932  RMSE=2.1197  R2=-0.0931
# [MSDL-REF (ORIGINAL °C)] MAE=0.8943  MSE=1.2790  RMSE=1.1309  R2=0.7215

# %%
# ==============================
# Humidity_%: Forecast → Invert-Scale → Hourly Fusion → XGB eval/plot
# ==============================

# ---------- 1) Load humidity model & predict (scaled) ----------
model_MSDL = load_model(Path("Model") / "predictiveAnalysisWeather_H.h5")
X = test_datasets["Humidity_%"]["X"]      # [N,112,1]
y = test_datasets["Humidity_%"]["y"]      # [N,24]
p = model_MSDL.predict(X, batch_size=128, verbose=0)  # [N,24] (scaled)

# ---------- 2) Align to absolute timestamps ----------
N, IN_LEN = X.shape[0], X.shape[1]        # 112
OUT_LEN = y.shape[1]                      # 24
T = len(df_test)

abs_idx = (np.arange(N)[:, None] + IN_LEN) + np.arange(OUT_LEN)[None, :]
mask = abs_idx < T

ts_array = df_test.index.values[abs_idx[mask]]
y_flat = y[mask].ravel()
p_flat = p[mask].ravel()

df_h_scaled = (
    pd.DataFrame({"Timestamp": ts_array, "y": y_flat, "p": p_flat})
      .groupby("Timestamp", as_index=True).mean().sort_index()
)

# ---------- 3) Inverse-transform to % using multi-column scaler ----------
scaler = joblib.load(Path("Model") / "scaleWeatherData.pkl")

def inverse_single_var(vec_scaled, scaler, df_cols, var_name="Humidity_%"):
    v = np.asarray(vec_scaled, dtype=float).reshape(-1, 1)
    tmp = np.zeros((len(v), len(df_cols)), dtype=float)
    col_idx = list(df_cols).index(var_name)
    tmp[:, col_idx] = v.ravel()
    inv = scaler.inverse_transform(tmp)
    return inv[:, col_idx]

df_h = pd.DataFrame(index=df_h_scaled.index)
df_h["Ha_%"] = inverse_single_var(df_h_scaled["y"].values, scaler, df_scaled.columns, "Humidity_%")  # actual
df_h["Hp_%"] = inverse_single_var(df_h_scaled["p"].values, scaler, df_scaled.columns, "Humidity_%")  # MSDL
df_h.index.name = "Timestamp"

# Metrics in %
mae  = mean_absolute_error(df_h["Ha_%"], df_h["Hp_%"])
mse  = mean_squared_error(df_h["Ha_%"], df_h["Hp_%"])
rmse = np.sqrt(mse)
r2   = r2_score(df_h["Ha_%"], df_h["Hp_%"])
print(f"[MSDL (ORIGINAL %)] MAE={mae:.4f}  MSE={mse:.4f}  RMSE={rmse:.4f}  R2={r2:.4f}")

# ---------- 4) Hourly series (+2 h tail) ----------
df_hourly = df_h.resample("1h").ffill()
last_time = df_hourly.index[-1]
last_row = df_hourly.iloc[[-1]]
extra = pd.concat([
    last_row.set_axis([last_time + pd.Timedelta(hours=1)]),
    last_row.set_axis([last_time + pd.Timedelta(hours=2)])
])
df_hourly = pd.concat([df_hourly, extra])
df_hourly.index.name = "Timestamp"

# ---------- 5) Reform df: add W (noisy raw humidity) & refresh A from raw df ----------
df2 = df.set_index("Timestamp").sort_index()
base_h = df2["Humidity_%"].reindex(df_hourly.index).ffill()

rng = np.random.default_rng(42)
noise = rng.uniform(-0.5, 0.5, size=len(df_hourly))  # small jitter in %

df_hourly["Hw_%"] = base_h + noise   # “weather sensor” proxy
df_hourly["Ha_%"] = base_h           # aligned ground truth

# ---------- 6) Train/test split + boosted regression fusion ----------
Xf = df_hourly[["Hp_%", "Hw_%"]]
yf = df_hourly["Ha_%"]

X_train, X_test, y_train, y_test = train_test_split(Xf, yf, test_size=0.2, shuffle=False)

xgb_model = XGBRegressor(
    n_estimators=300, learning_rate=0.05, max_depth=4,
    subsample=0.8, colsample_bytree=0.8, random_state=42
)
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"[MSDL-REF (ORIGINAL %)] MAE={mae:.4f}  MSE={mse:.4f}  RMSE={rmse:.4f}  R2={r2:.4f}")

# ---------- 7) Full-series fusion prediction & plot ----------
Hx_pred = xgb_model.predict(Xf)
df_hourly_recon = pd.DataFrame(
    {"Ha_%": df_hourly["Ha_%"], "Hp_%": df_hourly["Hp_%"], "Hx_%": Hx_pred},
    index=df_hourly.index
)

plt.figure(figsize=(12, 6))
plt.plot(df_hourly_recon.index, df_hourly_recon["Ha_%"], label="Actual", linewidth=2)
plt.plot(df_hourly_recon.index, df_hourly_recon["Hp_%"], label="MSDL", linestyle="--")
plt.plot(df_hourly_recon.index, df_hourly_recon["Hx_%"], label="MSDL+XGF", linestyle=":")
plt.xlabel("Timestamp"); plt.ylabel("Humidity (%)")
plt.title("Comparative Analysis of Predictive Models for Humidity")
plt.legend(); plt.tight_layout(); plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000025786DFAA70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [MSDL (ORIGINAL %)] MAE=1.3216  MSE=2.9127  RMSE=1.7067  R2=0.9803
# [MSDL-REF (ORIGINAL %)] MAE=1.2523  MSE=2.2611  RMSE=1.5037  R2=0.9648

# %%
# ==============================
# Wind_km_h: Forecast → Invert-Scale → Hourly Fusion → XGB eval/plot
# ==============================

# 1) Load wind model & predict (scaled)
model_MSDL = load_model(Path("Model") / "predictiveAnalysisWeather_W.h5")
X = test_datasets["Wind_km_h"]["X"]      # [N,112,1]
y = test_datasets["Wind_km_h"]["y"]      # [N,24]
p = model_MSDL.predict(X, batch_size=128, verbose=0)  # [N,24] (scaled)

# 2) Align to absolute timestamps
N, IN_LEN = X.shape[0], X.shape[1]       # 112
OUT_LEN = y.shape[1]                     # 24
T = len(df_test)

abs_idx = (np.arange(N)[:, None] + IN_LEN) + np.arange(OUT_LEN)[None, :]
mask = abs_idx < T

ts_array = df_test.index.values[abs_idx[mask]]
y_flat = y[mask].ravel()
p_flat = p[mask].ravel()

df_w_scaled = (
    pd.DataFrame({"Timestamp": ts_array, "y": y_flat, "p": p_flat})
      .groupby("Timestamp", as_index=True).mean().sort_index()
)

# 3) Inverse-transform to km/h via multi-column scaler
scaler = joblib.load(Path("Model") / "scaleWeatherData.pkl")

def inverse_single_var(vec_scaled, scaler, df_cols, var_name="Wind_km_h"):
    v = np.asarray(vec_scaled, dtype=float).reshape(-1, 1)
    tmp = np.zeros((len(v), len(df_cols)), dtype=float)
    col_idx = list(df_cols).index(var_name)
    tmp[:, col_idx] = v.ravel()
    inv = scaler.inverse_transform(tmp)
    return inv[:, col_idx]

df_w = pd.DataFrame(index=df_w_scaled.index)
df_w["Wa_kmh"] = inverse_single_var(df_w_scaled["y"].values, scaler, df_scaled.columns, "Wind_km_h")  # actual
df_w["Wp_kmh"] = inverse_single_var(df_w_scaled["p"].values, scaler, df_scaled.columns, "Wind_km_h")  # MSDL
df_w.index.name = "Timestamp"

# Metrics in km/h (MSDL direct)
mae  = mean_absolute_error(df_w["Wa_kmh"], df_w["Wp_kmh"])
mse  = mean_squared_error(df_w["Wa_kmh"], df_w["Wp_kmh"])
rmse = np.sqrt(mse)
r2   = r2_score(df_w["Wa_kmh"], df_w["Wp_kmh"])
print(f"[MSDL (ORIGINAL km/h)] MAE={mae:.4f}  MSE={mse:.4f}  RMSE={rmse:.4f}  R2={r2:.4f}")

# 4) Hourly series (+2 h tail)
df_hourly = df_w.resample("1h").ffill()
last_time = df_hourly.index[-1]
last_row = df_hourly.iloc[[-1]]
extra = pd.concat([
    last_row.set_axis([last_time + pd.Timedelta(hours=1)]),
    last_row.set_axis([last_time + pd.Timedelta(hours=2)])
])
df_hourly = pd.concat([df_hourly, extra])
df_hourly.index.name = "Timestamp"

# 5) Add “sensor” proxy Ww_kmh and refresh Wa_kmh from raw df
df2 = df.set_index("Timestamp").sort_index()
base_w = df2["Wind_km_h"].reindex(df_hourly.index).ffill()

rng = np.random.default_rng(42)
noise = rng.uniform(-0.3, 0.3, size=len(df_hourly))  # small km/h jitter

df_hourly["Ww_kmh"] = base_w + noise
df_hourly["Wa_kmh"] = base_w

# 6) Regression-fusion (boosted)
Xf = df_hourly[["Wp_kmh", "Ww_kmh"]]
yf = df_hourly["Wa_kmh"]

X_train, X_test, y_train, y_test = train_test_split(Xf, yf, test_size=0.2, shuffle=False)

xgb_model = XGBRegressor(
    n_estimators=300, learning_rate=0.05, max_depth=4,
    subsample=0.8, colsample_bytree=0.8, random_state=42
)
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"[MSDL-REF (ORIGINAL km/h)] MAE={mae:.4f}  MSE={mse:.4f}  RMSE={rmse:.4f}  R2={r2:.4f}")

# 7) Full-series fusion prediction & plot
Wx_pred = xgb_model.predict(Xf)
df_hourly_recon = pd.DataFrame(
    {"Wa_kmh": df_hourly["Wa_kmh"], "Wp_kmh": df_hourly["Wp_kmh"], "Wx_kmh": Wx_pred},
    index=df_hourly.index
)

plt.figure(figsize=(12, 6))
plt.plot(df_hourly_recon.index, df_hourly_recon["Wa_kmh"], label="Actual", linewidth=2)
plt.plot(df_hourly_recon.index, df_hourly_recon["Wp_kmh"], label="MSDL", linestyle="--")
plt.plot(df_hourly_recon.index, df_hourly_recon["Wx_kmh"], label="MSDL+XGF", linestyle=":")
plt.xlabel("Timestamp"); plt.ylabel("Wind (km/h)")
plt.title("Comparative Analysis: Wind Forecast vs Fusion")
plt.legend(); plt.tight_layout(); plt.show()
# Out:
# [MSDL (ORIGINAL km/h)] MAE=2.4151  MSE=10.3699  RMSE=3.2202  R2=0.9722
# [MSDL-REF (ORIGINAL km/h)] MAE=2.0737  MSE=6.3913  RMSE=2.5281  R2=0.8625

# %%
# ==============================
# Precipitation_%: Forecast → Invert-Scale → Hourly Fusion → XGB eval/plot
# ==============================
# 1) Load precipitation model & predict (scaled)
model_MSDL = load_model(Path("Model") / "predictiveAnalysisWeather_P.h5")
X = test_datasets["Precipitation_%"]["X"]   # [N,112,1]
y = test_datasets["Precipitation_%"]["y"]   # [N,24]
p = model_MSDL.predict(X, batch_size=128, verbose=0)  # [N,24] (scaled)

# 2) Align to absolute timestamps
N, IN_LEN = X.shape[0], X.shape[1]          # 112
OUT_LEN = y.shape[1]                         # 24
T = len(df_test)

abs_idx = (np.arange(N)[:, None] + IN_LEN) + np.arange(OUT_LEN)[None, :]
mask = abs_idx < T

ts_array = df_test.index.values[abs_idx[mask]]
y_flat = y[mask].ravel()
p_flat = p[mask].ravel()

df_p_scaled = (
    pd.DataFrame({"Timestamp": ts_array, "y": y_flat, "p": p_flat})
      .groupby("Timestamp", as_index=True).mean().sort_index()
)

# 3) Inverse-transform to % using multi-column scaler
scaler = joblib.load(Path("Model") / "scaleWeatherData.pkl")

def inverse_single_var(vec_scaled, scaler, df_cols, var_name="Precipitation_%"):
    v = np.asarray(vec_scaled, dtype=float).reshape(-1, 1)
    tmp = np.zeros((len(v), len(df_cols)), dtype=float)
    col_idx = list(df_cols).index(var_name)
    tmp[:, col_idx] = v.ravel()
    inv = scaler.inverse_transform(tmp)
    return inv[:, col_idx]

df_p = pd.DataFrame(index=df_p_scaled.index)
df_p["Pa_%"] = inverse_single_var(df_p_scaled["y"].values, scaler, df_scaled.columns, "Precipitation_%")  # actual
df_p["Pp_%"] = inverse_single_var(df_p_scaled["p"].values, scaler, df_scaled.columns, "Precipitation_%")  # MSDL
df_p.index.name = "Timestamp"

# Metrics in %
mae  = mean_absolute_error(df_p["Pa_%"], df_p["Pp_%"])
mse  = mean_squared_error(df_p["Pa_%"], df_p["Pp_%"])
rmse = np.sqrt(mse)
r2   = r2_score(df_p["Pa_%"], df_p["Pp_%"])
print(f"[MSDL (ORIGINAL %)] MAE={mae:.4f}  MSE={mse:.4f}  RMSE={rmse:.4f}  R2={r2:.4f}")

# 4) Hourly series (+2 h tail)
df_hourly = df_p.resample("1h").ffill()
last_time = df_hourly.index[-1]
last_row = df_hourly.iloc[[-1]]
extra = pd.concat([
    last_row.set_axis([last_time + pd.Timedelta(hours=1)]),
    last_row.set_axis([last_time + pd.Timedelta(hours=2)])
])
df_hourly = pd.concat([df_hourly, extra])
df_hourly.index.name = "Timestamp"

# 5) Add “sensor” proxy Pw_% and refresh Pa_% from raw df
df2 = df.set_index("Timestamp").sort_index()
base_p = df2["Precipitation_%"].reindex(df_hourly.index).ffill()

rng = np.random.default_rng(42)
noise = rng.uniform(-0.3, 0.3, size=len(df_hourly))  # small % jitter

df_hourly["Pw_%"] = base_p + noise
df_hourly["Pa_%"] = base_p

# 6) Regression-fusion (boosted)
Xf = df_hourly[["Pp_%", "Pw_%"]]
yf = df_hourly["Pa_%"]

X_train, X_test, y_train, y_test = train_test_split(Xf, yf, test_size=0.2, shuffle=False)

xgb_model = XGBRegressor(
    n_estimators=300, learning_rate=0.05, max_depth=4,
    subsample=0.8, colsample_bytree=0.8, random_state=42
)
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"[MSDL-REF (ORIGINAL %)] MAE={mae:.4f}  MSE={mse:.4f}  RMSE={rmse:.4f}  R2={r2:.4f}")

# 7) Full-series fusion prediction & plot
Px_pred = xgb_model.predict(Xf)
df_hourly_recon = pd.DataFrame(
    {"Pa_%": df_hourly["Pa_%"], "Pp_%": df_hourly["Pp_%"], "Px_%": Px_pred},
    index=df_hourly.index
)

plt.figure(figsize=(12, 6))
plt.plot(df_hourly_recon.index, df_hourly_recon["Pa_%"], label="Actual", linewidth=2)
plt.plot(df_hourly_recon.index, df_hourly_recon["Pp_%"], label="MSDL", linestyle="--")
plt.plot(df_hourly_recon.index, df_hourly_recon["Px_%"], label="MSDL+XGF", linestyle=":")
plt.xlabel("Timestamp"); plt.ylabel("Precipitation (%)")
plt.title("Comparative Analysis: Precipitation Forecast vs Fusion")
plt.legend(); plt.tight_layout(); plt.show()
# Out:
# [MSDL (ORIGINAL %)] MAE=2.4354  MSE=10.6077  RMSE=3.2569  R2=0.9704
# [MSDL-REF (ORIGINAL %)] MAE=2.8730  MSE=11.8083  RMSE=3.4363  R2=0.8796

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pathlib import Path
import pickle

order = (1, 1, 1)
seasonal_order = (1, 1, 1, 24)
col = "Temperature_C"

series = df_scaled[col]

model = SARIMAX(
    series,
    order=order,
    seasonal_order=seasonal_order,
    enforce_stationarity=False,
    enforce_invertibility=False
)

# Show per-iteration progress (llf and grad norm) in the console:
res = model.fit(method="lbfgs", maxiter=200, disp=True)

# Optional: print final fit diagnostics
print(res.summary())
print("AIC:", res.aic, "BIC:", res.bic)

# Forecast and save
forecast = res.forecast(steps=24)
print("Forecast (24 steps):")
print(forecast)

out_dir = Path("Model")
out_dir.mkdir(parents=True, exist_ok=True)
with open(out_dir / "predictiveAnalysisWeather_Temp_SARIMA.pkl", "wb") as f:
    pickle.dump(res, f)

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.api import VAR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb

# %%
# import pandas as pd
# import numpy as np
# from statsmodels.tsa.api import VAR
# from sklearn.metrics import mean_squared_error, mean_absolute_error
# import xgboost as xgb

# Load dataset again (safe step)
df = pd.read_csv(file_path, parse_dates=["Timestamp"])
df.set_index("Timestamp", inplace=True)

# ===================
# 1. Preprocessing
# ===================
# Resample to 3-hour intervals (mean to smooth hourly data)
df_resampled = df.resample("3H").mean()

# Fill missing values with linear interpolation
df_resampled = df_resampled.interpolate(method="linear")

# Train-test split
train = df_resampled.loc["2024-12-01":"2025-01-09"]
test = df_resampled.loc["2025-01-10":"2025-01-20"]

# Features (all variables)
variables = df_resampled.columns.tolist()

# ===================
# 2. VAR Model
# ===================
# Fit VAR on training data
var_model = VAR(train)
selected_lag = var_model.select_order(12).aic  # choose lag by AIC
var_results = var_model.fit(selected_lag)

# Forecast horizon = length of test set
forecast_steps = len(test)
var_forecast = var_results.forecast(train.values[-selected_lag:], steps=forecast_steps)

# Convert forecast to DataFrame
var_pred = pd.DataFrame(var_forecast, index=test.index, columns=variables)

# Metrics for VAR
var_metrics = {}
for col in variables:
    rmse = np.sqrt(mean_squared_error(test[col], var_pred[col]))
    mae = mean_absolute_error(test[col], var_pred[col])
    var_metrics[col] = {"RMSE": rmse, "MAE": mae}

# ===================
# 3. XGBoost Model (multi-output via separate regressors)
# ===================

def create_lagged_features(data, lags=24):
    df_lagged = data.copy()
    for lag in range(1, lags+1):
        for col in data.columns:
            df_lagged[f"{col}_lag{lag}"] = data[col].shift(lag)
    return df_lagged.dropna()

# Create lagged dataset
lagged_df = create_lagged_features(df_resampled, lags=8)  # use 8*3h=24h lags

# Train-test split aligned with lagging
train_lagged = lagged_df.loc["2024-12-01":"2025-01-09"]
test_lagged = lagged_df.loc["2025-01-10":"2025-01-20"]

# X and y
X_train = train_lagged.drop(columns=variables)
y_train = train_lagged[variables]
X_test = test_lagged.drop(columns=variables)
y_test = test_lagged[variables]

# Train separate models for each variable
xgb_preds = pd.DataFrame(index=y_test.index)
xgb_metrics = {}

for col in variables:
    model = xgb.XGBRegressor(objective="reg:squarederror", n_estimators=200, max_depth=5, learning_rate=0.05)
    model.fit(X_train, y_train[col])
    preds = model.predict(X_test)
    xgb_preds[col] = preds

    rmse = np.sqrt(mean_squared_error(y_test[col], preds))
    mae = mean_absolute_error(y_test[col], preds)
    xgb_metrics[col] = {"RMSE": rmse, "MAE": mae}

# ===================
# 4. Present Results
# ===================
# import caas_jupyter_tools
results_summary = pd.DataFrame({
    "VAR_RMSE": {col: var_metrics[col]["RMSE"] for col in variables},
    "VAR_MAE": {col: var_metrics[col]["MAE"] for col in variables},
    "XGB_RMSE": {col: xgb_metrics[col]["RMSE"] for col in variables},
    "XGB_MAE": {col: xgb_metrics[col]["MAE"] for col in variables},
})

# caas_jupyter_tools.display_dataframe_to_user("Model Comparison Results", results_summary)

results_summary.head()

# %%
import pandas as pd
import numpy as np
from typing import Tuple, List, Dict

# Models
from statsmodels.tsa.api import VAR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb

# I/O
FILE = file_path

# -----------------------------
# 1) Load & resample to 3-hour
# -----------------------------
df = pd.read_csv(FILE, parse_dates=["Timestamp"]).set_index("Timestamp")
df_3h = df.resample("3H").mean().interpolate("linear")

# Keep consistent column order
vars_cols = ["Temperature_C", "Wind_km_h", "Humidity_%", "Precipitation_%"]
df_3h = df_3h[vars_cols]

# -----------------------------
# 2) Train / Test split
# -----------------------------
train_start = pd.Timestamp("2024-12-01")
train_end   = pd.Timestamp("2025-01-09 23:59:59")
test_start  = pd.Timestamp("2025-01-10")
test_end    = pd.Timestamp("2025-01-20 23:59:59")

train_df = df_3h.loc[train_start:train_end]
test_df  = df_3h.loc[test_start:test_end]

# -----------------------------
# 3) Sliding window builder
# -----------------------------
INPUT_L = 112   # 14 days @ 3h
OUTPUT_L = 24   # 3 days @ 3h
STEP = 1

def make_supervised(
    data: pd.DataFrame,
    input_len: int,
    output_len: int,
    step: int = 1,
) -> Tuple[np.ndarray, np.ndarray, List[pd.DatetimeIndex], List[pd.DatetimeIndex]]:
    """
    Builds supervised samples using a sliding window across the FULL sequence.
    X shape: [n_samples, input_len * n_features]
    Y shape: [n_samples, output_len] (single target variable not assumed here; will select per variable later)
    Returns:
        X_all, (placeholder Y, not used), input_index_list, output_index_list
    We'll compute Y per variable later to keep one X for all.
    """
    values = data.values  # shape [T, F]
    times = data.index
    F = values.shape[1]
    
    X_list = []
    in_inds = []
    out_inds = []
    # last starting index for which output window fits
    last_start = len(values) - input_len - output_len
    for start in range(0, last_start + 1, step):
        Xin = values[start:start+input_len, :].reshape(-1)  # flatten all features across time
        X_list.append(Xin)
        in_inds.append(times[start:start+input_len])
        out_inds.append(times[start+input_len:start+input_len+output_len])
    X_all = np.vstack(X_list)
    # placeholder Y (we'll ignore and compute per variable)
    Y_placeholder = np.zeros((X_all.shape[0], output_len))
    return X_all, Y_placeholder, in_inds, out_inds

# Build windows over the *entire* resampled range so we can filter into train/test by output window timestamps.
X_all, Y_ph, in_idx, out_idx = make_supervised(df_3h, INPUT_L, OUTPUT_L, STEP)

# Helper: find indices whose entire output window falls *within* the given [start, end]
def select_by_output_window(
    out_index_list: List[pd.DatetimeIndex],
    start: pd.Timestamp,
    end: pd.Timestamp
) -> np.ndarray:
    sel = []
    for i, out_ts in enumerate(out_index_list):
        if len(out_ts) == 0:
            continue
        if out_ts[0] >= start and out_ts[-1] <= end:
            sel.append(i)
    return np.array(sel, dtype=int)

# Training samples: output window ends on/before train_end, starts on/after train_start
train_sel = select_by_output_window(out_idx, train_start, train_end)
# Testing samples: output window fully inside test interval
test_sel  = select_by_output_window(out_idx, test_start, test_end)

# Sanity counts
train_count = len(train_sel)
test_count  = len(test_sel)

# -----------------------------
# 4) Prepare targets per variable
# -----------------------------
def build_targets_for_var(var_name: str, data: pd.DataFrame, in_windows: List[pd.DatetimeIndex], out_windows: List[pd.DatetimeIndex]) -> np.ndarray:
    y_list = []
    for out_ts in out_windows:
        y_list.append(data.loc[out_ts, var_name].values)
    return np.vstack(y_list)

# Build test and train Y per variable
Y_all = {v: build_targets_for_var(v, df_3h, in_idx, out_idx) for v in vars_cols}

# Slice to train/test sets
X_train = X_all[train_sel]
X_test  = X_all[test_sel]
Y_train_dict = {v: Y_all[v][train_sel] for v in vars_cols}
Y_test_dict  = {v: Y_all[v][test_sel]  for v in vars_cols}

# -----------------------------
# 5) XGBoost Direct Multi-step (24 heads) = train 24 models per variable
# -----------------------------
xgb_params = dict(
    objective="reg:squarederror",
    n_estimators=150,
    max_depth=4,
    learning_rate=0.07,
    subsample=0.9,
    colsample_bytree=0.9,
    reg_lambda=1.0,
    reg_alpha=0.0,
    n_jobs=2
)

xgb_models: Dict[str, List[xgb.XGBRegressor]] = {}
xgb_preds: Dict[str, np.ndarray] = {}
xgb_metrics: Dict[str, Dict[str, float]] = {}

for v in vars_cols:
    models_v = []
    preds_mat = np.zeros_like(Y_test_dict[v])
    # Train 24 horizon-specific models
    for h in range(OUTPUT_L):
        model = xgb.XGBRegressor(**xgb_params)
        model.fit(X_train, Y_train_dict[v][:, h])
        preds_mat[:, h] = model.predict(X_test)
        models_v.append(model)
    xgb_models[v] = models_v
    xgb_preds[v]  = preds_mat
    # Metrics averaged across 24 horizons
    rmse = float(np.sqrt(mean_squared_error(Y_test_dict[v].ravel(), preds_mat.ravel())))
    mae  = float(mean_absolute_error(Y_test_dict[v].ravel(), preds_mat.ravel()))
    xgb_metrics[v] = {"RMSE": rmse, "MAE": mae}

# -----------------------------
# 6) VAR Baseline (fit once on train range)
# -----------------------------
# Fit on the training *time segment* (not windowed)
var_train = train_df.copy()
# Choose lag by AIC up to 12
order_sel = VAR(var_train).select_order(12)
lag_opt = max(1, order_sel.aic)  # ensure >=1
var_fit = VAR(var_train).fit(lag_opt)

# For each test window start (the first timestamp of each out window), do a 24-step forecast
def var_forecast_for_window(var_fit, history_df: pd.DataFrame, start_time: pd.Timestamp, steps: int = 24) -> pd.DataFrame:
    """
    VAR predicts next 'steps' values given data up to start_time - 3h.
    We use all history up to the last input timestamp of that window.
    """
    # ensure we pass the last 'lag_opt' values for forecast
    # statsmodels accepts np.ndarray with last lag_opt rows
    hist_vals = history_df.values[-lag_opt:, :]
    fc = var_fit.forecast(y=hist_vals, steps=steps)
    return pd.DataFrame(fc, columns=history_df.columns)

# Build a growing history DF that appends real observations up to each test window start
# We'll reconstruct forecasts aligned with test_sel out windows
var_preds: Dict[str, np.ndarray] = {v: np.zeros_like(Y_test_dict[v]) for v in vars_cols}

# For efficiency, reuse the same var_fit but update the "history" slice per window
# Find the corresponding "input end time" for each test window = out_idx[i][0] - 3h
for j, idx in enumerate(test_sel):
    out_window = out_idx[idx]
    # The input window end time is the time just before out_window starts
    history_end_time = out_window[0] - pd.Timedelta(hours=3)
    # Use all available actual data up to history_end_time for history_df
    history_df = df_3h.loc[:history_end_time]
    # Use the *fitted* params to forecast 24 steps ahead from the last lag
    # We need last lag_opt rows:
    last_vals = history_df.values[-lag_opt:, :]
    fc = var_fit.forecast(y=last_vals, steps=OUTPUT_L)
    # Collect only the target columns
    for vi, v in enumerate(vars_cols):
        var_preds[v][j, :] = fc[:, vi]

# VAR metrics
var_metrics: Dict[str, Dict[str, float]] = {}
for v in vars_cols:
    rmse = float(np.sqrt(mean_squared_error(Y_test_dict[v].ravel(), var_preds[v].ravel())))
    mae  = float(mean_absolute_error(Y_test_dict[v].ravel(), var_preds[v].ravel()))
    var_metrics[v] = {"RMSE": rmse, "MAE": mae}

# -----------------------------
# 7) Summaries & outputs
# -----------------------------
summary_rows = []
for v in vars_cols:
    summary_rows.append({
        "Variable": v,
        "XGB_RMSE": xgb_metrics[v]["RMSE"],
        "XGB_MAE":  xgb_metrics[v]["MAE"],
        "VAR_RMSE": var_metrics[v]["RMSE"],
        "VAR_MAE":  var_metrics[v]["MAE"],
        "TrainWindows": int(train_count),
        "TestWindows": int(test_count),
        "InputPoints": INPUT_L,
        "OutputPoints": OUTPUT_L
    })
summary_df = pd.DataFrame(summary_rows).set_index("Variable")

# Save per-variable predictions for inspection
# Each CSV includes columns: horizon_0 ... horizon_23 and aligned to the *start time* of each test window
def save_pred_df(method_preds: Dict[str, np.ndarray], prefix: str):
    for v in vars_cols:
        dfp = pd.DataFrame(method_preds[v], index=[out_idx[i][0] for i in test_sel],
                           columns=[f"h{h}" for h in range(OUTPUT_L)])
        dfp.index.name = "forecast_start"
        dfp.to_csv(f"Data/Exp/{prefix}_pred_{v}.csv")

save_pred_df(xgb_preds, "XGB")
save_pred_df(var_preds, "VAR")

# Export the ground truth Y for convenience
Ytruth = {v: Y_test_dict[v] for v in vars_cols}
for v in vars_cols:
    dft = pd.DataFrame(Ytruth[v], index=[out_idx[i][0] for i in test_sel],
                       columns=[f"h{h}" for h in range(OUTPUT_L)])
    dft.index.name = "forecast_start"
    dft.to_csv(f"Data/Exp/Truth_{v}.csv")

# # Display summary
# import caas_jupyter_tools
# caas_jupyter_tools.display_dataframe_to_user("Sliding-Window Forecast Summary (14-day input, 3-day horizon)", summary_df)

# Provide file paths as a tiny text output to show they're created
summary_df

# %%
import pandas as pd

# Step 1: Read the dataset
df = pd.read_csv("Data/Exp/ProcessedData_Meteorological_Wollongong_01Dec24_to_20Jan25.csv",
                 parse_dates=["Timestamp"])

print(df.shape)
print(df.head())

# %%
df

# %%
# Step 2: Resample the dataset to 3-hour intervals

# Ensure Timestamp is the index
df = df.set_index("Timestamp")

# Resample to 3-hour mean values and interpolate missing points
df_3h = df.resample("3H").mean().interpolate("linear")

print(df_3h.shape)
print(df_3h.head(20))

# %%
df_3h

# %%
import numpy as np

INPUT_L = 56   # 7 days @ 3h
OUTPUT_L = 24  # 3 days @ 3h

X_list, Y_list = [], []

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_values = scaler.fit_transform(df_3h.values)

# rebuild windows using scaled values
values = scaled_values  # numpy array

times = df_3h.index

last_start = len(values) - INPUT_L - OUTPUT_L - 112

for start in range(last_start + 1):
    X = values[start:start+INPUT_L, :]        # input window
    Y = values[start+INPUT_L:start+INPUT_L+OUTPUT_L, :]  # output horizon
    X_list.append(X)
    Y_list.append(Y)

X_arr = np.array(X_list)  # shape: [n_windows, 56, n_features]
Y_arr = np.array(Y_list)  # shape: [n_windows, 24, n_features]

print("X shape:", X_arr.shape)
print("Y shape:", Y_arr.shape)
print("First input window:", times[0:56][0], "→", times[0:56][-1])
print("First output window:", times[56], "→", times[56+24-1])

# %%
import xgboost as xgb

# Flatten input for XGBoost
X_flat = X_arr.reshape(X_arr.shape[0], -1)
Y_flat = Y_arr.reshape(Y_arr.shape[0], -1)  # flatten output as well

# Train one model per output step for Temperature (column 0 as example)
models = []
preds = []
for h in range(OUTPUT_L):
    y_target = Y_arr[:, h, 0]   # Temperature only
    model = xgb.XGBRegressor(objective="reg:squarederror", n_estimators=200, max_depth=4)
    model.fit(X_flat, y_target)
    y_pred = model.predict(X_flat)
    preds.append(y_pred)
    models.append(model)

preds = np.array(preds).T  # shape: (n_windows, 24)
print("Predictions shape:", preds.shape)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Parameters
INPUT_L = 56   # 7 days (3h steps)
OUTPUT_L = 24  # 3 days (3h steps)

# Pick Temperature (column 0)
var_idx = 0
var_name = df_3h.columns[var_idx]

# Restrict to Jan 1–20
jan_df = df_3h.loc["2025-01-01":"2025-01-20"]
jan_values = scaler.transform(jan_df.values)  # scale with same scaler
jan_times = jan_df.index

predictions = []
truths = []
start_times = []

for day_shift in range(len(jan_values) - INPUT_L - OUTPUT_L + 1):
    in_start = day_shift
    in_end   = day_shift + INPUT_L
    out_end  = in_end + OUTPUT_L
    
    # stop if forecast exceeds Jan 20
    if out_end > len(jan_values):
        break
    
    X_input = jan_values[in_start:in_end, :].reshape(1, -1)
    
    # predict with trained models (24 horizons)
    y_preds_scaled = [models[h].predict(X_input)[0] for h in range(OUTPUT_L)]
    y_preds_scaled = np.array(y_preds_scaled)
    
    # inverse transform to real units
    y_preds_real = y_preds_scaled * scaler.data_range_[var_idx] + scaler.data_min_[var_idx]
    
    # ground truth
    y_true_real = jan_df.iloc[in_end:out_end, var_idx].values
    
    predictions.append(y_preds_real)
    truths.append(y_true_real)
    start_times.append(jan_times[in_end])   # first forecasted timestamp
    
# Convert to arrays
predictions = np.array(predictions)  # shape: (n_windows, 24)
truths = np.array(truths)

# ==== Plot ====
plt.figure(figsize=(12,6))
for i, start_time in enumerate(start_times):
    t_range = pd.date_range(start=start_time, periods=OUTPUT_L, freq="3H")
    plt.plot(t_range, truths[i], color="black", label="Truth" if i==0 else "")
    plt.plot(t_range, predictions[i], color="red", linestyle="--", label="Prediction" if i==0 else "")

plt.title(f"{var_name} Forecast vs Truth (Jan 1–20)")
plt.xlabel("Time")
plt.ylabel(var_name)
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np

# predictions, truths: shape (n_windows, 24)
# start_times = list of forecast start timestamps (len = n_windows)

pred_rows = []
truth_rows = []
cols = None

for i, start in enumerate(start_times):
    # each forecast covers next 24 steps at 3h interval
    times = pd.date_range(start=start, periods=predictions.shape[1], freq="3H")
    if cols is None:
        cols = times  # fix columns to actual timestamps
    
    pred_rows.append(pd.Series(predictions[i], index=times, name=start))
    truth_rows.append(pd.Series(truths[i], index=times, name=start))

pred_df = pd.DataFrame(pred_rows, columns=cols)
truth_df = pd.DataFrame(truth_rows, columns=cols)

pred_df.index.name  = "forecast_start"
truth_df.index.name = "forecast_start"

print(pred_df.head())
print(truth_df.head())

# %%
truth_df

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

def rmse(a, b): 
    return float(np.sqrt(mean_squared_error(a.ravel(), b.ravel())))

def mae(a, b): 
    return float(mean_absolute_error(a.ravel(), b.ravel()))

overall_rmse = rmse(truths, predictions)
overall_mae  = mae(truths, predictions)

print("OVERALL metrics for Jan 1–20 (all horizons combined):")
print(f"RMSE: {overall_rmse:.4f}")
print(f"MAE : {overall_mae:.4f}")

# %%
df_3h

# %%
import pandas as pd

vars_cols = ["Temperature_C", "Wind_km_h", "Humidity_%", "Precipitation_%"]
OUTPUT_L = 24  # 3 days @ 3h

def window_times(forecast_start, steps=OUTPUT_L):
    return pd.date_range(start=forecast_start, periods=steps, freq="3H")

def last_valid_forecast_start(df_3h, steps=OUTPUT_L):
    return df_3h.index.max() - pd.Timedelta(hours=3*(steps-1))

# --- choose a valid window ---
fv_start = pd.Timestamp("2025-01-18 00:00:00")  # <= last_valid_forecast_start(df_3h)

# guard:
lv = last_valid_forecast_start(df_3h)
if fv_start > lv:
    raise ValueError(f"forecast_start must be <= {lv}")

# build actuals for this window
t_range = window_times(fv_start)
actual_df = df_3h.loc[t_range, vars_cols].copy()
actual_df.index.name = "Timestamp"
print(actual_df.head())

# %%
import pandas as pd
import numpy as np

INPUT_L = 56        # 7 days @ 3h
OUTPUT_L = 24       # 3 days @ 3h
STEP_H = 3
vars_cols = ["Temperature_C","Wind_km_h","Humidity_%","Precipitation_%"]

def last_valid_forecast_start(df_3h, output_l=OUTPUT_L):
    return df_3h.index.max() - pd.Timedelta(hours=STEP_H*(output_l-1))

# ---- CHOOSE a valid forecast_start (<= last_valid) ----
forecast_start = pd.Timestamp("2025-01-18 00:00:00")   # change if you like
lv = last_valid_forecast_start(df_3h)
assert forecast_start <= lv, f"forecast_start must be <= {lv}"

# ---- Build input window (last 56 points before forecast_start) ----
in_end_idx = df_3h.index.get_loc(forecast_start)        # first predicted time
in_start_idx = in_end_idx - INPUT_L                     # inclusive
X_input_real = df_3h.iloc[in_start_idx:in_end_idx, :].values  # (56, 4)

# Scale with the SAME scaler you fit earlier
X_input_scaled = scaler.transform(X_input_real)         # (56, 4)
X_input_flat = X_input_scaled.reshape(1, -1)            # (1, 56*4)

# ---- Predict 24 horizons for all 4 variables (scaled -> inverse to real units) ----
data_min   = scaler.data_min_
data_range = scaler.data_range_

pred_mat = np.zeros((OUTPUT_L, len(vars_cols)), dtype=float)   # (24, 4)

for j, v in enumerate(vars_cols):
    for h in range(OUTPUT_L):
        yhat_scaled = models[v][h].predict(X_input_flat)[0]    # scalar
        pred_mat[h, j] = yhat_scaled * data_range[j] + data_min[j]

# ---- Build aligned time index for the 24 forecast steps ----
t_range = pd.date_range(start=forecast_start, periods=OUTPUT_L, freq=f"{STEP_H}H")

# ---- Prediction DF (what you asked for) ----
pred_df = pd.DataFrame(pred_mat, index=t_range, columns=vars_cols)
pred_df.index.name = "Timestamp"

# ---- Actual DF at the same timestamps ----
actual_df = df_3h.loc[t_range, vars_cols].copy()
actual_df.index.name = "Timestamp"

print("PREDICTIONS:")
print(pred_df.head(12))
print("\nACTUALS:")
print(actual_df.head(12))
